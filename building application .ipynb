# %%
import pandas as pd 
df=pd.read_csv('C:\\Users\\masrra\Desktop\data2.csv')
df
# Out:
#                   Column1                         Column2    Column3  \
# 0                   Title                        Location      Price
# 1          Villa for sale              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# ...                   ...                             ...        ...
# 10183      Villa for sale                        Laar 196  € 599,900
# 10184    Mansion for sale               1030 — Schaerbeek  € 729,000
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186  Penthouse for sale            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                     Column4          Column5    Column6         Column7  \
# ...

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
df=pd.read_csv('C:\\Users\\masrra\Desktop\data2.csv')
df.rename(columns={'Column1':'property-type'},inplace=True)
df.rename(columns={'Column2':'Location'},inplace=True)
df.rename(columns={'Column3':'Price'},inplace=True)
df.rename(columns={'Column4':'Area'},inplace=True)
df.rename(columns={'Column5':'Number_of_Rooms'},inplace=True)
df.rename(columns={'Column6':'Furnished'},inplace=True)
df.rename(columns={'Column7':'Kitchen type'},inplace=True)
df.rename(columns={'Column8':'Status'},inplace=True)
df.rename(columns={'Column9':'Garden surface'},inplace=True)
df.rename(columns={'Column10':'Swimming Pool'},inplace=True)
df = df.drop(0)


df
#for column in df.columns:
 #   print(column)
# Out:
#             property-type                        Location      Price  \
# 1          Villa for sale              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# 5          House for sale             Rue Petite Voie 176  € 149,000
# ...                   ...                             ...        ...
# 10183      Villa for sale                        Laar 196  € 599,900
# 10184    Mansion for sale               1030 — Schaerbeek  € 729,000
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186  Penthouse for sale            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                        Area Number_of_Rooms Furnished    Kitchen type  \
# ...

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
df=pd.read_csv('C:\\Users\\masrra\Desktop\data2.csv')
df=df.replace({'Column1':{'Mansion for sale':'OTHERS',
'Penthouse for sale' :'OTHERS',
'Villa for sale':'OTHERS',
'Quartier du Bailou - Maisons' : 'OTHERS',
'Bungalow for sale' :'OTHERS',
 "'t Groenehof":'OTHERS',
'Mixed-use building for sale':'OTHERS',
'Exceptional property for sale':'OTHERS',
'Town-house for sale':'OTHERS',
'Exceptional property for sale':'OTHERS',
'Maisons Arborescence':'OTHERS',
'Maisons neuves à vendre à':'OTHERS',
'Farmhouse for sale':'OTHERS',
'Leuze - Centre ville':'OTHERS',
'TONGRE NOTRE DAME':'OTHERS',
'Residentie Berghof' :'OTHERS',
'Woonerf Velodroom':'OTHERS',
'Country house for sale' :'OTHERS',
'New real estate project':'OTHERS',
'Project ROTTERIJ':'OTHERS',
'Gezellige nieuwbouw woonwijk te koop in Beveren':'OTHERS',
'REGATTA WONINGEN':'OTHERS',
'TONGRE NOTRE DAME - 8 maisons':'OTHERS',
       'New real estate project - Houses for sale':'OTHERS',
       'Gezellige nieuwbouw woonwijk te koop in Beveren-Le':'OTHERS',
       'Woonproject Zittaart Fase 3':'OTHERS',
        "L'Orée de Seumay":'OTHERS',
       'Woonproject Zittaart Fase 1 en 2':'OTHERS',
        'SINJAN':'OTHERS', "Woningen Op't Zand":'OTHERS',
       'THIER DES SOTAIS':'OTHERS',
        'Hof Berlaere - Woningen':'OTHERS',
       'Basalt - nieuwbouwwoningen':'OTHERS',
        'Stellar - Maisons':'OTHERS',
       'Heibloem - BEN woningen te Nijlen':'OTHERS',
        '"Les Maisons de la Ferme':'OTHERS',
       'Woonproject te Paddenweg Lier - BEN woni ngen':'OTHERS',
       'Woonproject Diamant te Herenthout - Woningen':'OTHERS',
       'Parkview - Woningen':'OTHERS',
        'Woningen Lijsterweg':'OTHERS',
       'Residentie Zuidkwartier - Woningen':'OTHERS',
        'Chapelle Sainte-Anne':'OTHERS',
       'Woningen Meerlaarstraat':'OTHERS',
        'Woningen Heieinde':'OTHERS',
        'EKSTERVELD':'OTHERS',
       'Grensstraat - BEN woningen':'OTHERS',
       '5 woningen - Residentie De Winghe':'OTHERS',
       'Vloeiende - nieuwbouwwoningen':'OTHERS', 'Dockside Gardens woningen':'OTHERS',
       'Pré à la Planche Lots 7 à 15':'OTHERS', 'WONINGEN I':'OTHERS',
       'De Confiserie - gebouw H':'OTHERS', 'The Revelation':'OTHERS', 'Sluisstraat':'OTHERS',
       "'Eglegem Sunset'":'OTHERS', 'Nijven 27 Oppuurs':'OTHERS', 'Bottelarij':'OTHERS',
       '"Moulin Blanc" Villas':'OTHERS', 'MOULIN BLANC':'OTHERS', '"Clos du verger"':'OTHERS',
       'Quartier Champ Delvigne':'OTHERS', 'Other properties for sale':'OTHERS',
       'Gent - Hof van Gent':'OTHERS', 'Castle for sale':'OTHERS', 'HATTRICK':'OTHERS',
       'Chalet for sale':'OTHERS', 'Ground floor for sale':'OTHERS',
       'Clos Georgette Brenez':'OTHERS', 'CLOS DU ROGNAC FLEMALLE Phase 1':'OTHERS',
       'Clos des Etangs':'OTHERS', "Maison - Le haut d'Hondzo":'OTHERS',
       'Déjà 95% DES LOTS VENDUS - 20 maisons neuves haute':'OTHERS',
       "LES COTEAUX D'ERBONNE - MONT FALISE PHASE 1 MAISON":'OTHERS',
       'Lotissement "Ann-Sophie C':'OTHERS', 'Kerkstraat - Zwevegem':'OTHERS',
       'Domaine de Limonval':'OTHERS',
       'CLOS DES TROIS CHENES MAISONS - TREVI RASQUAIN':'OTHERS',
       'CLOS DES TROIS CHENES - TREVI LIEGE - MAISONS':'OTHERS', 'ARBOR - Otegem':'OTHERS',
       'Nieuwbouwproject Dahlia':'OTHERS' , 'Lotissement Frassem':'OTHERS',
       'Studio for sale':'OTHERS', 'Manor house for sale':'OTHERS', 'CHAUMONT-GISTOUX':'OTHERS',
       'Adolphe Hullebroeckstraat':'OTHERS', 'Combattants de Templeuve':'OTHERS',
       'Lotissement Signeulx':'OTHERS', 'Burenberg Uphill':'OTHERS', 'Simmendans':'OTHERS',
       'Leeuwhof':'OTHERS', 'Bouwgronden en nieuwe won':'OTHERS', 'Duplex for sale':'OTHERS',
       'Residentie Theresianenhof':'OTHERS', 'Bois de la Pierre':'OTHERS', 'Ten Amershove':'OTHERS',
       "Luxe villa's Zoute":'OTHERS',
       'Nieuwbouwwoningen in het centrum van Kachtem':'OTHERS', 'AntonyTuin':'OTHERS',
       'bouwgronden en nieuwe won':'OTHERS', 'Hélécine':'OTHERS',
       'nieuwe woningen en bouwgr':'OTHERS', "C' Shell":'OTHERS',
       'bouwgronden en nieuwbouww':'OTHERS', 'Eringhem':'OTHERS',
       'Nieuwe woning & gronden,':'OTHERS', 'Bouwgrond en nieuwe wonin':'OTHERS',
       'Eco-quartier Boncelles':'OTHERS', 'Nieuwe woningen op fietsa':'OTHERS',
       'Domaine des Papillons':'OTHERS', 'Saint-Nicolas - Rue Thiou':'OTHERS',
       'nieuwe woningen in een ru':'OTHERS', 'Verkaveling Borstelstraat Houthulst':'OTHERS',
       'nieuwe woningen pal onder':'OTHERS', 'Hertstraat 15-21':'OTHERS',
       'Nieuwbouw woonsite HUBA':'OTHERS', 'De Statie':'OTHERS', 'Ruiselede fase 3':'OTHERS',
       'Nieuwenhove':'OTHERS', 'VERKAVELING HONZEBROUCK':'OTHERS', 'Project Sogeta':'OTHERS',
       'Les Oliviers Woningen - F':'OTHERS', 'Madelon':'OTHERS',
       'Hector Olivierstraat, 8480 Eernegem':'OTHERS', 'nieuwe woningen met prach':'OTHERS',
       'Jemeppe - Rue Xhavée':'OTHERS', 'Ans - Rue Haut-Douy (Mais':'OTHERS',
       'WETTEREN - Project SVENDS':'OTHERS', 'nieuwe woningen vlak bij':'OTHERS',
       'HalleRiet':'OTHERS', 'Caserne de Saive':'OTHERS', 'Wellens Wonen':'OTHERS',
       "Green C - The Villa's":'OTHERS', 'Maison clé sur porte':'OTHERS',
       'Zandvoordsestraat Oudenburg':'OTHERS', 'Roclenge - Rue Jean Derri':'OTHERS',
       'nieuwe woningen in rustig':'OTHERS', 'nieuwe woningen met vlott':'OTHERS',
       'HUIS WOUTERS':'OTHERS', 'Louis Genot':'OTHERS', 'Belgrade Phase 2':'OTHERS',
       'Project Aalbeke':'OTHERS', 'Nieuwe, moderne woningen':'OTHERS',
       'LALYS: je droom binnen handbereik':'OTHERS', 'Boterberg - Nieuwerkerken':'OTHERS',
       "Wonen in 't park - Boutersem":'OTHERS', 'ESCANAFFLES 4330105':'OTHERS',
       'Woonproject Olympia':'OTHERS', 'Belgrade Maisons':'OTHERS',
       'Gitsstraat 42 te Torhout':'OTHERS', 'Bolderik':'OTHERS', 'Saint Joseph BE':'OTHERS',
       'GroeneMeer':'OTHERS', 'Champ du Tordoir FIII':'OTHERS', 'Project Astravorm':'OTHERS',
       'Izegem Forum':'OTHERS', 'Steenberg':'OTHERS', 'Tuinen van Eden':'OTHERS',
       'J.B. Coomansstraat - BEN woningen te Berlaar':'OTHERS', 'projet-martin':'OTHERS',
       'LEEUWHOF - PROJ FASE 2':'OTHERS', 'Kloostertuin Woningen':'OTHERS', 'Lebeke 202':'OTHERS',
       'MAISONS DU MANOIR II':'OTHERS', 'LEEUWHOF - PROJ FASE 3':'OTHERS',
       'Geneverpiete woningen':'OTHERS', '2 nieuwe woningen':'OTHERS',
       'trendy nieuwbouwwoningen':'OTHERS', 'Maisons neuves à Wierde':'OTHERS',
       'Brugge Gulden Roos':'OTHERS', 'Moderne woningen te Gompe':'OTHERS',
       'Nieuwe woningen in rustig':'OTHERS', 'Project Sint-Jozef':'OTHERS',
       'Bitterstraat Jabbeke':'OTHERS', 'Lieve Gardens - woningen':'OTHERS',
       'Lieve Gardens':'OTHERS', '9450 Haaltert - Pontweg 4':'OTHERS', "LIVIN'LOPPEM":'OTHERS',
       'De Gits':'OTHERS', 'Unieke BEN woningen':'OTHERS', 'Asperre (Papenhof2) - Won':'OTHERS',
       'Roggestraat':'OTHERS', 'Residentie Kapelleken':'OTHERS', 'De Stek Woningen':'OTHERS',
       '3 prachtige BEN-woningen':'OTHERS', 'Westdorp':'OTHERS',
       'Achterstraat 14, 8480 Eernegem':'OTHERS', 'Peterseliestraat Brugge -':'OTHERS',
       'LUX fase II_woningen':'OTHERS',
       'Peterseliestraat Brugge - Wonen langs de vestingen':'OTHERS',
       'Residentie Dockside Garde':'OTHERS', 'Woonerf Bachtekerkweg':'OTHERS', 'Townhouses':'OTHERS',
       'Woningen Rosalie':'OTHERS', 'Residentie Alex II':'OTHERS', 'Domaine du Fort':'OTHERS', '809':'OTHERS',
       'BEN-woningen te Herentals':'OTHERS',
       'Echte parkwoningen vlakbij centrum Tielt':'OTHERS', 
         "Woonproject te Paddenweg Lier - BEN woningen" :"OTHERS" 
                          }})
df.rename(columns={'Column1':'property-type'},inplace=True)
df.rename(columns={'Column2':'Location'},inplace=True)
df.rename(columns={'Column3':'Price'},inplace=True)
df.rename(columns={'Column4':'Area'},inplace=True)
df.rename(columns={'Column5':'Number_of_Rooms'},inplace=True)
df.rename(columns={'Column6':'Furnished'},inplace=True)
df.rename(columns={'Column7':'Kitchen type'},inplace=True)
df.rename(columns={'Column8':'Status'},inplace=True)
df.rename(columns={'Column9':'Garden surface'},inplace=True)
df.rename(columns={'Column10':'Swimming Pool'},inplace=True)
df = df.drop(0)

df
# Out:
#             property-type                        Location      Price  \
# 1                  OTHERS              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# 5          House for sale             Rue Petite Voie 176  € 149,000
# ...                   ...                             ...        ...
# 10183              OTHERS                        Laar 196  € 599,900
# 10184              OTHERS               1030 — Schaerbeek  € 729,000
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186              OTHERS            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                        Area Number_of_Rooms Furnished    Kitchen type  \
# ...

# %%
df['property-type'].unique
# Out:
# <bound method Series.unique of 1                    OTHERS
# 2            House for sale
# 3            House for sale
# 4            House for sale
# 5            House for sale
#                 ...
# 10183                OTHERS
# 10184                OTHERS
# 10185    Apartment for sale
# 10186                OTHERS
# 10187        House for sale
# Name: property-type, Length: 10187, dtype: object>

# %%
#df['Column1'].plot(kind='hist')
df['property-type'].value_counts()
# Out:
# House for sale              6502
# OTHERS                      2832
# Apartment block for sale     439
# Apartment for sale           414
# Name: property-type, dtype: int64

# %%
df = df.drop(df[df.Number_of_Rooms =='400 m² square meters livable space' ].index)
df = df.drop(df[df.Number_of_Rooms =='429 m² square meters livable spac' ].index)
df = df.drop(df[df.Number_of_Rooms =='275 m² square meters of land' ].index)
df = df.drop(df[df.Number_of_Rooms =='9 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='5 bathrooms' ].index)
df = df.drop(df[df.Number_of_Rooms =='2700 m² square meters of land' ].index)
df = df.drop(df[df.Number_of_Rooms =='141 m² square meters livable space' ].index)
df = df.drop(df[df.Number_of_Rooms =='306 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='200 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1440 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='44 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='249 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='435 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1440 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='633 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='360 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='388 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='367 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='763 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='312 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='150 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='500 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='9 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='509 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='429 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1362 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms=='77 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1436 m² square meters of land '].index)
df = df.drop(df[df.Number_of_Rooms =='550 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1436 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='409 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='6200 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1425 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='36 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='39 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='50 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='30 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='18 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='179 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='234 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='21 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2000 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1004 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='256 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='486 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='225 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='94 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='184 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='3 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2 - 3 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='140 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='13 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='12 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='14 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='3 - 5 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='17 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='16 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='1 bathroom'].index)
df = df.drop(df[df.Number_of_Rooms =='20 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='23 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='2 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='250 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='23 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='15 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='4 - 5 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='385 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='650 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='3 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='4 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='11 bedrooms  '].index)
df = df.drop(df[df.Number_of_Rooms =='96 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='875 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='75 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='252 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='350 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='750 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1 - 3 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='11 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='220 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='149 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='6 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2288 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='200050 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='Number_of_Rooms'].index)
df = df.drop(df[df.Number_of_Rooms =='270 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='218 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='507 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1038 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='305 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='700 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='22 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='295 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='28 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='715 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='21 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='280 m² square meters of land'].index)

df['Number_of_Rooms'] = df['Number_of_Rooms'].str.extract(r'(\d+)')
df
# Out:
#             property-type                        Location   Price  \
# 1                  OTHERS              Prins Karellaan 13    1650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  419000
# 4          House for sale                Ruelle Hierby 17  149000
# 5          House for sale             Rue Petite Voie 176  149000
# 6          House for sale            Rue Pierre Curie 107  149000
# ...                   ...                             ...     ...
# 10183              OTHERS                        Laar 196  599900
# 10184              OTHERS               1030 — Schaerbeek  729000
# 10185  Apartment for sale                 1370 — Jodoigne  150000
# 10186              OTHERS            Kustlaan 111 Box 6/7    2795
# 10187      House for sale              Chemin du Tombeu 6  980000
#
#                        Area Number_of_Rooms Furnished    Kitchen type  \
# 1      4 bedrooms | 499 m²                4        No  Hyper equipped
# ...

# %%
df

# %%
#df = df.drop(df[df.Column1 =='Apartment block for sale' ].index)
#df

# %%
# df['Column1'].replace({'Apartment block for sal': 'Apartment '})
#df['Column1'].replace({'Apartment for sal': 'Apartment '})
#(df.rename({'Apartment block for sale': 'appartement', 'Apartment  for sale': 'appartment'}))
#df.rename({'Apartment block for sale': 'appartement'})
df.rename({'Apartment block for sale': 'appartement'},inplace=True)
df

# %%
df['property-type'].value_counts()

# %%
df['property-type'].apply(type).value_counts()

# %%
df = df.drop(df[df.property-type== 0].index)
df = df.drop(df[df.Location == 0].index)
df = df.drop(df[df.Price == 0].index)
df = df.drop(df[df.Area== 0].index)
df = df.drop(df[df.Number_of_Rooms== 0].index)
df = df.drop(df[df.Furnished == 0].index)
df = df.drop(df[df.Kitchentype == 0].index)
df = df.drop(df[df.Status == 0].index)
df = df.drop(df[df.Gardensurface == 0].index)
df = df.drop(df[df.SwimmingPool== 0].index)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df = df.drop(df[df.property-type== 0].index)
#       2 df = df.drop(df[df.Location == 0].index)
#       3 df = df.drop(df[df.Price == 0].index)
#
# NameError: name 'df' is not defined

# %%
df.dtypes

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
df=pd.read_csv('C:\\Users\\masrra\Desktop\data2.csv')
df=df.replace({'Column1':{'Mansion for sale':'OTHERS',
'Penthouse for sale' :'OTHERS',
'Villa for sale':'OTHERS',
'Quartier du Bailou - Maisons' : 'OTHERS',
'Bungalow for sale' :'OTHERS',
 "'t Groenehof":'OTHERS',
'Mixed-use building for sale':'OTHERS',
'Exceptional property for sale':'OTHERS',
'Town-house for sale':'OTHERS',
'Exceptional property for sale':'OTHERS',
'Maisons Arborescence':'OTHERS',
'Maisons neuves à vendre à':'OTHERS',
'Farmhouse for sale':'OTHERS',
'Leuze - Centre ville':'OTHERS',
'TONGRE NOTRE DAME':'OTHERS',
'Residentie Berghof' :'OTHERS',
'Woonerf Velodroom':'OTHERS',
'Country house for sale' :'OTHERS',
'New real estate project':'OTHERS',
'Project ROTTERIJ':'OTHERS',
'Gezellige nieuwbouw woonwijk te koop in Beveren':'OTHERS',
'REGATTA WONINGEN':'OTHERS',
                          }})
#df
#for (columnName, columnData) in df.iteritems():
    #print('Column Name : ', columnName)
    #print('Column Contents : ', columnData.values)
#column1 = df.iloc[:, 0]
#print('Column Contents : ', column1.values)
#for i in df.iteritems():
 #   column1 = df.iloc[:, 0]
  #  if i =='House for sale':
   #     continue
    #elif i=='Apartment for sale':
     #       continue
    #else: i=='OTHERS'
#df   
df.rename(columns={'Column1':' "property-type'},inplace=True)
df.rename(columns={'Column2':'Location'},inplace=True)
df.rename(columns={'Column3':'Price'},inplace=True)
df.rename(columns={'Column4':'Area'},inplace=True)
df.rename(columns={'Column5':'Number_of_Rooms'},inplace=True)
df.rename(columns={'Column6':'Furnished'},inplace=True)
df.rename(columns={'Column7':'Kitchen type'},inplace=True)
df.rename(columns={'Column8':'Status'},inplace=True)
df.rename(columns={'Column9':'Garden surface'},inplace=True)
df.rename(columns={'Column10':'Swimming Pool'},inplace=True)

# Convert single column to int dtype.

#df['Number_of_Rooms'] = df['Number_of_Rooms'].astype(int)
#df = df.astype({'Number_of_Rooms':'int'})

df['Price'] = df['Price'].str.replace('[,]', '')
df['Price'] = df['Price'].str.replace('[€]', '')
df['Area'] = df['Area'].str.replace('[m²]', '')
df['Garden surface'] = df['Garden surface'].str.replace('[m²]', '')
df['Number_of_Rooms'] = df['Number_of_Rooms'].str.extract(r'(\d+)')
df

# %%
df['Number_of_Rooms'].describe()

# %%
df.dtypes

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#sns.regplot(x="Number_of_Rooms",y="Price",data=df)
#sns.regplot(x=df['Number_of_Rooms'],y=df['Price'])
#df['Price'].plot(kind='hist')

# %%
df['Price'].value_counts()

# %%
df['Price'].unique

# %%
#df['Price'] = pd.to_numeric(df['Price'])
#df["Price"] = pd.to_numeric(df["Price"].replace({',':''}, regex=True))
#df['Price'] = pd.to_numeric(df.Price.str.replace('\D',''))

# %%
#df.Price = pd.to_numeric(df.Price.str.replace(r"\€|,","", regex=True))

# %%
#df.Price

# %%
df['Number_of_Rooms'].unique()

# %%
df['Number_of_Rooms'].apply(type).value_counts()

# %%
df['Number_of_Rooms'].unique

# %%
df['Price'] = df['Price'].apply(lambda x: x.replace('€', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)
df
# Out:
#             property-type                        Location   Price  \
# 1                  OTHERS              Prins Karellaan 13    1650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  419000
# 4          House for sale                Ruelle Hierby 17  149000
# 5          House for sale             Rue Petite Voie 176  149000
# 6          House for sale            Rue Pierre Curie 107  149000
# ...                   ...                             ...     ...
# 10183              OTHERS                        Laar 196  599900
# 10184              OTHERS               1030 — Schaerbeek  729000
# 10185  Apartment for sale                 1370 — Jodoigne  150000
# 10186              OTHERS            Kustlaan 111 Box 6/7    2795
# 10187      House for sale              Chemin du Tombeu 6  980000
#
#                        Area  Number_of_Rooms Furnished    Kitchen type  \
# 1      4 bedrooms | 499 m²              1650        No  Hyper equipped
# ...

# %%
df['Number_of_Rooms'].apply(type).value_counts()

# %%
df['Number_of_Rooms'].plot(kind='hist')

# %%
sns.displot(df['Number_of_Rooms'],kde=False)

# %%
#df['Price']=df['Price'].apply(lambda x: ((r'[^\d.]', '', x)))
#print(df)

# %%
#df['Price'].apply(type)
df['Price'].apply(type).value_counts()

# %%
#def clean_currency(x):
 #   """ If the value is a string, then remove currency symbol and delimiters
  #  otherwise, the value is numeric and can be converted
   # """
   # if isinstance(x, str):
    #    return(x.replace('€', '').replace(',', ''))
    #return(x)
#df['Price'] = df['Price'].apply(clean_currency).astype('int')
#df['Price_Type'] = df['Price'].apply(lambda x: type(x).__name__)

# %%
#df['Price'] = df['Price'].str.replace(',','').str.replace('€','').astype('float')

# %%
num=df._get_numeric_data() #To extract the whole numbers from the dataFrame
num

# %%
df['Price'].value_counts()

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
df=pd.read_csv('C:\\Users\\masrra\Desktop\data2.csv')
df=df.replace({'Column1':{'Mansion for sale':'OTHERS',
'Penthouse for sale' :'OTHERS',
'Villa for sale':'OTHERS',
'Quartier du Bailou - Maisons' : 'OTHERS',
'Bungalow for sale' :'OTHERS',
 "'t Groenehof":'OTHERS',
'Mixed-use building for sale':'OTHERS',
'Exceptional property for sale':'OTHERS',
'Town-house for sale':'OTHERS',
'Exceptional property for sale':'OTHERS',
'Maisons Arborescence':'OTHERS',
'Maisons neuves à vendre à':'OTHERS',
'Farmhouse for sale':'OTHERS',
'Leuze - Centre ville':'OTHERS',
'TONGRE NOTRE DAME':'OTHERS',
'Residentie Berghof' :'OTHERS',
'Woonerf Velodroom':'OTHERS',
'Country house for sale' :'OTHERS',
'New real estate project':'OTHERS',
'Project ROTTERIJ':'OTHERS',
'Gezellige nieuwbouw woonwijk te koop in Beveren':'OTHERS',
'REGATTA WONINGEN':'OTHERS',
'TONGRE NOTRE DAME - 8 maisons':'OTHERS',
       'New real estate project - Houses for sale':'OTHERS',
       'Gezellige nieuwbouw woonwijk te koop in Beveren-Le':'OTHERS',
       'Woonproject Zittaart Fase 3':'OTHERS',
        "L'Orée de Seumay":'OTHERS',
       'Woonproject Zittaart Fase 1 en 2':'OTHERS',
        'SINJAN':'OTHERS', "Woningen Op't Zand":'OTHERS',
       'THIER DES SOTAIS':'OTHERS',
        'Hof Berlaere - Woningen':'OTHERS',
       'Basalt - nieuwbouwwoningen':'OTHERS',
        'Stellar - Maisons':'OTHERS',
       'Heibloem - BEN woningen te Nijlen':'OTHERS',
        '"Les Maisons de la Ferme':'OTHERS',
       'Woonproject te Paddenweg Lier - BEN woni ngen':'OTHERS',
       'Woonproject Diamant te Herenthout - Woningen':'OTHERS',
       'Parkview - Woningen':'OTHERS',
        'Woningen Lijsterweg':'OTHERS',
       'Residentie Zuidkwartier - Woningen':'OTHERS',
        'Chapelle Sainte-Anne':'OTHERS',
       'Woningen Meerlaarstraat':'OTHERS',
        'Woningen Heieinde':'OTHERS',
        'EKSTERVELD':'OTHERS',
       'Grensstraat - BEN woningen':'OTHERS',
       '5 woningen - Residentie De Winghe':'OTHERS',
       'Vloeiende - nieuwbouwwoningen':'OTHERS', 'Dockside Gardens woningen':'OTHERS',
       'Pré à la Planche Lots 7 à 15':'OTHERS', 'WONINGEN I':'OTHERS',
       'De Confiserie - gebouw H':'OTHERS', 'The Revelation':'OTHERS', 'Sluisstraat':'OTHERS',
       "'Eglegem Sunset'":'OTHERS', 'Nijven 27 Oppuurs':'OTHERS', 'Bottelarij':'OTHERS',
       '"Moulin Blanc" Villas':'OTHERS', 'MOULIN BLANC':'OTHERS', '"Clos du verger"':'OTHERS',
       'Quartier Champ Delvigne':'OTHERS', 'Other properties for sale':'OTHERS',
       'Gent - Hof van Gent':'OTHERS', 'Castle for sale':'OTHERS', 'HATTRICK':'OTHERS',
       'Chalet for sale':'OTHERS', 'Ground floor for sale':'OTHERS',
       'Clos Georgette Brenez':'OTHERS', 'CLOS DU ROGNAC FLEMALLE Phase 1':'OTHERS',
       'Clos des Etangs':'OTHERS', "Maison - Le haut d'Hondzo":'OTHERS',
       'Déjà 95% DES LOTS VENDUS - 20 maisons neuves haute':'OTHERS',
       "LES COTEAUX D'ERBONNE - MONT FALISE PHASE 1 MAISON":'OTHERS',
       'Lotissement "Ann-Sophie C':'OTHERS', 'Kerkstraat - Zwevegem':'OTHERS',
       'Domaine de Limonval':'OTHERS',
       'CLOS DES TROIS CHENES MAISONS - TREVI RASQUAIN':'OTHERS',
       'CLOS DES TROIS CHENES - TREVI LIEGE - MAISONS':'OTHERS', 'ARBOR - Otegem':'OTHERS',
       'Nieuwbouwproject Dahlia':'OTHERS' , 'Lotissement Frassem':'OTHERS',
       'Studio for sale':'OTHERS', 'Manor house for sale':'OTHERS', 'CHAUMONT-GISTOUX':'OTHERS',
       'Adolphe Hullebroeckstraat':'OTHERS', 'Combattants de Templeuve':'OTHERS',
       'Lotissement Signeulx':'OTHERS', 'Burenberg Uphill':'OTHERS', 'Simmendans':'OTHERS',
       'Leeuwhof':'OTHERS', 'Bouwgronden en nieuwe won':'OTHERS', 'Duplex for sale':'OTHERS',
       'Residentie Theresianenhof':'OTHERS', 'Bois de la Pierre':'OTHERS', 'Ten Amershove':'OTHERS',
       "Luxe villa's Zoute":'OTHERS',
       'Nieuwbouwwoningen in het centrum van Kachtem':'OTHERS', 'AntonyTuin':'OTHERS',
       'bouwgronden en nieuwe won':'OTHERS', 'Hélécine':'OTHERS',
       'nieuwe woningen en bouwgr':'OTHERS', "C' Shell":'OTHERS',
       'bouwgronden en nieuwbouww':'OTHERS', 'Eringhem':'OTHERS',
       'Nieuwe woning & gronden,':'OTHERS', 'Bouwgrond en nieuwe wonin':'OTHERS',
       'Eco-quartier Boncelles':'OTHERS', 'Nieuwe woningen op fietsa':'OTHERS',
       'Domaine des Papillons':'OTHERS', 'Saint-Nicolas - Rue Thiou':'OTHERS',
       'nieuwe woningen in een ru':'OTHERS', 'Verkaveling Borstelstraat Houthulst':'OTHERS',
       'nieuwe woningen pal onder':'OTHERS', 'Hertstraat 15-21':'OTHERS',
       'Nieuwbouw woonsite HUBA':'OTHERS', 'De Statie':'OTHERS', 'Ruiselede fase 3':'OTHERS',
       'Nieuwenhove':'OTHERS', 'VERKAVELING HONZEBROUCK':'OTHERS', 'Project Sogeta':'OTHERS',
       'Les Oliviers Woningen - F':'OTHERS', 'Madelon':'OTHERS',
       'Hector Olivierstraat, 8480 Eernegem':'OTHERS', 'nieuwe woningen met prach':'OTHERS',
       'Jemeppe - Rue Xhavée':'OTHERS', 'Ans - Rue Haut-Douy (Mais':'OTHERS',
       'WETTEREN - Project SVENDS':'OTHERS', 'nieuwe woningen vlak bij':'OTHERS',
       'HalleRiet':'OTHERS', 'Caserne de Saive':'OTHERS', 'Wellens Wonen':'OTHERS',
       "Green C - The Villa's":'OTHERS', 'Maison clé sur porte':'OTHERS',
       'Zandvoordsestraat Oudenburg':'OTHERS', 'Roclenge - Rue Jean Derri':'OTHERS',
       'nieuwe woningen in rustig':'OTHERS', 'nieuwe woningen met vlott':'OTHERS',
       'HUIS WOUTERS':'OTHERS', 'Louis Genot':'OTHERS', 'Belgrade Phase 2':'OTHERS',
       'Project Aalbeke':'OTHERS', 'Nieuwe, moderne woningen':'OTHERS',
       'LALYS: je droom binnen handbereik':'OTHERS', 'Boterberg - Nieuwerkerken':'OTHERS',
       "Wonen in 't park - Boutersem":'OTHERS', 'ESCANAFFLES 4330105':'OTHERS',
       'Woonproject Olympia':'OTHERS', 'Belgrade Maisons':'OTHERS',
       'Gitsstraat 42 te Torhout':'OTHERS', 'Bolderik':'OTHERS', 'Saint Joseph BE':'OTHERS',
       'GroeneMeer':'OTHERS', 'Champ du Tordoir FIII':'OTHERS', 'Project Astravorm':'OTHERS',
       'Izegem Forum':'OTHERS', 'Steenberg':'OTHERS', 'Tuinen van Eden':'OTHERS',
       'J.B. Coomansstraat - BEN woningen te Berlaar':'OTHERS', 'projet-martin':'OTHERS',
       'LEEUWHOF - PROJ FASE 2':'OTHERS', 'Kloostertuin Woningen':'OTHERS', 'Lebeke 202':'OTHERS',
       'MAISONS DU MANOIR II':'OTHERS', 'LEEUWHOF - PROJ FASE 3':'OTHERS',
       'Geneverpiete woningen':'OTHERS', '2 nieuwe woningen':'OTHERS',
       'trendy nieuwbouwwoningen':'OTHERS', 'Maisons neuves à Wierde':'OTHERS',
       'Brugge Gulden Roos':'OTHERS', 'Moderne woningen te Gompe':'OTHERS',
       'Nieuwe woningen in rustig':'OTHERS', 'Project Sint-Jozef':'OTHERS',
       'Bitterstraat Jabbeke':'OTHERS', 'Lieve Gardens - woningen':'OTHERS',
       'Lieve Gardens':'OTHERS', '9450 Haaltert - Pontweg 4':'OTHERS', "LIVIN'LOPPEM":'OTHERS',
       'De Gits':'OTHERS', 'Unieke BEN woningen':'OTHERS', 'Asperre (Papenhof2) - Won':'OTHERS',
       'Roggestraat':'OTHERS', 'Residentie Kapelleken':'OTHERS', 'De Stek Woningen':'OTHERS',
       '3 prachtige BEN-woningen':'OTHERS', 'Westdorp':'OTHERS',
       'Achterstraat 14, 8480 Eernegem':'OTHERS', 'Peterseliestraat Brugge -':'OTHERS',
       'LUX fase II_woningen':'OTHERS',
       'Peterseliestraat Brugge - Wonen langs de vestingen':'OTHERS',
       'Residentie Dockside Garde':'OTHERS', 'Woonerf Bachtekerkweg':'OTHERS', 'Townhouses':'OTHERS',
       'Woningen Rosalie':'OTHERS', 'Residentie Alex II':'OTHERS', 'Domaine du Fort':'OTHERS', '809':'OTHERS',
       'BEN-woningen te Herentals':'OTHERS',
       'Echte parkwoningen vlakbij centrum Tielt':'OTHERS', 
         "Woonproject te Paddenweg Lier - BEN woningen" :"OTHERS" 
                          }})
df.rename(columns={'Column1':'property-type'},inplace=True)
df.rename(columns={'Column2':'Location'},inplace=True)
df.rename(columns={'Column3':'Price'},inplace=True)
df.rename(columns={'Column4':'Area'},inplace=True)
df.rename(columns={'Column5':'Number_of_Rooms'},inplace=True)
df.rename(columns={'Column6':'Furnished'},inplace=True)
df.rename(columns={'Column7':'Kitchen type'},inplace=True)
df.rename(columns={'Column8':'Status'},inplace=True)
df.rename(columns={'Column9':'Garden surface'},inplace=True)
df.rename(columns={'Column10':'Swimming Pool'},inplace=True)
df = df.drop(0)
df = df.drop(df[df.Number_of_Rooms =='400 m² square meters livable space' ].index)
df = df.drop(df[df.Number_of_Rooms =='429 m² square meters livable spac' ].index)
df = df.drop(df[df.Number_of_Rooms =='275 m² square meters of land' ].index)
df = df.drop(df[df.Number_of_Rooms =='9 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='5 bathrooms' ].index)
df = df.drop(df[df.Number_of_Rooms =='2700 m² square meters of land' ].index)
df = df.drop(df[df.Number_of_Rooms =='141 m² square meters livable space' ].index)
df = df.drop(df[df.Number_of_Rooms =='306 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='200 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1440 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='44 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='249 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='435 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1440 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='633 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='360 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='388 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='367 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='763 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='312 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='150 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='500 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='9 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='509 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='429 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1362 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms=='77 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1436 m² square meters of land '].index)
df = df.drop(df[df.Number_of_Rooms =='550 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1436 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='409 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='6200 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1425 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='36 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='39 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='50 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='30 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='18 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='179 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='234 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='21 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2000 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1004 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='256 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='486 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='225 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='94 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='184 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='3 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2 - 3 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='140 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='13 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='12 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='14 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='3 - 5 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='17 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='16 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='1 bathroom'].index)
df = df.drop(df[df.Number_of_Rooms =='20 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='23 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='2 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='250 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='23 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='15 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='4 - 5 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='385 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='650 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='3 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='4 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='11 bedrooms  '].index)
df = df.drop(df[df.Number_of_Rooms =='96 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='875 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='75 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='252 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='350 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='750 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1 - 3 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='11 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='220 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='149 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='6 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2288 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='200050 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='Number_of_Rooms'].index)
df = df.drop(df[df.Number_of_Rooms =='270 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='218 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='507 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1038 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='305 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='700 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='22 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='295 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='28 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='715 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='21 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='280 m² square meters of land'].index)

df['Number_of_Rooms'] = df['Number_of_Rooms'].str.extract(r'(\d+)')
df = df.drop(df[df.Price =='€ 398,450'].index)
df = df.drop(df[df.Price =='€ 361,718'].index)
df = df.drop(df[df.Price =='€ 118,500'].index)
df = df.drop(df[df.Price =='€ 264,500'].index)
df = df.drop(df[df.Price =='€ 667,000'].index)
df = df.drop(df[df.Price =='€ 382,500'].index)
df = df.drop(df[df.Price =='€ 434,500'].index)
df = df.drop(df[df.Price =='€ 627,000'].index)
df = df.drop(df[df.Price =='€ 738,000'].index)
df = df.drop(df[df.Price =='€ 667,000'].index)
df = df.drop(df[df.Price =='€ 382,500'].index)
df = df.drop(df[df.Price =='€ 1,149'].index)
df = df.drop(df[df.Price =='€ 283,137'].index)
df = df.drop(df[df.Price =='€ 441,132'].index)
df = df.drop(df[df.Price =='€ 459,990'].index)
df = df.drop(df[df.Price =='€ 4,500'].index)
df = df.drop(df[df.Price =='€ 275,283'].index)
df = df.drop(df[df.Price =='€ 293,500'].index)
df = df.drop(df[df.Price =='€ 1,587'].index)
df = df.drop(df[df.Price =='€ 357,260'].index)
df = df.drop(df[df.Price =='€ 436,500'].index)
df = df.drop(df[df.Price =='€ 493,000'].index)
df = df.drop(df[df.Price =='€ 495,100'].index)
df = df.drop(df[df.Price =='€ 522,000'].index)
df = df.drop(df[df.Price =='€ 343,000'].index)
df = df.drop(df[df.Price =='€ 1,590'].index)
df = df.drop(df[df.Price =='€ 179,990'].index)
df = df.drop(df[df.Price =='€ 264,252'].index)
df = df.drop(df[df.Price =='€ 441,000'].index)
df = df.drop(df[df.Price =='€ 325,500'].index)
df = df.drop(df[df.Price =='€ 2,995'].index)
df = df.drop(df[df.Price =='€ 2,250'].index)
df = df.drop(df[df.Price =='€ 292,600'].index)
df = df.drop(df[df.Price =='€ 399,250'].index)
df = df.drop(df[df.Price =='€ 302,755'].index)
df = df.drop(df[df.Price =='€ 3,100'].index)
df = df.drop(df[df.Price =='€ 4,200'].index)
df = df.drop(df[df.Price =='€ 2,999'].index)
df = df.drop(df[df.Price =='€ 499,500'].index)
df = df.drop(df[df.Price =='€ 297,300'].index)
df = df.drop(df[df.Price =='€ 397,000'].index)
df = df.drop(df[df.Price =='€ 338,361'].index)
df = df.drop(df[df.Price =='€ 299,950'].index)
df = df.drop(df[df.Price =='€ 449,900'].index)
df = df.drop(df[df.Price =='€ 274,940'].index)
df = df.drop(df[df.Price =='€ 477,000'].index)
df = df.drop(df[df.Price =='€ 114,000'].index)
df = df.drop(df[df.Price =='€ 1,455'].index)
df = df.drop(df[df.Price =='€ 3,500'].index)
df = df.drop(df[df.Price =='€ 245,500 '].index)
df = df.drop(df[df.Price =='€ 288,000'].index)
df = df.drop(df[df.Price =='€ 281,436'].index)
df = df.drop(df[df.Price =='€ 356,877'].index)
df = df.drop(df[df.Price =='€ 509,000'].index)
df = df.drop(df[df.Price =='€ 245,500'].index)
df = df.drop(df[df.Price =='€ 934,000'].index)
df = df.drop(df[df.Price =='€ 618,000'].index)
df = df.drop(df[df.Price =='€ 383,500'].index)
df = df.drop(df[df.Price =='€ 349,900'].index)
df = df.drop(df[df.Price =='€ 189,999'].index)
df = df.drop(df[df.Price =='€ 1,198'].index)
df = df.drop(df[df.Price =='€ 694,000'].index)
df = df.drop(df[df.Price =='€ 674,500'].index)
df = df.drop(df[df.Price =='€ 399,500'].index)
df = df.drop(df[df.Price =='€ 177,500'].index)
df = df.drop(df[df.Price =='€ 336,500'].index)
df = df.drop(df[df.Price =='€ 244,048'].index)
df = df.drop(df[df.Price =='€ 1,620'].index)
df = df.drop(df[df.Price =='€ 1,599'].index)
df = df.drop(df[df.Price =='€ 138,000'].index)
df = df.drop(df[df.Price =='€ 280,700'].index)
df = df.drop(df[df.Price =='€ 260,100'].index)
df = df.drop(df[df.Price =='€ 237,800'].index)
df = df.drop(df[df.Price =='€ 169,900'].index)
df = df.drop(df[df.Price =='€ 121,000'].index)
df = df.drop(df[df.Price =='€ 352,500'].index)
df = df.drop(df[df.Price =='€ 314,836'].index)
df = df.drop(df[df.Price =='€ 447,000'].index)
df = df.drop(df[df.Price =='€ 682,000'].index)
df = df.drop(df[df.Price =='€ 261,000'].index)
df = df.drop(df[df.Price =='€ 344,500'].index)
df = df.drop(df[df.Price =='€ 266,200'].index)
df = df.drop(df[df.Price =='€ 419,900'].index)
df = df.drop(df[df.Price =='€ 258,000'].index)
df = df.drop(df[df.Price =='€ 364,173'].index)
df = df.drop(df[df.Price =='€ 377,000'].index)
df = df.drop(df[df.Price =='€ 467,500'].index)
df = df.drop(df[df.Price =='€ 561,200'].index)
df = df.drop(df[df.Price =='€ 674,900'].index)
df = df.drop(df[df.Price =='€ 361,599'].index)
df = df.drop(df[df.Price =='€ 239,900'].index)
df = df.drop(df[df.Price =='€ 156,800 '].index)
df = df.drop(df[df.Price =='€ 1,420'].index)
df = df.drop(df[df.Price =='€ 597,000'].index)
df = df.drop(df[df.Price =='€ 360,976'].index)
df = df.drop(df[df.Price =='€ 124,500'].index)
df = df.drop(df[df.Price =='€ 117,500'].index)
df = df.drop(df[df.Price =='€ 603,800'].index)
df = df.drop(df[df.Price =='€ 364,800'].index)
df = df.drop(df[df.Price =='€ 329,950'].index)
df = df.drop(df[df.Price =='€ 709,000'].index)
df = df.drop(df[df.Price =='€ 422,500'].index)
df = df.drop(df[df.Price =='€ 2,340'].index)
df = df.drop(df[df.Price =='€ 156,800'].index)
df = df.drop(df[df.Price =='€ 305,500'].index)
df = df.drop(df[df.Price =='€ 3,600'].index)
df = df.drop(df[df.Price =='€ 1,569'].index)
df = df.drop(df[df.Price =='€ 1,325'].index)
df = df.drop(df[df.Price =='€ 768,000'].index)
df = df.drop(df[df.Price =='€ 280,500'].index)
df = df.drop(df[df.Price =='€ 1,449'].index)
df = df.drop(df[df.Price =='€ 209,900'].index)
df = df.drop(df[df.Price =='€ 323,000'].index)
df = df.drop(df[df.Price =='€ 4,290'].index)
df = df.drop(df[df.Price =='€ 266,275'].index)
df = df.drop(df[df.Price =='€ 383,850'].index)
df = df.drop(df[df.Price =='€ 224,500'].index)
df = df.drop(df[df.Price =='€ 157,000'].index)
df = df.drop(df[df.Price =='€ 127,500'].index)
df = df.drop(df[df.Price =='€ 127,500'].index)
df = df.drop(df[df.Price =='€ 1,425'].index)
df = df.drop(df[df.Price =='€ 207,500'].index)
df = df.drop(df[df.Price =='€ 184,900'].index)
df = df.drop(df[df.Price =='€ 211,000'].index)
df = df.drop(df[df.Price =='€ 639,999'].index)
df = df.drop(df[df.Price =='€ 1,345'].index)
df = df.drop(df[df.Price =='€ 330,850'].index)
df = df.drop(df[df.Price =='€ 1,278'].index)
df = df.drop(df[df.Price =='€ 372,600'].index)
df = df.drop(df[df.Price =='€ 346,000'].index)
df = df.drop(df[df.Price =='€ 1,080'].index)
df = df.drop(df[df.Price =='€ 277,300'].index)
df = df.drop(df[df.Price =='€ 254,700'].index)
df = df.drop(df[df.Price =='€ 251,600'].index)
df = df.drop(df[df.Price =='€ 217,500'].index)
df = df.drop(df[df.Price =='€ 879,000'].index)
df = df.drop(df[df.Price =='€ 379,700'].index)
df = df.drop(df[df.Price =='€ 308,603'].index)
df = df.drop(df[df.Price =='€ 562,000'].index)
df = df.drop(df[df.Price =='€ 376,300'].index)
df = df.drop(df[df.Price =='€ 605,000'].index)
df = df.drop(df[df.Price =='€ 67,715'].index)
df = df.drop(df[df.Price =='€ 435,500'].index)
df = df.drop(df[df.Price =='€ 374,000'].index)
df = df.drop(df[df.Price =='€ 222,000'].index)
df = df.drop(df[df.Price =='€ 584,000'].index)
df = df.drop(df[df.Price =='€ 4,800'].index)
df = df.drop(df[df.Price =='€ 468,700'].index)
df = df.drop(df[df.Price =='€ 465,500'].index)
df = df.drop(df[df.Price =='€ 374,900'].index)
df = df.drop(df[df.Price =='€ 431,773'].index)
df = df.drop(df[df.Price =='€ 364,000'].index)
df = df.drop(df[df.Price =='€ 192,500'].index)
df = df.drop(df[df.Price =='€ 191,500'].index)
df = df.drop(df[df.Price =='€ 177,000'].index)
df = df.drop(df[df.Price =='€ 422,000'].index)
df = df.drop(df[df.Price =='€ 314,680'].index)
df = df.drop(df[df.Price =='€ 284,999'].index)
df = df.drop(df[df.Price =='€ 263,000'].index)
df = df.drop(df[df.Price =='€ 222,500'].index)
df = df.drop(df[df.Price =='€ 399,600'].index)
df = df.drop(df[df.Price =='€ 322,650'].index)
df = df.drop(df[df.Price =='€ 214,200'].index)
df = df.drop(df[df.Price =='€ 120,500'].index)
df = df.drop(df[df.Price =='€ 330,500'].index)
df = df.drop(df[df.Price =='€ 391,000'].index)
df = df.drop(df[df.Price =='€ 810,000'].index)
df = df.drop(df[df.Price =='€ 572,000'].index)
df = df.drop(df[df.Price =='€ 414,000'].index)
df = df.drop(df[df.Price =='€ 376,800'].index)
df = df.drop(df[df.Price =='€ 164,900'].index)
df = df.drop(df[df.Price =='€ 214,000'].index)
df = df.drop(df[df.Price =='€ 179,900'].index)
df = df.drop(df[df.Price =='€ 178,500'].index)
df = df.drop(df[df.Price =='€ 172,400'].index)
df = df.drop(df[df.Price =='€ 162,000'].index)
df = df.drop(df[df.Price =='€ 3,495'].index)
df = df.drop(df[df.Price =='€ 3,400'].index)
df = df.drop(df[df.Price =='€ 3,250'].index)
df = df.drop(df[df.Price =='€ 1,945'].index)
df = df.drop(df[df.Price =='€ 134,900'].index)
df = df.drop(df[df.Price =='€ 353,000'].index)
df = df.drop(df[df.Price =='€ 317,758'].index)
df = df.drop(df[df.Price =='€ 302,250'].index)
df = df.drop(df[df.Price =='€ 171,563'].index)
df = df.drop(df[df.Price =='€ 119,900'].index)
df = df.drop(df[df.Price =='€ 929,000'].index)
df = df.drop(df[df.Price =='€ 442,500'].index)
df = df.drop(df[df.Price =='€ 329,900'].index)
df = df.drop(df[df.Price =='€ 46,000'].index)
df = df.drop(df[df.Price =='€ 232,750'].index)
df = df.drop(df[df.Price =='€ 284,211'].index)
df = df.drop(df[df.Price =='€ 283,698'].index)
df = df.drop(df[df.Price =='€ 2,890'].index)
df = df.drop(df[df.Price =='€ 1,895'].index)
df = df.drop(df[df.Price =='€ 238,630'].index)
df = df.drop(df[df.Price =='€ 264,900'].index)
df = df.drop(df[df.Price =='€ 249,995'].index)
df = df.drop(df[df.Price =='€ 323,150'].index)
df = df.drop(df[df.Price =='€ 193,000'].index)
df = df.drop(df[df.Price =='€ 242,000'].index)
df = df.drop(df[df.Price =='€ 915,000'].index)
df = df.drop(df[df.Price =='€ 330,750'].index)
df = df.drop(df[df.Price =='€ 218,500'].index)
df = df.drop(df[df.Price =='€ 3,875'].index)
df = df.drop(df[df.Price =='€ 272,500'].index)
df = df.drop(df[df.Price =='€ 116,000'].index)
df = df.drop(df[df.Price =='€ 208,000'].index)
df = df.drop(df[df.Price =='€ 281,500'].index)
df = df.drop(df[df.Price =='€ 325,950'].index)
df = df.drop(df[df.Price =='€ 116,000'].index)
df = df.drop(df[df.Price =='€ 208,000'].index)
df = df.drop(df[df.Price =='€ 281,500'].index)
df = df.drop(df[df.Price =='€ 325,950'].index)
df = df.drop(df[df.Price =='€ 798,500'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 175500'].index)
df = df.drop(df[df.Price =='€ 117000'].index)
df = df.drop(df[df.Price =='€ 1770'].index)
df = df.drop(df[df.Price =='€ 4250'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 175500'].index)
df = df.drop(df[df.Price =='€ 117000'].index)
df = df.drop(df[df.Price =='€ 1770'].index)
df = df.drop(df[df.Price =='€ 4250'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 276,600 '].index)
df = df.drop(df[df.Price =='€ 175,500 '].index)
df = df.drop(df[df.Price =='€ 1,098'].index)
df = df.drop(df[df.Price =='€ 233,000'].index)
df = df.drop(df[df.Price =='€ 236,987'].index)
df = df.drop(df[df.Price =='€ 241,995'].index)
df = df.drop(df[df.Price =='€ 311,621'].index)
df = df.drop(df[df.Price =='€ 2,430'].index)
df = df.drop(df[df.Price =='€ 574,000'].index)
df = df.drop(df[df.Price =='€ 276,600'].index)
df = df.drop(df[df.Price =='€ 117,000'].index)
df = df.drop(df[df.Price =='€ 4,250'].index)
df = df.drop(df[df.Price =='€ 97,200'].index)
df = df.drop(df[df.Price =='€ 97,000'].index)
df = df.drop(df[df.Price =='€ 67,500'].index)
df = df.drop(df[df.Price =='€ 329,717'].index)
df = df.drop(df[df.Price =='€ 261,877'].index)
df = df.drop(df[df.Price =='€ 175,500'].index)
df = df.drop(df[df.Price =='€ 1,770'].index)


df = df.drop(df[df.Price =='€ 388,850'].index)
df = df.drop(df[df.Price =='€ 46,650'].index)
df = df.drop(df[df.Price =='€ 2,520'].index)
df = df.drop(df[df.Price =='€ 6,250'].index)
df = df.drop(df[df.Price =='€ 67,678'].index)
df = df.drop(df[df.Price =='€ 371,000'].index)
df = df.drop(df[df.Price =='€ 214,464'].index)
df = df.drop(df[df.Price =='€ 543,500'].index)
df = df.drop(df[df.Price =='€ 582,000'].index)

df = df.drop(df[df.Price =='€ 1,585'].index)
df = df.drop(df[df.Price =='€ 818,000'].index)
df = df.drop(df[df.Price =='€ 3,050'].index)
df = df.drop(df[df.Price =='€ 279,900'].index)
df = df.drop(df[df.Price =='€ 491,000'].index)
df = df.drop(df[df.Price =='€ 519,900'].index)

df = df.drop(df[df.Price =='€ 301,412'].index)
df = df.drop(df[df.Price =='€ 144,317'].index)
df = df.drop(df[df.Price =='€ 151,177'].index)
df = df.drop(df[df.Price =='€ 233,558'].index)
df = df.drop(df[df.Price =='€ 239,284'].index)
df = df.drop(df[df.Price =='€ 295,801'].index)
df = df.drop(df[df.Price =='€ 206,954'].index)
df = df.drop(df[df.Price =='€ 213,000'].index)
df = df.drop(df[df.Price =='€ 216,800'].index)
df = df.drop(df[df.Price =='€ 230,610'].index)
df = df.drop(df[df.Price =='€ 301,604'].index)
df = df.drop(df[df.Price =='€ 4,700'].index)
df = df.drop(df[df.Price =='€ 458,000'].index)
df = df.drop(df[df.Price =='€ 81,792'].index)
df = df.drop(df[df.Price =='€ 82,880'].index)
df = df.drop(df[df.Price =='€ 68,000'].index)
df = df.drop(df[df.Price =='€ 1,115'].index)
df = df.drop(df[df.Price =='€ 428,500'].index)
df = df.drop(df[df.Price =='€ 386,000'].index)
df = df.drop(df[df.Price =='€ 216,000'].index)

df = df.drop(df[df.Price =='€ 214,990'].index)
df = df.drop(df[df.Price =='€ 1,875'].index)
df = df.drop(df[df.Price =='€ 798,000'].index)
df = df.drop(df[df.Price =='€ 1,220'].index)
df = df.drop(df[df.Price =='€ 755,000'].index)
df = df.drop(df[df.Price =='€ 89,467'].index)
df = df.drop(df[df.Price =='€ 107,060'].index)
df = df.drop(df[df.Price =='€ 128,775'].index)
df = df.drop(df[df.Price =='€ 128,900'].index)
df = df.drop(df[df.Price =='€ 476,035'].index)
df = df.drop(df[df.Price =='€ 332,914'].index)
df = df.drop(df[df.Price =='€ 351,273'].index)
df = df.drop(df[df.Price =='€ 363,000'].index)
df = df.drop(df[df.Price =='€ 368,160'].index)

df = df.drop(df[df.Price =='€ 2,495'].index)
df = df.drop(df[df.Price =='€ 265,500'].index)
df = df.drop(df[df.Price =='€ 267,750'].index)
df = df.drop(df[df.Price =='€ 273,461'].index)
df = df.drop(df[df.Price =='€ 274,363'].index)
df = df.drop(df[df.Price =='€ 243,000'].index)
df = df.drop(df[df.Price =='€ 245,400'].index)
df = df.drop(df[df.Price =='€ 245,665'].index)
df = df.drop(df[df.Price =='€ 247,964'].index)
df = df.drop(df[df.Price =='€ 252,905'].index)
df = df.drop(df[df.Price =='€ 488,000'].index)
df = df.drop(df[df.Price =='€ 881,000'].index)
df = df.drop(df[df.Price =='€ 673,000'].index)
df = df.drop(df[df.Price =='€ 84,130'].index)
df = df.drop(df[df.Price =='€ 88,740'].index)
df = df.drop(df[df.Price =='€ 261,440'].index)
df = df.drop(df[df.Price =='€ 256,500'].index)
df = df.drop(df[df.Price =='€ 255,750'].index)
df = df.drop(df[df.Price =='€ 3,699'].index)
df = df.drop(df[df.Price =='€ 2,699'].index)

df = df.drop(df[df.Price =='€ 398,450'].index)
df = df.drop(df[df.Price =='€ 361,718'].index)
df = df.drop(df[df.Price =='€ 118,500'].index)
df = df.drop(df[df.Price =='€ 264,500'].index)
df = df.drop(df[df.Price =='€ 667,000'].index)
df = df.drop(df[df.Price =='€ 382,500'].index)
df = df.drop(df[df.Price =='€ 434,500'].index)
df = df.drop(df[df.Price =='€ 627,000'].index)
df = df.drop(df[df.Price =='€ 738,000'].index)
df = df.drop(df[df.Price =='€ 667,000'].index)
df = df.drop(df[df.Price =='€ 382,500'].index)
df = df.drop(df[df.Price =='€ 1,149'].index)
df = df.drop(df[df.Price =='€ 283,137'].index)
df = df.drop(df[df.Price =='€ 441,132'].index)
df = df.drop(df[df.Price =='€ 459,990'].index)
df = df.drop(df[df.Price =='€ 4,500'].index)
df = df.drop(df[df.Price =='€ 275,283'].index)
df = df.drop(df[df.Price =='€ 293,500'].index)
df = df.drop(df[df.Price =='€ 1,587'].index)
df = df.drop(df[df.Price =='€ 357,260'].index)
df = df.drop(df[df.Price =='€ 436,500'].index)
df = df.drop(df[df.Price =='€ 493,000'].index)
df = df.drop(df[df.Price =='€ 495,100'].index)
df = df.drop(df[df.Price =='€ 522,000'].index)
df = df.drop(df[df.Price =='€ 343,000'].index)
df = df.drop(df[df.Price =='€ 1,590'].index)
df = df.drop(df[df.Price =='€ 179,990'].index)
df = df.drop(df[df.Price =='€ 264,252'].index)
df = df.drop(df[df.Price =='€ 441,000'].index)
df = df.drop(df[df.Price =='€ 325,500'].index)
df = df.drop(df[df.Price =='€ 2,995'].index)
df = df.drop(df[df.Price =='€ 2,250'].index)
df = df.drop(df[df.Price =='€ 292,600'].index)
df = df.drop(df[df.Price =='€ 399,250'].index)
df = df.drop(df[df.Price =='€ 302,755'].index)
df = df.drop(df[df.Price =='€ 3,100'].index)
df = df.drop(df[df.Price =='€ 4,200'].index)
df = df.drop(df[df.Price =='€ 2,999'].index)
df = df.drop(df[df.Price =='€ 499,500'].index)
df = df.drop(df[df.Price =='€ 297,300'].index)
df = df.drop(df[df.Price =='€ 397,000'].index)
df = df.drop(df[df.Price =='€ 338,361'].index)
df = df.drop(df[df.Price =='€ 299,950'].index)
df = df.drop(df[df.Price =='€ 449,900'].index)
df = df.drop(df[df.Price =='€ 274,940'].index)
df = df.drop(df[df.Price =='€ 477,000'].index)
df = df.drop(df[df.Price =='€ 114,000'].index)
df = df.drop(df[df.Price =='€ 1,455'].index)
df = df.drop(df[df.Price =='€ 3,500'].index)
df = df.drop(df[df.Price =='€ 245,500 '].index)
df = df.drop(df[df.Price =='€ 288,000'].index)
df = df.drop(df[df.Price =='€ 281,436'].index)
df = df.drop(df[df.Price =='€ 356,877'].index)
df = df.drop(df[df.Price =='€ 509,000'].index)
df = df.drop(df[df.Price =='€ 245,500'].index)
df = df.drop(df[df.Price =='€ 934,000'].index)
df = df.drop(df[df.Price =='€ 618,000'].index)
df = df.drop(df[df.Price =='€ 383,500'].index)
df = df.drop(df[df.Price =='€ 349,900'].index)
df = df.drop(df[df.Price =='€ 189,999'].index)
df = df.drop(df[df.Price =='€ 1,198'].index)
df = df.drop(df[df.Price =='€ 694,000'].index)
df = df.drop(df[df.Price =='€ 674,500'].index)
df = df.drop(df[df.Price =='€ 399,500'].index)
df = df.drop(df[df.Price =='€ 177,500'].index)
df = df.drop(df[df.Price =='€ 336,500'].index)
df = df.drop(df[df.Price =='€ 244,048'].index)
df = df.drop(df[df.Price =='€ 1,620'].index)
df = df.drop(df[df.Price =='€ 1,599'].index)
df = df.drop(df[df.Price =='€ 138,000'].index)
df = df.drop(df[df.Price =='€ 280,700'].index)
df = df.drop(df[df.Price =='€ 260,100'].index)
df = df.drop(df[df.Price =='€ 237,800'].index)
df = df.drop(df[df.Price =='€ 169,900'].index)
df = df.drop(df[df.Price =='€ 121,000'].index)
df = df.drop(df[df.Price =='€ 352,500'].index)
df = df.drop(df[df.Price =='€ 314,836'].index)
df = df.drop(df[df.Price =='€ 447,000'].index)
df = df.drop(df[df.Price =='€ 682,000'].index)
df = df.drop(df[df.Price =='€ 261,000'].index)
df = df.drop(df[df.Price =='€ 344,500'].index)
df = df.drop(df[df.Price =='€ 266,200'].index)
df = df.drop(df[df.Price =='€ 419,900'].index)
df = df.drop(df[df.Price =='€ 258,000'].index)
df = df.drop(df[df.Price =='€ 364,173'].index)
df = df.drop(df[df.Price =='€ 377,000'].index)
df = df.drop(df[df.Price =='€ 467,500'].index)
df = df.drop(df[df.Price =='€ 561,200'].index)
df = df.drop(df[df.Price =='€ 674,900'].index)
df = df.drop(df[df.Price =='€ 361,599'].index)
df = df.drop(df[df.Price =='€ 239,900'].index)
df = df.drop(df[df.Price =='€ 156,800 '].index)
df = df.drop(df[df.Price =='€ 1,420'].index)
df = df.drop(df[df.Price =='€ 597,000'].index)
df = df.drop(df[df.Price =='€ 360,976'].index)
df = df.drop(df[df.Price =='€ 124,500'].index)
df = df.drop(df[df.Price =='€ 117,500'].index)
df = df.drop(df[df.Price =='€ 603,800'].index)
df = df.drop(df[df.Price =='€ 364,800'].index)
df = df.drop(df[df.Price =='€ 329,950'].index)
df = df.drop(df[df.Price =='€ 709,000'].index)
df = df.drop(df[df.Price =='€ 422,500'].index)
df = df.drop(df[df.Price =='€ 2,340'].index)
df = df.drop(df[df.Price =='€ 156,800'].index)
df = df.drop(df[df.Price =='€ 305,500'].index)
df = df.drop(df[df.Price =='€ 3,600'].index)
df = df.drop(df[df.Price =='€ 1,569'].index)
df = df.drop(df[df.Price =='€ 1,325'].index)
df = df.drop(df[df.Price =='€ 768,000'].index)
df = df.drop(df[df.Price =='€ 280,500'].index)
df = df.drop(df[df.Price =='€ 1,449'].index)
df = df.drop(df[df.Price =='€ 209,900'].index)
df = df.drop(df[df.Price =='€ 323,000'].index)
df = df.drop(df[df.Price =='€ 4,290'].index)
df = df.drop(df[df.Price =='€ 266,275'].index)
df = df.drop(df[df.Price =='€ 383,850'].index)
df = df.drop(df[df.Price =='€ 224,500'].index)
df = df.drop(df[df.Price =='€ 157,000'].index)
df = df.drop(df[df.Price =='€ 127,500'].index)
df = df.drop(df[df.Price =='€ 127,500'].index)
df = df.drop(df[df.Price =='€ 1,425'].index)
df = df.drop(df[df.Price =='€ 207,500'].index)
df = df.drop(df[df.Price =='€ 184,900'].index)
df = df.drop(df[df.Price =='€ 211,000'].index)
df = df.drop(df[df.Price =='€ 639,999'].index)
df = df.drop(df[df.Price =='€ 1,345'].index)
df = df.drop(df[df.Price =='€ 330,850'].index)
df = df.drop(df[df.Price =='€ 1,278'].index)
df = df.drop(df[df.Price =='€ 372,600'].index)
df = df.drop(df[df.Price =='€ 346,000'].index)
df = df.drop(df[df.Price =='€ 1,080'].index)
df = df.drop(df[df.Price =='€ 277,300'].index)
df = df.drop(df[df.Price =='€ 254,700'].index)
df = df.drop(df[df.Price =='€ 251,600'].index)
df = df.drop(df[df.Price =='€ 217,500'].index)
df = df.drop(df[df.Price =='€ 879,000'].index)
df = df.drop(df[df.Price =='€ 379,700'].index)
df = df.drop(df[df.Price =='€ 308,603'].index)
df = df.drop(df[df.Price =='€ 562,000'].index)
df = df.drop(df[df.Price =='€ 376,300'].index)
df = df.drop(df[df.Price =='€ 605,000'].index)
df = df.drop(df[df.Price =='€ 67,715'].index)
df = df.drop(df[df.Price =='€ 435,500'].index)
df = df.drop(df[df.Price =='€ 374,000'].index)
df = df.drop(df[df.Price =='€ 222,000'].index)
df = df.drop(df[df.Price =='€ 584,000'].index)
df = df.drop(df[df.Price =='€ 4,800'].index)
df = df.drop(df[df.Price =='€ 468,700'].index)
df = df.drop(df[df.Price =='€ 465,500'].index)
df = df.drop(df[df.Price =='€ 374,900'].index)
df = df.drop(df[df.Price =='€ 431,773'].index)
df = df.drop(df[df.Price =='€ 364,000'].index)
df = df.drop(df[df.Price =='€ 192,500'].index)
df = df.drop(df[df.Price =='€ 191,500'].index)
df = df.drop(df[df.Price =='€ 177,000'].index)
df = df.drop(df[df.Price =='€ 422,000'].index)
df = df.drop(df[df.Price =='€ 314,680'].index)
df = df.drop(df[df.Price =='€ 284,999'].index)
df = df.drop(df[df.Price =='€ 263,000'].index)
df = df.drop(df[df.Price =='€ 222,500'].index)
df = df.drop(df[df.Price =='€ 399,600'].index)
df = df.drop(df[df.Price =='€ 322,650'].index)
df = df.drop(df[df.Price =='€ 214,200'].index)
df = df.drop(df[df.Price =='€ 120,500'].index)
df = df.drop(df[df.Price =='€ 330,500'].index)
df = df.drop(df[df.Price =='€ 391,000'].index)
df = df.drop(df[df.Price =='€ 810,000'].index)
df = df.drop(df[df.Price =='€ 572,000'].index)
df = df.drop(df[df.Price =='€ 414,000'].index)
df = df.drop(df[df.Price =='€ 376,800'].index)
df = df.drop(df[df.Price =='€ 164,900'].index)
df = df.drop(df[df.Price =='€ 214,000'].index)
df = df.drop(df[df.Price =='€ 179,900'].index)
df = df.drop(df[df.Price =='€ 178,500'].index)
df = df.drop(df[df.Price =='€ 172,400'].index)
df = df.drop(df[df.Price =='€ 162,000'].index)
df = df.drop(df[df.Price =='€ 3,495'].index)
df = df.drop(df[df.Price =='€ 3,400'].index)
df = df.drop(df[df.Price =='€ 3,250'].index)
df = df.drop(df[df.Price =='€ 1,945'].index)
df = df.drop(df[df.Price =='€ 134,900'].index)
df = df.drop(df[df.Price =='€ 353,000'].index)
df = df.drop(df[df.Price =='€ 317,758'].index)
df = df.drop(df[df.Price =='€ 302,250'].index)
df = df.drop(df[df.Price =='€ 171,563'].index)
df = df.drop(df[df.Price =='€ 119,900'].index)
df = df.drop(df[df.Price =='€ 929,000'].index)
df = df.drop(df[df.Price =='€ 442,500'].index)
df = df.drop(df[df.Price =='€ 329,900'].index)
df = df.drop(df[df.Price =='€ 46,000'].index)
df = df.drop(df[df.Price =='€ 232,750'].index)
df = df.drop(df[df.Price =='€ 284,211'].index)
df = df.drop(df[df.Price =='€ 283,698'].index)
df = df.drop(df[df.Price =='€ 2,890'].index)
df = df.drop(df[df.Price =='€ 1,895'].index)
df = df.drop(df[df.Price =='€ 238,630'].index)
df = df.drop(df[df.Price =='€ 264,900'].index)
df = df.drop(df[df.Price =='€ 249,995'].index)
df = df.drop(df[df.Price =='€ 323,150'].index)
df = df.drop(df[df.Price =='€ 193,000'].index)
df = df.drop(df[df.Price =='€ 242,000'].index)
df = df.drop(df[df.Price =='€ 915,000'].index)
df = df.drop(df[df.Price =='€ 330,750'].index)
df = df.drop(df[df.Price =='€ 218,500'].index)
df = df.drop(df[df.Price =='€ 3,875'].index)
df = df.drop(df[df.Price =='€ 272,500'].index)
df = df.drop(df[df.Price =='€ 116,000'].index)
df = df.drop(df[df.Price =='€ 208,000'].index)
df = df.drop(df[df.Price =='€ 281,500'].index)
df = df.drop(df[df.Price =='€ 325,950'].index)
df = df.drop(df[df.Price =='€ 116,000'].index)
df = df.drop(df[df.Price =='€ 208,000'].index)
df = df.drop(df[df.Price =='€ 281,500'].index)
df = df.drop(df[df.Price =='€ 325,950'].index)
df = df.drop(df[df.Price =='€ 798,500'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 175500'].index)
df = df.drop(df[df.Price =='€ 117000'].index)
df = df.drop(df[df.Price =='€ 1770'].index)
df = df.drop(df[df.Price =='€ 4250'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 175500'].index)
df = df.drop(df[df.Price =='€ 117000'].index)
df = df.drop(df[df.Price =='€ 1770'].index)
df = df.drop(df[df.Price =='€ 4250'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 276,600 '].index)
df = df.drop(df[df.Price =='€ 175,500 '].index)
df = df.drop(df[df.Price =='€ 1,098'].index)
df = df.drop(df[df.Price =='€ 233,000'].index)
df = df.drop(df[df.Price =='€ 236,987'].index)
df = df.drop(df[df.Price =='€ 241,995'].index)
df = df.drop(df[df.Price =='€ 311,621'].index)
df = df.drop(df[df.Price =='€ 2,430'].index)
df = df.drop(df[df.Price =='€ 574,000'].index)
df = df.drop(df[df.Price =='€ 276,600'].index)
df = df.drop(df[df.Price =='€ 117,000'].index)
df = df.drop(df[df.Price =='€ 4,250'].index)
df = df.drop(df[df.Price =='€ 97,200'].index)
df = df.drop(df[df.Price =='€ 97,000'].index)
df = df.drop(df[df.Price =='€ 67,500'].index)
df = df.drop(df[df.Price =='€ 329,717'].index)
df = df.drop(df[df.Price =='€ 261,877'].index)
df = df.drop(df[df.Price =='€ 175,500'].index)
df = df.drop(df[df.Price =='€ 1,770'].index)

df = df.drop(df[df.Price =='€ 388,850'].index)
df = df.drop(df[df.Price =='€ 46,650'].index)
df = df.drop(df[df.Price =='€ 2,520'].index)
df = df.drop(df[df.Price =='€ 6,250'].index)
df = df.drop(df[df.Price =='€ 67,678'].index)
df = df.drop(df[df.Price =='€ 371,000'].index)
df = df.drop(df[df.Price =='€ 214,464'].index)
df = df.drop(df[df.Price =='€ 543,500'].index)
df = df.drop(df[df.Price =='€ 582,000'].index)

df = df.drop(df[df.Price =='€ 1,585'].index)
df = df.drop(df[df.Price =='€ 818,000'].index)
df = df.drop(df[df.Price =='€ 3,050'].index)
df = df.drop(df[df.Price =='€ 279,900'].index)
df = df.drop(df[df.Price =='€ 491,000'].index)
df = df.drop(df[df.Price =='€ 519,900'].index)

df = df.drop(df[df.Price =='€ 301,412'].index)
df = df.drop(df[df.Price =='€ 144,317'].index)
df = df.drop(df[df.Price =='€ 151,177'].index)
df = df.drop(df[df.Price =='€ 233,558'].index)
df = df.drop(df[df.Price =='€ 239,284'].index)
df = df.drop(df[df.Price =='€ 295,801'].index)
df = df.drop(df[df.Price =='€ 206,954'].index)
df = df.drop(df[df.Price =='€ 213,000'].index)
df = df.drop(df[df.Price =='€ 216,800'].index)
df = df.drop(df[df.Price =='€ 230,610'].index)
df = df.drop(df[df.Price =='€ 301,604'].index)
df = df.drop(df[df.Price =='€ 4,700'].index)
df = df.drop(df[df.Price =='€ 458,000'].index)
df = df.drop(df[df.Price =='€ 81,792'].index)
df = df.drop(df[df.Price =='€ 82,880'].index)
df = df.drop(df[df.Price =='€ 68,000'].index)
df = df.drop(df[df.Price =='€ 1,115'].index)
df = df.drop(df[df.Price =='€ 428,500'].index)
df = df.drop(df[df.Price =='€ 386,000'].index)
df = df.drop(df[df.Price =='€ 216,000'].index)

df = df.drop(df[df.Price =='€ 214,990'].index)
df = df.drop(df[df.Price =='€ 1,875'].index)
df = df.drop(df[df.Price =='€ 798,000'].index)
df = df.drop(df[df.Price =='€ 1,220'].index)
df = df.drop(df[df.Price =='€ 755,000'].index)
df = df.drop(df[df.Price =='€ 89,467'].index)
df = df.drop(df[df.Price =='€ 107,060'].index)
df = df.drop(df[df.Price =='€ 128,775'].index)
df = df.drop(df[df.Price =='€ 128,900'].index)
df = df.drop(df[df.Price =='€ 476,035'].index)
df = df.drop(df[df.Price =='€ 332,914'].index)
df = df.drop(df[df.Price =='€ 351,273'].index)
df = df.drop(df[df.Price =='€ 363,000'].index)
df = df.drop(df[df.Price =='€ 368,160'].index)

df = df.drop(df[df.Price =='€ 2,495'].index)
df = df.drop(df[df.Price =='€ 265,500'].index)
df = df.drop(df[df.Price =='€ 267,750'].index)
df = df.drop(df[df.Price =='€ 273,461'].index)
df = df.drop(df[df.Price =='€ 274,363'].index)
df = df.drop(df[df.Price =='€ 243,000'].index)
df = df.drop(df[df.Price =='€ 245,400'].index)
df = df.drop(df[df.Price =='€ 245,665'].index)
df = df.drop(df[df.Price =='€ 247,964'].index)
df = df.drop(df[df.Price =='€ 252,905'].index)
df = df.drop(df[df.Price =='€ 488,000'].index)
df = df.drop(df[df.Price =='€ 881,000'].index)
df = df.drop(df[df.Price =='€ 673,000'].index)
df = df.drop(df[df.Price =='€ 84,130'].index)
df = df.drop(df[df.Price =='€ 88,740'].index)
df = df.drop(df[df.Price =='€ 261,440'].index)
df = df.drop(df[df.Price =='€ 256,500'].index)
df = df.drop(df[df.Price =='€ 255,750'].index)
df = df.drop(df[df.Price =='€ 3,699'].index)
df = df.drop(df[df.Price =='€ 2,699'].index)
df = df.drop(df[df.Price =='€ 348,528'].index)
df = df.drop(df[df.Price =='€ 285,155'].index)
df = df.drop(df[df.Price =='€ 288,300'].index)
df = df.drop(df[df.Price =='€ 289,010'].index)
df = df.drop(df[df.Price =='€ 289,522'].index)
df = df.drop(df[df.Price =='€ 252,350'].index)
df = df.drop(df[df.Price =='€ 127,000'].index)
df = df.drop(df[df.Price =='€ 274,500'].index)
df = df.drop(df[df.Price =='€ 279,650'].index)
df = df.drop(df[df.Price =='€ 284,313'].index)
df = df.drop(df[df.Price =='€ 348,528'].index)
df = df.drop(df[df.Price =='€ 285,155'].index)
df = df.drop(df[df.Price =='€ 288,300'].index)
df = df.drop(df[df.Price =='€ 289,010'].index)
df = df.drop(df[df.Price =='€ 289,522'].index)
df = df.drop(df[df.Price =='€ 252,350'].index)
df = df.drop(df[df.Price =='€ 127,000'].index)
df = df.drop(df[df.Price =='€ 274,500'].index)
df = df.drop(df[df.Price =='€ 279,650'].index)
df = df.drop(df[df.Price =='€ 284,313'].index)
df = df.drop(df[df.Price =='€ 294,915'].index)
df = df.drop(df[df.Price =='€ 293,512'].index)
df = df.drop(df[df.Price =='€ 293,248'].index)
df = df.drop(df[df.Price =='€ 290,500'].index)
df = df.drop(df[df.Price =='€ 882,000'].index)

df = df.drop(df[df.Price =='€ 669,300'].index)
df = df.drop(df[df.Price =='€ 333,760'].index)
df = df.drop(df[df.Price =='€ 333,321'].index)
df = df.drop(df[df.Price =='€ 327,700'].index)
df = df.drop(df[df.Price =='€ 320,200'].index)
df = df.drop(df[df.Price =='€ 254,500'].index)
df = df.drop(df[df.Price =='€ 303,500'].index)
df = df.drop(df[df.Price =='€ 303,445'].index)
df = df.drop(df[df.Price =='€ 302,500'].index)
df = df.drop(df[df.Price =='€ 301,100'].index)
df = df.drop(df[df.Price =='€ 315,130'].index)
df = df.drop(df[df.Price =='€ 316,937'].index)
df = df.drop(df[df.Price =='€ 318,555'].index)
df = df.drop(df[df.Price =='€ 320,200 '].index)
df = df.drop(df[df.Price =='€ 338,000'].index)
df = df.drop(df[df.Price =='€ 329,624'].index)
df = df.drop(df[df.Price =='€ 330,928'].index)
df = df.drop(df[df.Price =='€ 332,277'].index)
df = df.drop(df[df.Price =='€ 332,852'].index)
df = df.drop(df[df.Price =='€ 299,999'].index)

df = df.drop(df[df.Price =='€ 370,435'].index)
df = df.drop(df[df.Price =='€ 352,855'].index)
df = df.drop(df[df.Price =='€ 351,500'].index)
df = df.drop(df[df.Price =='€ 349,050'].index)
df = df.drop(df[df.Price =='€ 348,871'].index)
df = df.drop(df[df.Price =='€ 275,200'].index)
df = df.drop(df[df.Price =='€ 347,196'].index)
df = df.drop(df[df.Price =='€ 146,000'].index)
df = df.drop(df[df.Price =='€ 340,256'].index)
df = df.drop(df[df.Price =='€ 336,852'].index)
df = df.drop(df[df.Price =='€ 36,000'].index)
df = df.drop(df[df.Price =='€ 318,578'].index)
df = df.drop(df[df.Price =='€ 207,000'].index)
df = df.drop(df[df.Price =='€ 284,450'].index)
df = df.drop(df[df.Price =='€ 498,850'].index)

df = df.drop(df[df.Price =='€ 441,805'].index)
df = df.drop(df[df.Price =='€ 408,999'].index)
df = df.drop(df[df.Price =='€ 403,000'].index)
df = df.drop(df[df.Price =='€ 398,346'].index)
df = df.drop(df[df.Price =='€ 389,990'].index)
df = df.drop(df[df.Price =='€ 187,000'].index)
df = df.drop(df[df.Price =='€ 365,800'].index)
df = df.drop(df[df.Price =='€ 360,900'].index)
df = df.drop(df[df.Price =='€ 358,939'].index)
df = df.drop(df[df.Price =='€ 335,387'].index)
df = df.drop(df[df.Price =='€ 247,500'].index)
df = df.drop(df[df.Price =='€ 356,000'].index)
df = df.drop(df[df.Price =='€ 354,643'].index)
df = df.drop(df[df.Price =='€ 354,413'].index)
df = df.drop(df[df.Price =='€ 347,698'].index)
df = df.drop(df[df.Price =='€ 349,300'].index)
df = df.drop(df[df.Price =='€ 313,599'].index)
df = df.drop(df[df.Price =='€ 307,343'].index)
df = df.drop(df[df.Price =='€ 306,447'].index)
df = df.drop(df[df.Price =='€ 296,845'].index)
df = df.drop(df[df.Price =='€ 374,571'].index)
df = df.drop(df[df.Price =='€ 417,240'].index)
df = df.drop(df[df.Price =='€ 417,685'].index)
df = df.drop(df[df.Price =='€ 462,788'].index)
df = df.drop(df[df.Price =='€ 1,435'].index)
df = df.drop(df[df.Price =='€ 369,675'].index)
df = df.drop(df[df.Price =='€ 1,169'].index)
df = df.drop(df[df.Price =='€ 161,000'].index)
df = df.drop(df[df.Price =='€ 167,000'].index)
df = df.drop(df[df.Price =='€ 305,127'].index)

df = df.drop(df[df.Price =='€ 739,000'].index)
df = df.drop(df[df.Price =='€ 330,346'].index)
df = df.drop(df[df.Price =='€ 327,440'].index)
df = df.drop(df[df.Price =='€ 320,039'].index)
df = df.drop(df[df.Price =='€ 314,576'].index)
df = df.drop(df[df.Price =='€ 789,000'].index)
df = df.drop(df[df.Price =='€ 263,147'].index)
df = df.drop(df[df.Price =='€ 1,999'].index)
df = df.drop(df[df.Price =='€ 391,200'].index)
df = df.drop(df[df.Price =='€ 216,500'].index)
df = df.drop(df[df.Price =='€ 472,788'].index)
df = df.drop(df[df.Price =='€ 494,972'].index)
df = df.drop(df[df.Price =='€ 498,067'].index)
df = df.drop(df[df.Price =='€ 1,015'].index)
df = df.drop(df[df.Price =='€ 325,601'].index)

df = df.drop(df[df.Price =='€ 349,296'].index)
df = df.drop(df[df.Price =='€ 122,000'].index)
df = df.drop(df[df.Price =='€ 538,071'].index)
df = df.drop(df[df.Price =='€ 335,458'].index)
df = df.drop(df[df.Price =='€ 332,458'].index)
df = df.drop(df[df.Price =='€ 304,997'].index)
df = df.drop(df[df.Price =='€ 295,825'].index)
df = df.drop(df[df.Price =='€ 291,968'].index)
df = df.drop(df[df.Price =='€ 345,750'].index)
df = df.drop(df[df.Price =='€ 689,000'].index)
df = df.drop(df[df.Price =='€ 476,000'].index)
df = df.drop(df[df.Price =='€ 1,525'].index)
df = df.drop(df[df.Price =='€ 307,000'].index)
df = df.drop(df[df.Price =='€ 14,500'].index)
df = df.drop(df[df.Price =='€ 2,375'].index)
df = df.drop(df[df.Price =='€ 339,325'].index)
df = df.drop(df[df.Price =='€ 1,290'].index)
df = df.drop(df[df.Price =='€ 341,493'].index)
df = df.drop(df[df.Price =='€ 348,217'].index)
df = df.drop(df[df.Price =='€ 292,528'].index)

df = df.drop(df[df.Price =='€ 407,364'].index)
df = df.drop(df[df.Price =='€ 988,000'].index)
df = df.drop(df[df.Price =='€ 497,650'].index)
df = df.drop(df[df.Price =='€ 456,000'].index)
df = df.drop(df[df.Price =='€ 344,000'].index)
df = df.drop(df[df.Price =='€ 370,250'].index)
df = df.drop(df[df.Price =='€ 219,950'].index)
df = df.drop(df[df.Price =='€ 432,309'].index)
df = df.drop(df[df.Price =='€ 398,500'].index)
df = df.drop(df[df.Price =='€ 2,095'].index)
df = df.drop(df[df.Price =='€ 137,500'].index)
df = df.drop(df[df.Price =='€ 592,450'].index)
df = df.drop(df[df.Price =='€ 235,500'].index)
df = df.drop(df[df.Price =='€ 228,530'].index)
df = df.drop(df[df.Price =='€ 528,000'].index)

df = df.drop(df[df.Price =='€ 4,850'].index)
df = df.drop(df[df.Price =='€ 623,000'].index)
df = df.drop(df[df.Price =='€ 349,850'].index)
df = df.drop(df[df.Price =='€ 331,950'].index)
df = df.drop(df[df.Price =='€ 1,985'].index)
df = df.drop(df[df.Price =='€ 2,190'].index)
df = df.drop(df[df.Price =='€ 147,500'].index)
df = df.drop(df[df.Price =='€ 319,926'].index)
df = df.drop(df[df.Price =='€ 267,500'].index)
df = df.drop(df[df.Price =='€ 509,500'].index)
df = df.drop(df[df.Price =='€ 898,000'].index)
df = df.drop(df[df.Price =='€ 2,480'].index)
df = df.drop(df[df.Price =='€ 998,000'].index)
df = df.drop(df[df.Price =='€ 224,900'].index)
df = df.drop(df[df.Price =='€ 192,000'].index)

df = df.drop(df[df.Price =='€ 251,016'].index)
df = df.drop(df[df.Price =='€ 330,816'].index)
df = df.drop(df[df.Price =='€ 165,239'].index)
df = df.drop(df[df.Price =='€ 162,500'].index)
df = df.drop(df[df.Price =='€ 134,000'].index)
df = df.drop(df[df.Price =='€ 1,285'].index)
df = df.drop(df[df.Price =='€ 27,500'].index)
df = df.drop(df[df.Price =='€ 27,500'].index)
df = df.drop(df[df.Price =='€ 459,500'].index)
df = df.drop(df[df.Price =='€ 84,000'].index)
df = df.drop(df[df.Price =='€ 723,500'].index)

df = df.drop(df[df.Price =='€ 281,698'].index)
df = df.drop(df[df.Price =='€ 5,825'].index)
df = df.drop(df[df.Price =='€ 5,250'].index)
df = df.drop(df[df.Price =='€ 2,740'].index)
df = df.drop(df[df.Price =='€ 338,800'].index)
df = df.drop(df[df.Price =='€ 174,500'].index)
df = df.drop(df[df.Price =='€ 124,000'].index)
df = df.drop(df[df.Price =='€ 167,500'].index)
df = df.drop(df[df.Price =='€ 59,900'].index)
df = df.drop(df[df.Price =='€ 314,001'].index)


df = df.drop(df[df.Price =='€ 289,900'].index)
df = df.drop(df[df.Price =='€ 339,500'].index)
df = df.drop(df[df.Price =='€ 357,500'].index)
df = df.drop(df[df.Price =='€ 426,454'].index)
df = df.drop(df[df.Price =='€ 134,500'].index)
df = df.drop(df[df.Price =='€ 328,500'].index)
df = df.drop(df[df.Price =='€ 396,000'].index)
df = df.drop(df[df.Price =='€ 136,500'].index)
df = df.drop(df[df.Price =='€ 371,900'].index)
df = df.drop(df[df.Price =='€ 907,500'].index)
df = df.drop(df[df.Price =='€ 108,535'].index)
df = df.drop(df[df.Price =='€ 1,045'].index)
df = df.drop(df[df.Price =='€ 614,000'].index)
df = df.drop(df[df.Price =='€ 581,000'].index)
df = df.drop(df[df.Price =='€ 183,000'].index)
df = df.drop(df[df.Price =='€ 518,000'].index)
df = df.drop(df[df.Price =='€ 388,800'].index)
df = df.drop(df[df.Price =='€ 488,051'].index)
df = df.drop(df[df.Price =='€ 502,700'].index)
df = df.drop(df[df.Price =='€ 383,800'].index)

df = df.drop(df[df.Price =='€ 2,000'].index)
df = df.drop(df[df.Price =='€ 3,700'].index)
df = df.drop(df[df.Price =='€ 393,000'].index)
df = df.drop(df[df.Price =='€ 103,000'].index)
df = df.drop(df[df.Price =='€ 417,930'].index)
df = df.drop(df[df.Price =='€ 32,000'].index)
df = df.drop(df[df.Price =='€ 722,000'].index)
df = df.drop(df[df.Price =='€ 697,500'].index)
df = df.drop(df[df.Price =='€ 258,500'].index)
df = df.drop(df[df.Price =='€ 74,900'].index)
df = df.drop(df[df.Price =='€ 497,400'].index)
df = df.drop(df[df.Price =='€ 141,385'].index)
df = df.drop(df[df.Price =='€ 313,000'].index)
df = df.drop(df[df.Price =='€ 129,800'].index)
df = df.drop(df[df.Price =='€ 429,500'].index)
df = df.drop(df[df.Price =='€ 441,141'].index)
df = df.drop(df[df.Price =='€ 431,816'].index)
df = df.drop(df[df.Price =='€ 693,600'].index)
df = df.drop(df[df.Price =='€ 651,100'].index)
df = df.drop(df[df.Price =='€ 156,000'].index)

df = df.drop(df[df.Price =='€ 331,785'].index)
df = df.drop(df[df.Price =='€ 93,000'].index)
df = df.drop(df[df.Price =='€ 285,975'].index)
df = df.drop(df[df.Price =='€ 229,669'].index)
df = df.drop(df[df.Price =='€ 157,500'].index)
df = df.drop(df[df.Price =='€ 361,347'].index)
df = df.drop(df[df.Price =='€ 163,000'].index)
df = df.drop(df[df.Price =='€ 173,000'].index)
df = df.drop(df[df.Price =='€ 494,000'].index)
df = df.drop(df[df.Price =='€ 322,291'].index)
df = df.drop(df[df.Price =='€ 296,607'].index)
df = df.drop(df[df.Price =='€ 362,989'].index)
df = df.drop(df[df.Price =='€ 361,499'].index)
df = df.drop(df[df.Price =='€ 361,260'].index)
df = df.drop(df[df.Price =='€ 337,500'].index)

df = df.drop(df[df.Price =='€ 276,075'].index)
df = df.drop(df[df.Price =='€ 291,000'].index)
df = df.drop(df[df.Price =='€ 256,932'].index)
df = df.drop(df[df.Price =='€ 346,500'].index)
df = df.drop(df[df.Price =='€ 232,247'].index)
df = df.drop(df[df.Price =='€ 670,000'].index)
df = df.drop(df[df.Price =='€ 139,999'].index)
df = df.drop(df[df.Price =='€ 72,200'].index)
df = df.drop(df[df.Price =='€ 439,900'].index)
df = df.drop(df[df.Price =='€ 255,087'].index)
df = df.drop(df[df.Price =='€ 569,600'].index)
df = df.drop(df[df.Price =='€ 328,210'].index)
df = df.drop(df[df.Price =='€ 234,900'].index)
df = df.drop(df[df.Price =='€ 342,866'].index)
df = df.drop(df[df.Price =='€ 398,900'].index)
df = df.drop(df[df.Price =='€ 387,500'].index)
df = df.drop(df[df.Price =='€ 215,244'].index)
df = df.drop(df[df.Price =='€ 56,000'].index)
df = df.drop(df[df.Price =='€ 307,867'].index)
df = df.drop(df[df.Price =='€ 668,000'].index)
df = df.drop(df[df.Price =='€ 55,000'].index)
df = df.drop(df[df.Price =='€ 341,000'].index)
df = df.drop(df[df.Price =='€ 356,257'].index)
df = df.drop(df[df.Price =='€ 464,000'].index)
df = df.drop(df[df.Price =='€ 310,846'].index)
df = df.drop(df[df.Price =='€ 1,125'].index)
df = df.drop(df[df.Price =='€ 1,240'].index)
df = df.drop(df[df.Price =='€ 379,386'].index)
df = df.drop(df[df.Price =='€ 386,466'].index)
df = df.drop(df[df.Price =='€ 504,300'].index)
df = df.drop(df[df.Price =='€ 461,272'].index)
df = df.drop(df[df.Price =='€ 89,900'].index)
df = df.drop(df[df.Price =='€ 688,000'].index)
df = df.drop(df[df.Price =='€ 1,399'].index)
df = df.drop(df[df.Price =='€ 351,800'].index)

df = df.drop(df[df.Price =='€ 278,500'].index)
df = df.drop(df[df.Price =='€ 537,000'].index)
df = df.drop(df[df.Price =='€ 1,374'].index)
df = df.drop(df[df.Price =='€ 445,750'].index)
df = df.drop(df[df.Price =='€ 1,075'].index)
df = df.drop(df[df.Price =='€ 443,000'].index)
df = df.drop(df[df.Price =='€ 447,100'].index)
df = df.drop(df[df.Price =='€ 453,816'].index)
df = df.drop(df[df.Price =='€ 383,100'].index)
df = df.drop(df[df.Price =='€ 378,800'].index)
df = df.drop(df[df.Price =='€ 424,000'].index)
df = df.drop(df[df.Price =='€ 1,430'].index)
df = df.drop(df[df.Price =='€ 106,900'].index)
df = df.drop(df[df.Price =='€ 129,900'].index)
df = df.drop(df[df.Price =='€ 448,000'].index)

df = df.drop(df[df.Price =='€ 354,000'].index)
df = df.drop(df[df.Price =='€ 271,500'].index)
df = df.drop(df[df.Price =='€ 214,500'].index)
df = df.drop(df[df.Price =='€ 199,999'].index)
df = df.drop(df[df.Price =='€ 147,000'].index)
df = df.drop(df[df.Price =='€ 634,500'].index)
df = df.drop(df[df.Price =='€ 206,000'].index)
df = df.drop(df[df.Price =='€ 349,560'].index)
df = df.drop(df[df.Price =='€ 331,200'].index)
df = df.drop(df[df.Price =='€ 313,500'].index)
df = df.drop(df[df.Price =='€ 280,443'].index)
df = df.drop(df[df.Price =='€ 437,692'].index)
df = df.drop(df[df.Price =='€ 368,800'].index)
df = df.drop(df[df.Price =='€ 849,999'].index)
df = df.drop(df[df.Price =='€ 338,744'].index)
df = df.drop(df[df.Price =='€ 594,500'].index)
df = df.drop(df[df.Price =='€ 612,800'].index)
df = df.drop(df[df.Price =='€ 108,000'].index)
df = df.drop(df[df.Price =='€ 300,500'].index)
df = df.drop(df[df.Price =='€ 333,181'].index)
df = df.drop(df[df.Price =='€ 338,215'].index)

df = df.drop(df[df.Price =='€ 340,400'].index)
df = df.drop(df[df.Price =='€ 184,500'].index)
df = df.drop(df[df.Price =='€ 1,049'].index)
df = df.drop(df[df.Price =='€ 939,000'].index)
df = df.drop(df[df.Price =='€ 267,000'].index)
df = df.drop(df[df.Price =='€ 368,324'].index)
df = df.drop(df[df.Price =='€ 314,000'].index)
df = df.drop(df[df.Price =='€ 45,000'].index)
df = df.drop(df[df.Price =='€ 2,900'].index)
df = df.drop(df[df.Price =='€ 6,650'].index)
df = df.drop(df[df.Price =='€ 829,000'].index)
df = df.drop(df[df.Price =='€ 370,882'].index)
df = df.drop(df[df.Price =='€ 321,000'].index)
df = df.drop(df[df.Price =='€ 299,995'].index)
df = df.drop(df[df.Price =='€ 354,000'].index)

df = df.drop(df[df.Price =='€ 2,985'].index)
df = df.drop(df[df.Price =='€ 94,000'].index)
df = df.drop(df[df.Price =='€ 436,000'].index)
df = df.drop(df[df.Price =='€ 182,000'].index)
df = df.drop(df[df.Price =='€ 3,690'].index)
df = df.drop(df[df.Price =='€ 342,000'].index)
df = df.drop(df[df.Price =='€ 274,000'].index)
df = df.drop(df[df.Price =='€ 485,700'].index)
df = df.drop(df[df.Price =='€ 463,400'].index)
df = df.drop(df[df.Price =='€ 399,900'].index)

df = df.drop(df[df.Price =='€ 795,500'].index)
df = df.drop(df[df.Price =='€ 3,450'].index)
df = df.drop(df[df.Price =='€ 1,940'].index)
df = df.drop(df[df.Price =='€ 154,500'].index)
df = df.drop(df[df.Price =='€ 1,785'].index)
df = df.drop(df[df.Price =='€ 39,000'].index)
df = df.drop(df[df.Price =='€ 327,500'].index)
df = df.drop(df[df.Price =='€ 710,000'].index)
df = df.drop(df[df.Price =='€ 364,900'].index)
df = df.drop(df[df.Price =='€ 365,700'].index)
df = df.drop(df[df.Price =='€ 1,480'].index)
df = df.drop(df[df.Price =='€ 3,850'].index)
df = df.drop(df[df.Price =='€ 255,500'].index)
df = df.drop(df[df.Price =='€ 2,145'].index)
df = df.drop(df[df.Price =='€ 1,990'].index)

df = df.drop(df[df.Price =='€ 79,500'].index)
df = df.drop(df[df.Price =='€ 448,500'].index)
df = df.drop(df[df.Price =='€ 286,000'].index)
df = df.drop(df[df.Price =='€ 196,000'].index)
df = df.drop(df[df.Price =='€ 387,000'].index)
df = df.drop(df[df.Price =='€ 889,000'].index)
df = df.drop(df[df.Price =='€ 2,399'].index)
df = df.drop(df[df.Price =='€ 999,500'].index)
df = df.drop(df[df.Price =='€ 69,000'].index)
df = df.drop(df[df.Price =='€ 411,000'].index)
df = df.drop(df[df.Price =='€ 256,000'].index)
df = df.drop(df[df.Price =='€ 588,000'].index)
df = df.drop(df[df.Price =='€ 697,000'].index)
df = df.drop(df[df.Price =='€ 20,000'].index)
df = df.drop(df[df.Price =='€ 154,000'].index)
df = df.drop(df[df.Price =='€ 1,820'].index)
df = df.drop(df[df.Price =='€ 252,000'].index)
df = df.drop(df[df.Price =='€ 1,249'].index)
df = df.drop(df[df.Price =='€ 99,500'].index)
df = df.drop(df[df.Price =='€ 15,000'].index)


df = df.drop(df[df.Price =='€ 132,000'].index)
df = df.drop(df[df.Price =='€ 779,000'].index)
df = df.drop(df[df.Price =='€ 865,000'].index)
df = df.drop(df[df.Price =='€ 303,000'].index)
df = df.drop(df[df.Price =='€ 232,948'].index)
df = df.drop(df[df.Price =='€ 1,575'].index)
df = df.drop(df[df.Price =='€ 171,000'].index)
df = df.drop(df[df.Price =='€ 277,000'].index)
df = df.drop(df[df.Price =='€ 482,000'].index)
df = df.drop(df[df.Price =='€ 344,630'].index)
df = df.drop(df[df.Price =='€ 1,060'].index)
df = df.drop(df[df.Price =='€ 444,500'].index)
df = df.drop(df[df.Price =='€ 329,500'].index)
df = df.drop(df[df.Price =='€ 277,500'].index)
df = df.drop(df[df.Price =='€ 3,380'].index)
df = df.drop(df[df.Price =='€ 287,000'].index)
df = df.drop(df[df.Price =='€ 282,500'].index)
df = df.drop(df[df.Price =='€ 1,370'].index)
df = df.drop(df[df.Price =='€ 412,000'].index)
df = df.drop(df[df.Price =='€ 999,000'].index)

df = df.drop(df[df.Price =='€ 149,500'].index)
df = df.drop(df[df.Price =='€ 332,000'].index)
df = df.drop(df[df.Price =='€ 1,645'].index)
df = df.drop(df[df.Price =='€ 249,950'].index)
df = df.drop(df[df.Price =='€ 122,500'].index)
df = df.drop(df[df.Price =='€ 69,500'].index)
df = df.drop(df[df.Price =='€ 357,000'].index)
df = df.drop(df[df.Price =='€ 1,140'].index)
df = df.drop(df[df.Price =='€ 133,000'].index)
df = df.drop(df[df.Price =='€ 269,500'].index)
df = df.drop(df[df.Price =='€ 10,000'].index)
df = df.drop(df[df.Price =='€ 648,000'].index)
df = df.drop(df[df.Price =='€ 478,000'].index)
df = df.drop(df[df.Price =='€ 474,000'].index)
df = df.drop(df[df.Price =='€ 118,000'].index)
df = df.drop(df[df.Price =='€ 1,920'].index)
df = df.drop(df[df.Price =='€ 419,893'].index)
df = df.drop(df[df.Price =='€ 89,500'].index)
df = df.drop(df[df.Price =='€ 352,000'].index)
df = df.drop(df[df.Price =='€ 249,750'].index)
df = df.drop(df[df.Price =='€ 2,990'].index)
df = df.drop(df[df.Price =='€ 232,000'].index)
df = df.drop(df[df.Price =='€ 333,000'].index)
df = df.drop(df[df.Price =='€ 272,000'].index)
df = df.drop(df[df.Price =='€ 339,900'].index)
df = df.drop(df[df.Price =='€ 159,169'].index)
df = df.drop(df[df.Price =='€ 227,000'].index)
df = df.drop(df[df.Price =='€ 276,000'].index)
df = df.drop(df[df.Price =='€ 292,500'].index)
df = df.drop(df[df.Price =='€ 317,500'].index)
df = df.drop(df[df.Price =='€ 483,000'].index)
df = df.drop(df[df.Price =='€ 342,785'].index)
df = df.drop(df[df.Price =='€ 345,900'].index)
df = df.drop(df[df.Price =='€ 347,000'].index)
df = df.drop(df[df.Price =='€ 2,817'].index)
df = df.drop(df[df.Price =='€ 337,000'].index)

df = df.drop(df[df.Price =='€ 142,000'].index)
df = df.drop(df[df.Price =='€ 328,000'].index)
df = df.drop(df[df.Price =='€ 678,000'].index)
df = df.drop(df[df.Price =='€ 237,500'].index)
df = df.drop(df[df.Price =='€ 109,900'].index)
df = df.drop(df[df.Price =='€ 136,000'].index)
df = df.drop(df[df.Price =='€ 660,000'].index)
df = df.drop(df[df.Price =='€ 144,000'].index)
df = df.drop(df[df.Price =='€ 309,500'].index)
df = df.drop(df[df.Price =='€ 144,000'].index)
df = df.drop(df[df.Price =='€ 660,000'].index)
df = df.drop(df[df.Price =='€ 423,500'].index)
df = df.drop(df[df.Price =='€ 291,328'].index)
df = df.drop(df[df.Price =='€ 291,328'].index)
df = df.drop(df[df.Price =='€ 297,348'].index)
df = df.drop(df[df.Price =='€ 202,000'].index)
df = df.drop(df[df.Price =='€ 262,000'].index)
df = df.drop(df[df.Price =='€ 1,299'].index)
df = df.drop(df[df.Price =='€ 1,065'].index)
df = df.drop(df[df.Price =='€ 340,347'].index)
df = df.drop(df[df.Price =='€ 835,000'].index)
df = df.drop(df[df.Price =='€ 295,500'].index)
df = df.drop(df[df.Price =='€ 512,000'].index)
df = df.drop(df[df.Price =='€ 2,249'].index)
df = df.drop(df[df.Price =='€ 5,850'].index)
df = df.drop(df[df.Price =='€ 559,000'].index)
df = df.drop(df[df.Price =='€ 1,255'].index)
df = df.drop(df[df.Price =='€ 367,000'].index)
df = df.drop(df[df.Price =='€ 253,000'].index)
df = df.drop(df[df.Price =='€ 166,000'].index)
df = df.drop(df[df.Price =='€ 2,685'].index)
df = df.drop(df[df.Price =='€ 253,740'].index)
df = df.drop(df[df.Price =='€ 322,000'].index)
df = df.drop(df[df.Price =='€ 492,000'].index)
df = df.drop(df[df.Price =='€ 424,450'].index)
df = df.drop(df[df.Price =='€ 262,500'].index)
df = df.drop(df[df.Price =='€ 9,500'].index)
df = df.drop(df[df.Price =='€ 830,000'].index)
df = df.drop(df[df.Price =='€ 336,000'].index)
df = df.drop(df[df.Price =='€ 332,410'].index)
df = df.drop(df[df.Price =='€ 433,000'].index)
df = df.drop(df[df.Price =='€ 358,500'].index)
df = df.drop(df[df.Price =='€ 362,500'].index)
df = df.drop(df[df.Price =='€ 2,850'].index)
df = df.drop(df[df.Price =='€ 5,500'].index)
df = df.drop(df[df.Price =='€ 2,650'].index)
df = df.drop(df[df.Price =='€ 1,280'].index)

df = df.drop(df[df.Price =='€ 2,280'].index)
df = df.drop(df[df.Price =='€ 257,500'].index)
df = df.drop(df[df.Price =='€ 620,000'].index)
df = df.drop(df[df.Price =='€ 88,000'].index)
df = df.drop(df[df.Price =='€ 364,300'].index)
df = df.drop(df[df.Price =='€ 99,900'].index)
df = df.drop(df[df.Price =='€ 284,000'].index)
df = df.drop(df[df.Price =='€ 497,000'].index)
df = df.drop(df[df.Price =='€ 1,275'].index)
df = df.drop(df[df.Price =='€ 128,000'].index)
df = df.drop(df[df.Price =='€ 3,750'].index)
df = df.drop(df[df.Price =='€ 49,000'].index)
df = df.drop(df[df.Price =='€ 169,500'].index)
df = df.drop(df[df.Price =='€ 679,000'].index)
df = df.drop(df[df.Price =='€ 2,975'].index)
df = df.drop(df[df.Price =='€ 209,500'].index)
df = df.drop(df[df.Price =='€ 434,000'].index)
df = df.drop(df[df.Price =='€ 1,890'].index)
df = df.drop(df[df.Price =='€ 644,500'].index)
df = df.drop(df[df.Price =='€ 1,165'].index)
df = df.drop(df[df.Price =='€ 353,050'].index)
df = df.drop(df[df.Price =='€ 497,500'].index)
df = df.drop(df[df.Price =='€ 164,500'].index)
df = df.drop(df[df.Price =='€ 197,000'].index)
df = df.drop(df[df.Price =='€ 119,500'].index)
df = df.drop(df[df.Price =='€ 815,000'].index)
df = df.drop(df[df.Price =='€ 559,500'].index)
df = df.drop(df[df.Price =='€ 707,645'].index)
df = df.drop(df[df.Price =='€ 296,000'].index)
df = df.drop(df[df.Price =='€ 408,000'].index)

df = df.drop(df[df.Price =='€ 2,400'].index)
df = df.drop(df[df.Price =='€ 168,000'].index)
df = df.drop(df[df.Price =='€ 4,350'].index)
df = df.drop(df[df.Price =='€ 59,000'].index)
df = df.drop(df[df.Price =='€ 428,000'].index)
df = df.drop(df[df.Price =='€ 1,800'].index)
df = df.drop(df[df.Price =='€ 2,275'].index)
df = df.drop(df[df.Price =='€ 282,000'].index)
df = df.drop(df[df.Price =='€ 378,000'].index)
df = df.drop(df[df.Price =='€ 580,953'].index)
df = df.drop(df[df.Price =='€ 595,400'].index)
df = df.drop(df[df.Price =='€ 870,000'].index)
df = df.drop(df[df.Price =='€ 639,000'].index)
df = df.drop(df[df.Price =='€ 376,700'].index)
df = df.drop(df[df.Price =='€ 1,790'].index)



df = df.drop(df[df.Price =='€ 293,250'].index)
df = df.drop(df[df.Price =='€ 194,900'].index)
df = df.drop(df[df.Price =='€ 2,490'].index)
df = df.drop(df[df.Price =='€ 359,500'].index)
df = df.drop(df[df.Price =='€ 1,145'].index)
df = df.drop(df[df.Price =='€ 748,000'].index)
df = df.drop(df[df.Price =='€ 388,000'].index)
df = df.drop(df[df.Price =='€ 885,000'].index)
df = df.drop(df[df.Price =='€ 820,000'].index)
df = df.drop(df[df.Price =='€ 266,000'].index)
df = df.drop(df[df.Price =='€ 219,500'].index)
df = df.drop(df[df.Price =='€ 384,000'].index)
df = df.drop(df[df.Price =='€ 3,150'].index)
df = df.drop(df[df.Price =='€ 112,000'].index)
df = df.drop(df[df.Price =='€ 759,000'].index)

df = df.drop(df[df.Price =='€ 1,390'].index)
df = df.drop(df[df.Price =='€ 347,500'].index)
df = df.drop(df[df.Price =='€ 287,500'].index)
df = df.drop(df[df.Price =='€ 1,180'].index)
df = df.drop(df[df.Price =='€ 780,000'].index)
df = df.drop(df[df.Price =='€ 404,600'].index)
df = df.drop(df[df.Price =='€ 245,748'].index)
df = df.drop(df[df.Price =='€ 139,900'].index)
df = df.drop(df[df.Price =='€ 244,000'].index)
df = df.drop(df[df.Price =='€ 392,110'].index)
df = df.drop(df[df.Price =='€ 630,000'].index)
df = df.drop(df[df.Price =='€ 1,245'].index)
df = df.drop(df[df.Price =='€ 2,295'].index)
df = df.drop(df[df.Price =='€ 990,000'].index)
df = df.drop(df[df.Price =='€ 1,190'].index)
df = df.drop(df[df.Price =='€ 555,000'].index)
df = df.drop(df[df.Price =='€ 297,500'].index)
df = df.drop(df[df.Price =='€ 178,000'].index)
df = df.drop(df[df.Price =='€ 372,000'].index)
df = df.drop(df[df.Price =='€ 129,500'].index)

df = df.drop(df[df.Price =='€ 249,900'].index)
df = df.drop(df[df.Price =='€ 35,000'].index)
df = df.drop(df[df.Price =='€ 139,500'].index)
df = df.drop(df[df.Price =='€ 218,000'].index)
df = df.drop(df[df.Price =='€ 1,680'].index)
df = df.drop(df[df.Price =='€ 409,000'].index)
df = df.drop(df[df.Price =='€ 292,000'].index)
df = df.drop(df[df.Price =='€ 392,000'].index)
df = df.drop(df[df.Price =='€ 1,085'].index)
df = df.drop(df[df.Price =='€ 985,000'].index)
df = df.drop(df[df.Price =='€ 239,500'].index)
df = df.drop(df[df.Price =='€ 1,225'].index)
df = df.drop(df[df.Price =='€ 318,000'].index)
df = df.drop(df[df.Price =='€ 910,000'].index)
df = df.drop(df[df.Price =='€ 259,900'].index)


df = df.drop(df[df.Price =='€ 289,500'].index)
df = df.drop(df[df.Price =='€ 229,900'].index)
df = df.drop(df[df.Price =='€ 199,900'].index)
df = df.drop(df[df.Price =='€ 1,199'].index)
df = df.drop(df[df.Price =='€ 212,000'].index)
df = df.drop(df[df.Price =='€ 79,000'].index)
df = df.drop(df[df.Price =='€ 137,000'].index)
df = df.drop(df[df.Price =='€ 1,185'].index)
df = df.drop(df[df.Price =='€ 1,375'].index)
df = df.drop(df[df.Price =='€ 1,980'].index)

df = df.drop(df[df.Price =='€ 2,200'].index)
df = df.drop(df[df.Price =='€ 2,300'].index)
df = df.drop(df[df.Price =='€ 1,700'].index)
df = df.drop(df[df.Price =='€ 405,000'].index)
df = df.drop(df[df.Price =='€ 299,900'].index)
df = df.drop(df[df.Price =='€ 394,400'].index)
df = df.drop(df[df.Price =='€ 394,000'].index)
df = df.drop(df[df.Price =='€ 569,000'].index)
df = df.drop(df[df.Price =='€ 331,000'].index)
df = df.drop(df[df.Price =='€ 159,500'].index)
df = df.drop(df[df.Price =='€ 920,000'].index)
df = df.drop(df[df.Price =='€ 1,380'].index)
df = df.drop(df[df.Price =='€ 467,000'].index)
df = df.drop(df[df.Price =='€ 294,500'].index)
df = df.drop(df[df.Price =='€ 159,50'].index)
df = df.drop(df[df.Price =='€ 1,300'].index)
df = df.drop(df[df.Price =='€ 334,000'].index)
df = df.drop(df[df.Price =='€ 228,000'].index)
df = df.drop(df[df.Price =='€ 184,000'].index)
df = df.drop(df[df.Price =='€ 770,000'].index)

df = df.drop(df[df.Price =='€ 1,690'].index)
df = df.drop(df[df.Price =='€ 880,000'].index)
df = df.drop(df[df.Price =='€ 294,000'].index)
df = df.drop(df[df.Price =='€ 860,000'].index)
df = df.drop(df[df.Price =='€ 1,600'].index)
df = df.drop(df[df.Price =='€ 589,000'].index)
df = df.drop(df[df.Price =='€ 349,500'].index)
df = df.drop(df[df.Price =='€ 540,000'].index)
df = df.drop(df[df.Price =='€ 548,000'].index)
df = df.drop(df[df.Price =='€ 610,000'].index)
df = df.drop(df[df.Price =='€ 1,995'].index)
df = df.drop(df[df.Price =='€ 316,000'].index)
df = df.drop(df[df.Price =='€ 257,000'].index)
df = df.drop(df[df.Price =='€ 247,000'].index)
df = df.drop(df[df.Price =='€ 1,900'].index)

df = df.drop(df[df.Price =='€ 669,000'].index)
df = df.drop(df[df.Price =='€ 539,000'].index)
df = df.drop(df[df.Price =='€ 3,950'].index)
df = df.drop(df[df.Price =='€ 3,900'].index)
df = df.drop(df[df.Price =='€ 158,000'].index)
df = df.drop(df[df.Price =='€ 669,000 '].index)
df = df.drop(df[df.Price =='€ 3,300'].index)
df = df.drop(df[df.Price =='€ 406,000'].index)
df = df.drop(df[df.Price =='€ 659,000'].index)
df = df.drop(df[df.Price =='€ 1,695'].index)
df = df.drop(df[df.Price =='€ 268,000'].index)
df = df.drop(df[df.Price =='€ 680,000'].index)
df = df.drop(df[df.Price =='€ 25,000'].index)
df = df.drop(df[df.Price =='€ 259,500'].index)
df = df.drop(df[df.Price =='€ 189,900'].index)
df = df.drop(df[df.Price ==''].index)
df = df.drop(df[df.Price ==''].index)

df = df.drop(df[df.Price =='€ 530,000'].index)
df = df.drop(df[df.Price =='€ 730,000'].index)
df = df.drop(df[df.Price =='€ 1,000'].index)
df = df.drop(df[df.Price =='€ 2,800'].index)
df = df.drop(df[df.Price =='€ 629,000'].index)
df = df.drop(df[df.Price =='€ 1,975'].index)
df = df.drop(df[df.Price =='€ 149,900'].index)
df = df.drop(df[df.Price =='€ 299,500'].index)
df = df.drop(df[df.Price =='€ 1,499'].index)
df = df.drop(df[df.Price =='€ 174,000'].index)
df = df.drop(df[df.Price =='€ 224,000'].index)
df = df.drop(df[df.Price =='€ 358,000'].index)
df = df.drop(df[df.Price =='€ 945,000'].index)
df = df.drop(df[df.Price =='€ 935,000'].index)
df = df.drop(df[df.Price =='€ 1,175'].index)

df = df.drop(df[df.Price =='€ 283,000'].index)
df = df.drop(df[df.Price =='€ 819,000'].index)
df = df.drop(df[df.Price =='€ 1,200'].index)
df = df.drop(df[df.Price =='€ 1,090'].index)
df = df.drop(df[df.Price =='€ 397,500'].index)
df = df.drop(df[df.Price =='€ 698,000'].index)
df = df.drop(df[df.Price =='€ 2,600'].index)
df = df.drop(df[df.Price =='€ 1,550'].index)
df = df.drop(df[df.Price =='€ 900,000'].index)
df = df.drop(df[df.Price =='€ 234,000'].index)
df = df.drop(df[df.Price =='€ 949,000'].index)
df = df.drop(df[df.Price =='€ 30,000'].index)
df = df.drop(df[df.Price =='€ 40,000'].index)
df = df.drop(df[df.Price =='€ 1,795'].index)
df = df.drop(df[df.Price =='€ 899,000'].index)
df = df.drop(df[df.Price =='€ 248,000'].index)
df = df.drop(df[df.Price =='€ 279,500'].index)
df = df.drop(df[df.Price =='€ 972,000'].index)
df = df.drop(df[df.Price =='€ 324,000'].index)
df = df.drop(df[df.Price =='€ 640,000'].index)
df = df.drop(df[df.Price =='€ 510,000'].index)
df = df.drop(df[df.Price =='€ 500,000'].index)
df = df.drop(df[df.Price =='€ 735,000'].index)
df = df.drop(df[df.Price =='€ 498,000'].index)
df = df.drop(df[df.Price =='€ 849,000'].index)
df = df.drop(df[df.Price =='€ 560,000'].index)
df = df.drop(df[df.Price =='€ 715,000'].index)
df = df.drop(df[df.Price =='€ 765,000'].index)
df = df.drop(df[df.Price =='€ 800,000'].index)
df = df.drop(df[df.Price =='€ 189,500'].index)
df = df.drop(df[df.Price =='€ 237,000'].index)

df = df.drop(df[df.Price =='€ 2,950'].index)
df = df.drop(df[df.Price =='€ 665,000'].index)
df = df.drop(df[df.Price =='€ 519,000'].index)
df = df.drop(df[df.Price =='€ 238,000'].index)
df = df.drop(df[df.Price =='€ 2,350'].index)
df = df.drop(df[df.Price =='€ 2,450'].index)
df = df.drop(df[df.Price =='€ 297,000'].index)
df = df.drop(df[df.Price =='€ 229,500'].index)
df = df.drop(df[df.Price =='€ 3,200'].index)
df = df.drop(df[df.Price =='€ 1,750'].index)
df = df.drop(df[df.Price =='€ 199,500'].index)
df = df.drop(df[df.Price =='€ 440,000'].index)
df = df.drop(df[df.Price =='€ 438,000'].index)
df = df.drop(df[df.Price =='€ 2,500'].index)
df = df.drop(df[df.Price =='€ 455,000'].index)

df = df.drop(df[df.Price =='€ 685,000'].index)
df = df.drop(df[df.Price =='€ 179,500'].index)
df = df.drop(df[df.Price =='€ 4,950'].index)
df = df.drop(df[df.Price =='€ 580,000'].index)
df = df.drop(df[df.Price =='€ 368,000'].index)
df = df.drop(df[df.Price =='€ 50,000'].index)
df = df.drop(df[df.Price =='€ 615,000'].index)
df = df.drop(df[df.Price =='€ 298,000'].index)
df = df.drop(df[df.Price =='€ 749,000'].index)
df = df.drop(df[df.Price =='€ 278,000'].index)
df = df.drop(df[df.Price =='€ 875,000'].index)
df = df.drop(df[df.Price =='€ 198,000'].index)
df = df.drop(df[df.Price =='€ 700,000'].index)
df = df.drop(df[df.Price =='€ 825,000'].index)
df = df.drop(df[df.Price =='€ 579,000'].index)
df = df.drop(df[df.Price =='€ 975,000'].index)
df = df.drop(df[df.Price =='€ 459,000'].index)
df = df.drop(df[df.Price =='€ 249,500'].index)
df = df.drop(df[df.Price =='€ 598,000'].index)
df = df.drop(df[df.Price =='€ 890,000'].index)
df = df.drop(df[df.Price =='€ 60,000'].index)
df = df.drop(df[df.Price =='€ 89,000'].index)
df = df.drop(df[df.Price =='€ 65,000'].index)
df = df.drop(df[df.Price =='€ 1,400'].index)
df = df.drop(df[df.Price =='€ 1,095'].index)

df = df.drop(df[df.Price =='€ 398,000'].index)
df = df.drop(df[df.Price =='€ 205,000'].index)
df = df.drop(df[df.Price =='€ 2,750'].index)
df = df.drop(df[df.Price =='€ 535,000'].index)
df = df.drop(df[df.Price =='€ 799,000'].index)
df = df.drop(df[df.Price =='€ 720,000'].index)
df = df.drop(df[df.Price =='€ 925,000'].index)
df = df.drop(df[df.Price =='€ 845,000'].index)
df = df.drop(df[df.Price =='€ 1,950'].index)
df = df.drop(df[df.Price =='€ 309,000'].index)
df = df.drop(df[df.Price =='€ 1,500'].index)
df = df.drop(df[df.Price =='€ 1,395'].index)
df = df.drop(df[df.Price =='€ 348,000'].index)
df = df.drop(df[df.Price =='€ 1,775'].index)
df = df.drop(df[df.Price =='€ 529,000'].index)
df = df.drop(df[df.Price =='€ 1,850'].index)
df = df.drop(df[df.Price =='€ 70,000'].index)
df = df.drop(df[df.Price =='€ 590,000'].index)
df = df.drop(df[df.Price =='€ 745,000'].index)
df = df.drop(df[df.Price =='€ 479,000'].index)
df['Price'] = df['Price'].apply(lambda x: x.replace('€', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
df=pd.read_csv('C:\\Users\\masrra\Desktop\data2.csv')
df=df.replace({'Column1':{'Mansion for sale':'OTHERS',
'Penthouse for sale' :'OTHERS',
'Villa for sale':'OTHERS',
'Quartier du Bailou - Maisons' : 'OTHERS',
'Bungalow for sale' :'OTHERS',
 "'t Groenehof":'OTHERS',
'Mixed-use building for sale':'OTHERS',
'Exceptional property for sale':'OTHERS',
'Town-house for sale':'OTHERS',
'Exceptional property for sale':'OTHERS',
'Maisons Arborescence':'OTHERS',
'Maisons neuves à vendre à':'OTHERS',
'Farmhouse for sale':'OTHERS',
'Leuze - Centre ville':'OTHERS',
'TONGRE NOTRE DAME':'OTHERS',
'Residentie Berghof' :'OTHERS',
'Woonerf Velodroom':'OTHERS',
'Country house for sale' :'OTHERS',
'New real estate project':'OTHERS',
'Project ROTTERIJ':'OTHERS',
'Gezellige nieuwbouw woonwijk te koop in Beveren':'OTHERS',
'REGATTA WONINGEN':'OTHERS',
'TONGRE NOTRE DAME - 8 maisons':'OTHERS',
       'New real estate project - Houses for sale':'OTHERS',
       'Gezellige nieuwbouw woonwijk te koop in Beveren-Le':'OTHERS',
       'Woonproject Zittaart Fase 3':'OTHERS',
        "L'Orée de Seumay":'OTHERS',
       'Woonproject Zittaart Fase 1 en 2':'OTHERS',
        'SINJAN':'OTHERS', "Woningen Op't Zand":'OTHERS',
       'THIER DES SOTAIS':'OTHERS',
        'Hof Berlaere - Woningen':'OTHERS',
       'Basalt - nieuwbouwwoningen':'OTHERS',
        'Stellar - Maisons':'OTHERS',
       'Heibloem - BEN woningen te Nijlen':'OTHERS',
        '"Les Maisons de la Ferme':'OTHERS',
       'Woonproject te Paddenweg Lier - BEN woni ngen':'OTHERS',
       'Woonproject Diamant te Herenthout - Woningen':'OTHERS',
       'Parkview - Woningen':'OTHERS',
        'Woningen Lijsterweg':'OTHERS',
       'Residentie Zuidkwartier - Woningen':'OTHERS',
        'Chapelle Sainte-Anne':'OTHERS',
       'Woningen Meerlaarstraat':'OTHERS',
        'Woningen Heieinde':'OTHERS',
        'EKSTERVELD':'OTHERS',
       'Grensstraat - BEN woningen':'OTHERS',
       '5 woningen - Residentie De Winghe':'OTHERS',
       'Vloeiende - nieuwbouwwoningen':'OTHERS', 'Dockside Gardens woningen':'OTHERS',
       'Pré à la Planche Lots 7 à 15':'OTHERS', 'WONINGEN I':'OTHERS',
       'De Confiserie - gebouw H':'OTHERS', 'The Revelation':'OTHERS', 'Sluisstraat':'OTHERS',
       "'Eglegem Sunset'":'OTHERS', 'Nijven 27 Oppuurs':'OTHERS', 'Bottelarij':'OTHERS',
       '"Moulin Blanc" Villas':'OTHERS', 'MOULIN BLANC':'OTHERS', '"Clos du verger"':'OTHERS',
       'Quartier Champ Delvigne':'OTHERS', 'Other properties for sale':'OTHERS',
       'Gent - Hof van Gent':'OTHERS', 'Castle for sale':'OTHERS', 'HATTRICK':'OTHERS',
       'Chalet for sale':'OTHERS', 'Ground floor for sale':'OTHERS',
       'Clos Georgette Brenez':'OTHERS', 'CLOS DU ROGNAC FLEMALLE Phase 1':'OTHERS',
       'Clos des Etangs':'OTHERS', "Maison - Le haut d'Hondzo":'OTHERS',
       'Déjà 95% DES LOTS VENDUS - 20 maisons neuves haute':'OTHERS',
       "LES COTEAUX D'ERBONNE - MONT FALISE PHASE 1 MAISON":'OTHERS',
       'Lotissement "Ann-Sophie C':'OTHERS', 'Kerkstraat - Zwevegem':'OTHERS',
       'Domaine de Limonval':'OTHERS',
       'CLOS DES TROIS CHENES MAISONS - TREVI RASQUAIN':'OTHERS',
       'CLOS DES TROIS CHENES - TREVI LIEGE - MAISONS':'OTHERS', 'ARBOR - Otegem':'OTHERS',
       'Nieuwbouwproject Dahlia':'OTHERS' , 'Lotissement Frassem':'OTHERS',
       'Studio for sale':'OTHERS', 'Manor house for sale':'OTHERS', 'CHAUMONT-GISTOUX':'OTHERS',
       'Adolphe Hullebroeckstraat':'OTHERS', 'Combattants de Templeuve':'OTHERS',
       'Lotissement Signeulx':'OTHERS', 'Burenberg Uphill':'OTHERS', 'Simmendans':'OTHERS',
       'Leeuwhof':'OTHERS', 'Bouwgronden en nieuwe won':'OTHERS', 'Duplex for sale':'OTHERS',
       'Residentie Theresianenhof':'OTHERS', 'Bois de la Pierre':'OTHERS', 'Ten Amershove':'OTHERS',
       "Luxe villa's Zoute":'OTHERS',
       'Nieuwbouwwoningen in het centrum van Kachtem':'OTHERS', 'AntonyTuin':'OTHERS',
       'bouwgronden en nieuwe won':'OTHERS', 'Hélécine':'OTHERS',
       'nieuwe woningen en bouwgr':'OTHERS', "C' Shell":'OTHERS',
       'bouwgronden en nieuwbouww':'OTHERS', 'Eringhem':'OTHERS',
       'Nieuwe woning & gronden,':'OTHERS', 'Bouwgrond en nieuwe wonin':'OTHERS',
       'Eco-quartier Boncelles':'OTHERS', 'Nieuwe woningen op fietsa':'OTHERS',
       'Domaine des Papillons':'OTHERS', 'Saint-Nicolas - Rue Thiou':'OTHERS',
       'nieuwe woningen in een ru':'OTHERS', 'Verkaveling Borstelstraat Houthulst':'OTHERS',
       'nieuwe woningen pal onder':'OTHERS', 'Hertstraat 15-21':'OTHERS',
       'Nieuwbouw woonsite HUBA':'OTHERS', 'De Statie':'OTHERS', 'Ruiselede fase 3':'OTHERS',
       'Nieuwenhove':'OTHERS', 'VERKAVELING HONZEBROUCK':'OTHERS', 'Project Sogeta':'OTHERS',
       'Les Oliviers Woningen - F':'OTHERS', 'Madelon':'OTHERS',
       'Hector Olivierstraat, 8480 Eernegem':'OTHERS', 'nieuwe woningen met prach':'OTHERS',
       'Jemeppe - Rue Xhavée':'OTHERS', 'Ans - Rue Haut-Douy (Mais':'OTHERS',
       'WETTEREN - Project SVENDS':'OTHERS', 'nieuwe woningen vlak bij':'OTHERS',
       'HalleRiet':'OTHERS', 'Caserne de Saive':'OTHERS', 'Wellens Wonen':'OTHERS',
       "Green C - The Villa's":'OTHERS', 'Maison clé sur porte':'OTHERS',
       'Zandvoordsestraat Oudenburg':'OTHERS', 'Roclenge - Rue Jean Derri':'OTHERS',
       'nieuwe woningen in rustig':'OTHERS', 'nieuwe woningen met vlott':'OTHERS',
       'HUIS WOUTERS':'OTHERS', 'Louis Genot':'OTHERS', 'Belgrade Phase 2':'OTHERS',
       'Project Aalbeke':'OTHERS', 'Nieuwe, moderne woningen':'OTHERS',
       'LALYS: je droom binnen handbereik':'OTHERS', 'Boterberg - Nieuwerkerken':'OTHERS',
       "Wonen in 't park - Boutersem":'OTHERS', 'ESCANAFFLES 4330105':'OTHERS',
       'Woonproject Olympia':'OTHERS', 'Belgrade Maisons':'OTHERS',
       'Gitsstraat 42 te Torhout':'OTHERS', 'Bolderik':'OTHERS', 'Saint Joseph BE':'OTHERS',
       'GroeneMeer':'OTHERS', 'Champ du Tordoir FIII':'OTHERS', 'Project Astravorm':'OTHERS',
       'Izegem Forum':'OTHERS', 'Steenberg':'OTHERS', 'Tuinen van Eden':'OTHERS',
       'J.B. Coomansstraat - BEN woningen te Berlaar':'OTHERS', 'projet-martin':'OTHERS',
       'LEEUWHOF - PROJ FASE 2':'OTHERS', 'Kloostertuin Woningen':'OTHERS', 'Lebeke 202':'OTHERS',
       'MAISONS DU MANOIR II':'OTHERS', 'LEEUWHOF - PROJ FASE 3':'OTHERS',
       'Geneverpiete woningen':'OTHERS', '2 nieuwe woningen':'OTHERS',
       'trendy nieuwbouwwoningen':'OTHERS', 'Maisons neuves à Wierde':'OTHERS',
       'Brugge Gulden Roos':'OTHERS', 'Moderne woningen te Gompe':'OTHERS',
       'Nieuwe woningen in rustig':'OTHERS', 'Project Sint-Jozef':'OTHERS',
       'Bitterstraat Jabbeke':'OTHERS', 'Lieve Gardens - woningen':'OTHERS',
       'Lieve Gardens':'OTHERS', '9450 Haaltert - Pontweg 4':'OTHERS', "LIVIN'LOPPEM":'OTHERS',
       'De Gits':'OTHERS', 'Unieke BEN woningen':'OTHERS', 'Asperre (Papenhof2) - Won':'OTHERS',
       'Roggestraat':'OTHERS', 'Residentie Kapelleken':'OTHERS', 'De Stek Woningen':'OTHERS',
       '3 prachtige BEN-woningen':'OTHERS', 'Westdorp':'OTHERS',
       'Achterstraat 14, 8480 Eernegem':'OTHERS', 'Peterseliestraat Brugge -':'OTHERS',
       'LUX fase II_woningen':'OTHERS',
       'Peterseliestraat Brugge - Wonen langs de vestingen':'OTHERS',
       'Residentie Dockside Garde':'OTHERS', 'Woonerf Bachtekerkweg':'OTHERS', 'Townhouses':'OTHERS',
       'Woningen Rosalie':'OTHERS', 'Residentie Alex II':'OTHERS', 'Domaine du Fort':'OTHERS', '809':'OTHERS',
       'BEN-woningen te Herentals':'OTHERS',
       'Echte parkwoningen vlakbij centrum Tielt':'OTHERS', 
         "Woonproject te Paddenweg Lier - BEN woningen" :"OTHERS" 
                          }})
df.rename(columns={'Column1':'property-type'},inplace=True)
df.rename(columns={'Column2':'Location'},inplace=True)
df.rename(columns={'Column3':'Price'},inplace=True)
df.rename(columns={'Column4':'Area'},inplace=True)
df.rename(columns={'Column5':'Number_of_Rooms'},inplace=True)
df.rename(columns={'Column6':'Furnished'},inplace=True)
df.rename(columns={'Column7':'Kitchen type'},inplace=True)
df.rename(columns={'Column8':'Status'},inplace=True)
df.rename(columns={'Column9':'Garden surface'},inplace=True)
df.rename(columns={'Column10':'Swimming Pool'},inplace=True)
df = df.drop(0)
df = df.drop(df[df.Number_of_Rooms =='400 m² square meters livable space' ].index)
df = df.drop(df[df.Number_of_Rooms =='429 m² square meters livable spac' ].index)
df = df.drop(df[df.Number_of_Rooms =='275 m² square meters of land' ].index)
df = df.drop(df[df.Number_of_Rooms =='9 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='5 bathrooms' ].index)
df = df.drop(df[df.Number_of_Rooms =='2700 m² square meters of land' ].index)
df = df.drop(df[df.Number_of_Rooms =='141 m² square meters livable space' ].index)
df = df.drop(df[df.Number_of_Rooms =='306 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='200 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1440 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='44 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='249 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='435 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1440 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='633 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='360 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='388 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='367 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='763 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='312 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='150 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='500 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='9 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='509 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='429 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1362 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms=='77 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1436 m² square meters of land '].index)
df = df.drop(df[df.Number_of_Rooms =='550 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1436 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='409 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='6200 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1425 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='36 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='39 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='50 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='30 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='18 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='179 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='234 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='21 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2000 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1004 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='256 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='486 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='225 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='94 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='184 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='3 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2 - 3 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='140 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='13 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='12 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='14 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='3 - 5 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='17 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='16 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='1 bathroom'].index)
df = df.drop(df[df.Number_of_Rooms =='20 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='23 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='2 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='250 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='23 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='15 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='4 - 5 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='385 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='650 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='3 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='4 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='11 bedrooms  '].index)
df = df.drop(df[df.Number_of_Rooms =='96 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='875 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='75 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1 - 4 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='252 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='350 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='750 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1 - 3 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='11 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='220 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='149 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='6 bathrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='2288 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='200050 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='Number_of_Rooms'].index)
df = df.drop(df[df.Number_of_Rooms =='270 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='218 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='507 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='1038 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='305 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='700 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='22 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='295 m² square meters of land'].index)
df = df.drop(df[df.Number_of_Rooms =='28 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='715 m² square meters livable space'].index)
df = df.drop(df[df.Number_of_Rooms =='21 bedrooms'].index)
df = df.drop(df[df.Number_of_Rooms =='280 m² square meters of land'].index)

df['Number_of_Rooms'] = df['Number_of_Rooms'].str.extract(r'(\d+)')
df = df.drop(df[df.Price =='€ 398,450'].index)
df = df.drop(df[df.Price =='€ 361,718'].index)
df = df.drop(df[df.Price =='€ 118,500'].index)
df = df.drop(df[df.Price =='€ 264,500'].index)
df = df.drop(df[df.Price =='€ 667,000'].index)
df = df.drop(df[df.Price =='€ 382,500'].index)
df = df.drop(df[df.Price =='€ 434,500'].index)
df = df.drop(df[df.Price =='€ 627,000'].index)
df = df.drop(df[df.Price =='€ 738,000'].index)
df = df.drop(df[df.Price =='€ 667,000'].index)
df = df.drop(df[df.Price =='€ 382,500'].index)
df = df.drop(df[df.Price =='€ 1,149'].index)
df = df.drop(df[df.Price =='€ 283,137'].index)
df = df.drop(df[df.Price =='€ 441,132'].index)
df = df.drop(df[df.Price =='€ 459,990'].index)
df = df.drop(df[df.Price =='€ 4,500'].index)
df = df.drop(df[df.Price =='€ 275,283'].index)
df = df.drop(df[df.Price =='€ 293,500'].index)
df = df.drop(df[df.Price =='€ 1,587'].index)
df = df.drop(df[df.Price =='€ 357,260'].index)
df = df.drop(df[df.Price =='€ 436,500'].index)
df = df.drop(df[df.Price =='€ 493,000'].index)
df = df.drop(df[df.Price =='€ 495,100'].index)
df = df.drop(df[df.Price =='€ 522,000'].index)
df = df.drop(df[df.Price =='€ 343,000'].index)
df = df.drop(df[df.Price =='€ 1,590'].index)
df = df.drop(df[df.Price =='€ 179,990'].index)
df = df.drop(df[df.Price =='€ 264,252'].index)
df = df.drop(df[df.Price =='€ 441,000'].index)
df = df.drop(df[df.Price =='€ 325,500'].index)
df = df.drop(df[df.Price =='€ 2,995'].index)
df = df.drop(df[df.Price =='€ 2,250'].index)
df = df.drop(df[df.Price =='€ 292,600'].index)
df = df.drop(df[df.Price =='€ 399,250'].index)
df = df.drop(df[df.Price =='€ 302,755'].index)
df = df.drop(df[df.Price =='€ 3,100'].index)
df = df.drop(df[df.Price =='€ 4,200'].index)
df = df.drop(df[df.Price =='€ 2,999'].index)
df = df.drop(df[df.Price =='€ 499,500'].index)
df = df.drop(df[df.Price =='€ 297,300'].index)
df = df.drop(df[df.Price =='€ 397,000'].index)
df = df.drop(df[df.Price =='€ 338,361'].index)
df = df.drop(df[df.Price =='€ 299,950'].index)
df = df.drop(df[df.Price =='€ 449,900'].index)
df = df.drop(df[df.Price =='€ 274,940'].index)
df = df.drop(df[df.Price =='€ 477,000'].index)
df = df.drop(df[df.Price =='€ 114,000'].index)
df = df.drop(df[df.Price =='€ 1,455'].index)
df = df.drop(df[df.Price =='€ 3,500'].index)
df = df.drop(df[df.Price =='€ 245,500 '].index)
df = df.drop(df[df.Price =='€ 288,000'].index)
df = df.drop(df[df.Price =='€ 281,436'].index)
df = df.drop(df[df.Price =='€ 356,877'].index)
df = df.drop(df[df.Price =='€ 509,000'].index)
df = df.drop(df[df.Price =='€ 245,500'].index)
df = df.drop(df[df.Price =='€ 934,000'].index)
df = df.drop(df[df.Price =='€ 618,000'].index)
df = df.drop(df[df.Price =='€ 383,500'].index)
df = df.drop(df[df.Price =='€ 349,900'].index)
df = df.drop(df[df.Price =='€ 189,999'].index)
df = df.drop(df[df.Price =='€ 1,198'].index)
df = df.drop(df[df.Price =='€ 694,000'].index)
df = df.drop(df[df.Price =='€ 674,500'].index)
df = df.drop(df[df.Price =='€ 399,500'].index)
df = df.drop(df[df.Price =='€ 177,500'].index)
df = df.drop(df[df.Price =='€ 336,500'].index)
df = df.drop(df[df.Price =='€ 244,048'].index)
df = df.drop(df[df.Price =='€ 1,620'].index)
df = df.drop(df[df.Price =='€ 1,599'].index)
df = df.drop(df[df.Price =='€ 138,000'].index)
df = df.drop(df[df.Price =='€ 280,700'].index)
df = df.drop(df[df.Price =='€ 260,100'].index)
df = df.drop(df[df.Price =='€ 237,800'].index)
df = df.drop(df[df.Price =='€ 169,900'].index)
df = df.drop(df[df.Price =='€ 121,000'].index)
df = df.drop(df[df.Price =='€ 352,500'].index)
df = df.drop(df[df.Price =='€ 314,836'].index)
df = df.drop(df[df.Price =='€ 447,000'].index)
df = df.drop(df[df.Price =='€ 682,000'].index)
df = df.drop(df[df.Price =='€ 261,000'].index)
df = df.drop(df[df.Price =='€ 344,500'].index)
df = df.drop(df[df.Price =='€ 266,200'].index)
df = df.drop(df[df.Price =='€ 419,900'].index)
df = df.drop(df[df.Price =='€ 258,000'].index)
df = df.drop(df[df.Price =='€ 364,173'].index)
df = df.drop(df[df.Price =='€ 377,000'].index)
df = df.drop(df[df.Price =='€ 467,500'].index)
df = df.drop(df[df.Price =='€ 561,200'].index)
df = df.drop(df[df.Price =='€ 674,900'].index)
df = df.drop(df[df.Price =='€ 361,599'].index)
df = df.drop(df[df.Price =='€ 239,900'].index)
df = df.drop(df[df.Price =='€ 156,800 '].index)
df = df.drop(df[df.Price =='€ 1,420'].index)
df = df.drop(df[df.Price =='€ 597,000'].index)
df = df.drop(df[df.Price =='€ 360,976'].index)
df = df.drop(df[df.Price =='€ 124,500'].index)
df = df.drop(df[df.Price =='€ 117,500'].index)
df = df.drop(df[df.Price =='€ 603,800'].index)
df = df.drop(df[df.Price =='€ 364,800'].index)
df = df.drop(df[df.Price =='€ 329,950'].index)
df = df.drop(df[df.Price =='€ 709,000'].index)
df = df.drop(df[df.Price =='€ 422,500'].index)
df = df.drop(df[df.Price =='€ 2,340'].index)
df = df.drop(df[df.Price =='€ 156,800'].index)
df = df.drop(df[df.Price =='€ 305,500'].index)
df = df.drop(df[df.Price =='€ 3,600'].index)
df = df.drop(df[df.Price =='€ 1,569'].index)
df = df.drop(df[df.Price =='€ 1,325'].index)
df = df.drop(df[df.Price =='€ 768,000'].index)
df = df.drop(df[df.Price =='€ 280,500'].index)
df = df.drop(df[df.Price =='€ 1,449'].index)
df = df.drop(df[df.Price =='€ 209,900'].index)
df = df.drop(df[df.Price =='€ 323,000'].index)
df = df.drop(df[df.Price =='€ 4,290'].index)
df = df.drop(df[df.Price =='€ 266,275'].index)
df = df.drop(df[df.Price =='€ 383,850'].index)
df = df.drop(df[df.Price =='€ 224,500'].index)
df = df.drop(df[df.Price =='€ 157,000'].index)
df = df.drop(df[df.Price =='€ 127,500'].index)
df = df.drop(df[df.Price =='€ 127,500'].index)
df = df.drop(df[df.Price =='€ 1,425'].index)
df = df.drop(df[df.Price =='€ 207,500'].index)
df = df.drop(df[df.Price =='€ 184,900'].index)
df = df.drop(df[df.Price =='€ 211,000'].index)
df = df.drop(df[df.Price =='€ 639,999'].index)
df = df.drop(df[df.Price =='€ 1,345'].index)
df = df.drop(df[df.Price =='€ 330,850'].index)
df = df.drop(df[df.Price =='€ 1,278'].index)
df = df.drop(df[df.Price =='€ 372,600'].index)
df = df.drop(df[df.Price =='€ 346,000'].index)
df = df.drop(df[df.Price =='€ 1,080'].index)
df = df.drop(df[df.Price =='€ 277,300'].index)
df = df.drop(df[df.Price =='€ 254,700'].index)
df = df.drop(df[df.Price =='€ 251,600'].index)
df = df.drop(df[df.Price =='€ 217,500'].index)
df = df.drop(df[df.Price =='€ 879,000'].index)
df = df.drop(df[df.Price =='€ 379,700'].index)
df = df.drop(df[df.Price =='€ 308,603'].index)
df = df.drop(df[df.Price =='€ 562,000'].index)
df = df.drop(df[df.Price =='€ 376,300'].index)
df = df.drop(df[df.Price =='€ 605,000'].index)
df = df.drop(df[df.Price =='€ 67,715'].index)
df = df.drop(df[df.Price =='€ 435,500'].index)
df = df.drop(df[df.Price =='€ 374,000'].index)
df = df.drop(df[df.Price =='€ 222,000'].index)
df = df.drop(df[df.Price =='€ 584,000'].index)
df = df.drop(df[df.Price =='€ 4,800'].index)
df = df.drop(df[df.Price =='€ 468,700'].index)
df = df.drop(df[df.Price =='€ 465,500'].index)
df = df.drop(df[df.Price =='€ 374,900'].index)
df = df.drop(df[df.Price =='€ 431,773'].index)
df = df.drop(df[df.Price =='€ 364,000'].index)
df = df.drop(df[df.Price =='€ 192,500'].index)
df = df.drop(df[df.Price =='€ 191,500'].index)
df = df.drop(df[df.Price =='€ 177,000'].index)
df = df.drop(df[df.Price =='€ 422,000'].index)
df = df.drop(df[df.Price =='€ 314,680'].index)
df = df.drop(df[df.Price =='€ 284,999'].index)
df = df.drop(df[df.Price =='€ 263,000'].index)
df = df.drop(df[df.Price =='€ 222,500'].index)
df = df.drop(df[df.Price =='€ 399,600'].index)
df = df.drop(df[df.Price =='€ 322,650'].index)
df = df.drop(df[df.Price =='€ 214,200'].index)
df = df.drop(df[df.Price =='€ 120,500'].index)
df = df.drop(df[df.Price =='€ 330,500'].index)
df = df.drop(df[df.Price =='€ 391,000'].index)
df = df.drop(df[df.Price =='€ 810,000'].index)
df = df.drop(df[df.Price =='€ 572,000'].index)
df = df.drop(df[df.Price =='€ 414,000'].index)
df = df.drop(df[df.Price =='€ 376,800'].index)
df = df.drop(df[df.Price =='€ 164,900'].index)
df = df.drop(df[df.Price =='€ 214,000'].index)
df = df.drop(df[df.Price =='€ 179,900'].index)
df = df.drop(df[df.Price =='€ 178,500'].index)
df = df.drop(df[df.Price =='€ 172,400'].index)
df = df.drop(df[df.Price =='€ 162,000'].index)
df = df.drop(df[df.Price =='€ 3,495'].index)
df = df.drop(df[df.Price =='€ 3,400'].index)
df = df.drop(df[df.Price =='€ 3,250'].index)
df = df.drop(df[df.Price =='€ 1,945'].index)
df = df.drop(df[df.Price =='€ 134,900'].index)
df = df.drop(df[df.Price =='€ 353,000'].index)
df = df.drop(df[df.Price =='€ 317,758'].index)
df = df.drop(df[df.Price =='€ 302,250'].index)
df = df.drop(df[df.Price =='€ 171,563'].index)
df = df.drop(df[df.Price =='€ 119,900'].index)
df = df.drop(df[df.Price =='€ 929,000'].index)
df = df.drop(df[df.Price =='€ 442,500'].index)
df = df.drop(df[df.Price =='€ 329,900'].index)
df = df.drop(df[df.Price =='€ 46,000'].index)
df = df.drop(df[df.Price =='€ 232,750'].index)
df = df.drop(df[df.Price =='€ 284,211'].index)
df = df.drop(df[df.Price =='€ 283,698'].index)
df = df.drop(df[df.Price =='€ 2,890'].index)
df = df.drop(df[df.Price =='€ 1,895'].index)
df = df.drop(df[df.Price =='€ 238,630'].index)
df = df.drop(df[df.Price =='€ 264,900'].index)
df = df.drop(df[df.Price =='€ 249,995'].index)
df = df.drop(df[df.Price =='€ 323,150'].index)
df = df.drop(df[df.Price =='€ 193,000'].index)
df = df.drop(df[df.Price =='€ 242,000'].index)
df = df.drop(df[df.Price =='€ 915,000'].index)
df = df.drop(df[df.Price =='€ 330,750'].index)
df = df.drop(df[df.Price =='€ 218,500'].index)
df = df.drop(df[df.Price =='€ 3,875'].index)
df = df.drop(df[df.Price =='€ 272,500'].index)
df = df.drop(df[df.Price =='€ 116,000'].index)
df = df.drop(df[df.Price =='€ 208,000'].index)
df = df.drop(df[df.Price =='€ 281,500'].index)
df = df.drop(df[df.Price =='€ 325,950'].index)
df = df.drop(df[df.Price =='€ 116,000'].index)
df = df.drop(df[df.Price =='€ 208,000'].index)
df = df.drop(df[df.Price =='€ 281,500'].index)
df = df.drop(df[df.Price =='€ 325,950'].index)
df = df.drop(df[df.Price =='€ 798,500'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 175500'].index)
df = df.drop(df[df.Price =='€ 117000'].index)
df = df.drop(df[df.Price =='€ 1770'].index)
df = df.drop(df[df.Price =='€ 4250'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 175500'].index)
df = df.drop(df[df.Price =='€ 117000'].index)
df = df.drop(df[df.Price =='€ 1770'].index)
df = df.drop(df[df.Price =='€ 4250'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 276,600 '].index)
df = df.drop(df[df.Price =='€ 175,500 '].index)
df = df.drop(df[df.Price =='€ 1,098'].index)
df = df.drop(df[df.Price =='€ 233,000'].index)
df = df.drop(df[df.Price =='€ 236,987'].index)
df = df.drop(df[df.Price =='€ 241,995'].index)
df = df.drop(df[df.Price =='€ 311,621'].index)
df = df.drop(df[df.Price =='€ 2,430'].index)
df = df.drop(df[df.Price =='€ 574,000'].index)
df = df.drop(df[df.Price =='€ 276,600'].index)
df = df.drop(df[df.Price =='€ 117,000'].index)
df = df.drop(df[df.Price =='€ 4,250'].index)
df = df.drop(df[df.Price =='€ 97,200'].index)
df = df.drop(df[df.Price =='€ 97,000'].index)
df = df.drop(df[df.Price =='€ 67,500'].index)
df = df.drop(df[df.Price =='€ 329,717'].index)
df = df.drop(df[df.Price =='€ 261,877'].index)
df = df.drop(df[df.Price =='€ 175,500'].index)
df = df.drop(df[df.Price =='€ 1,770'].index)


df = df.drop(df[df.Price =='€ 388,850'].index)
df = df.drop(df[df.Price =='€ 46,650'].index)
df = df.drop(df[df.Price =='€ 2,520'].index)
df = df.drop(df[df.Price =='€ 6,250'].index)
df = df.drop(df[df.Price =='€ 67,678'].index)
df = df.drop(df[df.Price =='€ 371,000'].index)
df = df.drop(df[df.Price =='€ 214,464'].index)
df = df.drop(df[df.Price =='€ 543,500'].index)
df = df.drop(df[df.Price =='€ 582,000'].index)

df = df.drop(df[df.Price =='€ 1,585'].index)
df = df.drop(df[df.Price =='€ 818,000'].index)
df = df.drop(df[df.Price =='€ 3,050'].index)
df = df.drop(df[df.Price =='€ 279,900'].index)
df = df.drop(df[df.Price =='€ 491,000'].index)
df = df.drop(df[df.Price =='€ 519,900'].index)

df = df.drop(df[df.Price =='€ 301,412'].index)
df = df.drop(df[df.Price =='€ 144,317'].index)
df = df.drop(df[df.Price =='€ 151,177'].index)
df = df.drop(df[df.Price =='€ 233,558'].index)
df = df.drop(df[df.Price =='€ 239,284'].index)
df = df.drop(df[df.Price =='€ 295,801'].index)
df = df.drop(df[df.Price =='€ 206,954'].index)
df = df.drop(df[df.Price =='€ 213,000'].index)
df = df.drop(df[df.Price =='€ 216,800'].index)
df = df.drop(df[df.Price =='€ 230,610'].index)
df = df.drop(df[df.Price =='€ 301,604'].index)
df = df.drop(df[df.Price =='€ 4,700'].index)
df = df.drop(df[df.Price =='€ 458,000'].index)
df = df.drop(df[df.Price =='€ 81,792'].index)
df = df.drop(df[df.Price =='€ 82,880'].index)
df = df.drop(df[df.Price =='€ 68,000'].index)
df = df.drop(df[df.Price =='€ 1,115'].index)
df = df.drop(df[df.Price =='€ 428,500'].index)
df = df.drop(df[df.Price =='€ 386,000'].index)
df = df.drop(df[df.Price =='€ 216,000'].index)

df = df.drop(df[df.Price =='€ 214,990'].index)
df = df.drop(df[df.Price =='€ 1,875'].index)
df = df.drop(df[df.Price =='€ 798,000'].index)
df = df.drop(df[df.Price =='€ 1,220'].index)
df = df.drop(df[df.Price =='€ 755,000'].index)
df = df.drop(df[df.Price =='€ 89,467'].index)
df = df.drop(df[df.Price =='€ 107,060'].index)
df = df.drop(df[df.Price =='€ 128,775'].index)
df = df.drop(df[df.Price =='€ 128,900'].index)
df = df.drop(df[df.Price =='€ 476,035'].index)
df = df.drop(df[df.Price =='€ 332,914'].index)
df = df.drop(df[df.Price =='€ 351,273'].index)
df = df.drop(df[df.Price =='€ 363,000'].index)
df = df.drop(df[df.Price =='€ 368,160'].index)

df = df.drop(df[df.Price =='€ 2,495'].index)
df = df.drop(df[df.Price =='€ 265,500'].index)
df = df.drop(df[df.Price =='€ 267,750'].index)
df = df.drop(df[df.Price =='€ 273,461'].index)
df = df.drop(df[df.Price =='€ 274,363'].index)
df = df.drop(df[df.Price =='€ 243,000'].index)
df = df.drop(df[df.Price =='€ 245,400'].index)
df = df.drop(df[df.Price =='€ 245,665'].index)
df = df.drop(df[df.Price =='€ 247,964'].index)
df = df.drop(df[df.Price =='€ 252,905'].index)
df = df.drop(df[df.Price =='€ 488,000'].index)
df = df.drop(df[df.Price =='€ 881,000'].index)
df = df.drop(df[df.Price =='€ 673,000'].index)
df = df.drop(df[df.Price =='€ 84,130'].index)
df = df.drop(df[df.Price =='€ 88,740'].index)
df = df.drop(df[df.Price =='€ 261,440'].index)
df = df.drop(df[df.Price =='€ 256,500'].index)
df = df.drop(df[df.Price =='€ 255,750'].index)
df = df.drop(df[df.Price =='€ 3,699'].index)
df = df.drop(df[df.Price =='€ 2,699'].index)

df = df.drop(df[df.Price =='€ 398,450'].index)
df = df.drop(df[df.Price =='€ 361,718'].index)
df = df.drop(df[df.Price =='€ 118,500'].index)
df = df.drop(df[df.Price =='€ 264,500'].index)
df = df.drop(df[df.Price =='€ 667,000'].index)
df = df.drop(df[df.Price =='€ 382,500'].index)
df = df.drop(df[df.Price =='€ 434,500'].index)
df = df.drop(df[df.Price =='€ 627,000'].index)
df = df.drop(df[df.Price =='€ 738,000'].index)
df = df.drop(df[df.Price =='€ 667,000'].index)
df = df.drop(df[df.Price =='€ 382,500'].index)
df = df.drop(df[df.Price =='€ 1,149'].index)
df = df.drop(df[df.Price =='€ 283,137'].index)
df = df.drop(df[df.Price =='€ 441,132'].index)
df = df.drop(df[df.Price =='€ 459,990'].index)
df = df.drop(df[df.Price =='€ 4,500'].index)
df = df.drop(df[df.Price =='€ 275,283'].index)
df = df.drop(df[df.Price =='€ 293,500'].index)
df = df.drop(df[df.Price =='€ 1,587'].index)
df = df.drop(df[df.Price =='€ 357,260'].index)
df = df.drop(df[df.Price =='€ 436,500'].index)
df = df.drop(df[df.Price =='€ 493,000'].index)
df = df.drop(df[df.Price =='€ 495,100'].index)
df = df.drop(df[df.Price =='€ 522,000'].index)
df = df.drop(df[df.Price =='€ 343,000'].index)
df = df.drop(df[df.Price =='€ 1,590'].index)
df = df.drop(df[df.Price =='€ 179,990'].index)
df = df.drop(df[df.Price =='€ 264,252'].index)
df = df.drop(df[df.Price =='€ 441,000'].index)
df = df.drop(df[df.Price =='€ 325,500'].index)
df = df.drop(df[df.Price =='€ 2,995'].index)
df = df.drop(df[df.Price =='€ 2,250'].index)
df = df.drop(df[df.Price =='€ 292,600'].index)
df = df.drop(df[df.Price =='€ 399,250'].index)
df = df.drop(df[df.Price =='€ 302,755'].index)
df = df.drop(df[df.Price =='€ 3,100'].index)
df = df.drop(df[df.Price =='€ 4,200'].index)
df = df.drop(df[df.Price =='€ 2,999'].index)
df = df.drop(df[df.Price =='€ 499,500'].index)
df = df.drop(df[df.Price =='€ 297,300'].index)
df = df.drop(df[df.Price =='€ 397,000'].index)
df = df.drop(df[df.Price =='€ 338,361'].index)
df = df.drop(df[df.Price =='€ 299,950'].index)
df = df.drop(df[df.Price =='€ 449,900'].index)
df = df.drop(df[df.Price =='€ 274,940'].index)
df = df.drop(df[df.Price =='€ 477,000'].index)
df = df.drop(df[df.Price =='€ 114,000'].index)
df = df.drop(df[df.Price =='€ 1,455'].index)
df = df.drop(df[df.Price =='€ 3,500'].index)
df = df.drop(df[df.Price =='€ 245,500 '].index)
df = df.drop(df[df.Price =='€ 288,000'].index)
df = df.drop(df[df.Price =='€ 281,436'].index)
df = df.drop(df[df.Price =='€ 356,877'].index)
df = df.drop(df[df.Price =='€ 509,000'].index)
df = df.drop(df[df.Price =='€ 245,500'].index)
df = df.drop(df[df.Price =='€ 934,000'].index)
df = df.drop(df[df.Price =='€ 618,000'].index)
df = df.drop(df[df.Price =='€ 383,500'].index)
df = df.drop(df[df.Price =='€ 349,900'].index)
df = df.drop(df[df.Price =='€ 189,999'].index)
df = df.drop(df[df.Price =='€ 1,198'].index)
df = df.drop(df[df.Price =='€ 694,000'].index)
df = df.drop(df[df.Price =='€ 674,500'].index)
df = df.drop(df[df.Price =='€ 399,500'].index)
df = df.drop(df[df.Price =='€ 177,500'].index)
df = df.drop(df[df.Price =='€ 336,500'].index)
df = df.drop(df[df.Price =='€ 244,048'].index)
df = df.drop(df[df.Price =='€ 1,620'].index)
df = df.drop(df[df.Price =='€ 1,599'].index)
df = df.drop(df[df.Price =='€ 138,000'].index)
df = df.drop(df[df.Price =='€ 280,700'].index)
df = df.drop(df[df.Price =='€ 260,100'].index)
df = df.drop(df[df.Price =='€ 237,800'].index)
df = df.drop(df[df.Price =='€ 169,900'].index)
df = df.drop(df[df.Price =='€ 121,000'].index)
df = df.drop(df[df.Price =='€ 352,500'].index)
df = df.drop(df[df.Price =='€ 314,836'].index)
df = df.drop(df[df.Price =='€ 447,000'].index)
df = df.drop(df[df.Price =='€ 682,000'].index)
df = df.drop(df[df.Price =='€ 261,000'].index)
df = df.drop(df[df.Price =='€ 344,500'].index)
df = df.drop(df[df.Price =='€ 266,200'].index)
df = df.drop(df[df.Price =='€ 419,900'].index)
df = df.drop(df[df.Price =='€ 258,000'].index)
df = df.drop(df[df.Price =='€ 364,173'].index)
df = df.drop(df[df.Price =='€ 377,000'].index)
df = df.drop(df[df.Price =='€ 467,500'].index)
df = df.drop(df[df.Price =='€ 561,200'].index)
df = df.drop(df[df.Price =='€ 674,900'].index)
df = df.drop(df[df.Price =='€ 361,599'].index)
df = df.drop(df[df.Price =='€ 239,900'].index)
df = df.drop(df[df.Price =='€ 156,800 '].index)
df = df.drop(df[df.Price =='€ 1,420'].index)
df = df.drop(df[df.Price =='€ 597,000'].index)
df = df.drop(df[df.Price =='€ 360,976'].index)
df = df.drop(df[df.Price =='€ 124,500'].index)
df = df.drop(df[df.Price =='€ 117,500'].index)
df = df.drop(df[df.Price =='€ 603,800'].index)
df = df.drop(df[df.Price =='€ 364,800'].index)
df = df.drop(df[df.Price =='€ 329,950'].index)
df = df.drop(df[df.Price =='€ 709,000'].index)
df = df.drop(df[df.Price =='€ 422,500'].index)
df = df.drop(df[df.Price =='€ 2,340'].index)
df = df.drop(df[df.Price =='€ 156,800'].index)
df = df.drop(df[df.Price =='€ 305,500'].index)
df = df.drop(df[df.Price =='€ 3,600'].index)
df = df.drop(df[df.Price =='€ 1,569'].index)
df = df.drop(df[df.Price =='€ 1,325'].index)
df = df.drop(df[df.Price =='€ 768,000'].index)
df = df.drop(df[df.Price =='€ 280,500'].index)
df = df.drop(df[df.Price =='€ 1,449'].index)
df = df.drop(df[df.Price =='€ 209,900'].index)
df = df.drop(df[df.Price =='€ 323,000'].index)
df = df.drop(df[df.Price =='€ 4,290'].index)
df = df.drop(df[df.Price =='€ 266,275'].index)
df = df.drop(df[df.Price =='€ 383,850'].index)
df = df.drop(df[df.Price =='€ 224,500'].index)
df = df.drop(df[df.Price =='€ 157,000'].index)
df = df.drop(df[df.Price =='€ 127,500'].index)
df = df.drop(df[df.Price =='€ 127,500'].index)
df = df.drop(df[df.Price =='€ 1,425'].index)
df = df.drop(df[df.Price =='€ 207,500'].index)
df = df.drop(df[df.Price =='€ 184,900'].index)
df = df.drop(df[df.Price =='€ 211,000'].index)
df = df.drop(df[df.Price =='€ 639,999'].index)
df = df.drop(df[df.Price =='€ 1,345'].index)
df = df.drop(df[df.Price =='€ 330,850'].index)
df = df.drop(df[df.Price =='€ 1,278'].index)
df = df.drop(df[df.Price =='€ 372,600'].index)
df = df.drop(df[df.Price =='€ 346,000'].index)
df = df.drop(df[df.Price =='€ 1,080'].index)
df = df.drop(df[df.Price =='€ 277,300'].index)
df = df.drop(df[df.Price =='€ 254,700'].index)
df = df.drop(df[df.Price =='€ 251,600'].index)
df = df.drop(df[df.Price =='€ 217,500'].index)
df = df.drop(df[df.Price =='€ 879,000'].index)
df = df.drop(df[df.Price =='€ 379,700'].index)
df = df.drop(df[df.Price =='€ 308,603'].index)
df = df.drop(df[df.Price =='€ 562,000'].index)
df = df.drop(df[df.Price =='€ 376,300'].index)
df = df.drop(df[df.Price =='€ 605,000'].index)
df = df.drop(df[df.Price =='€ 67,715'].index)
df = df.drop(df[df.Price =='€ 435,500'].index)
df = df.drop(df[df.Price =='€ 374,000'].index)
df = df.drop(df[df.Price =='€ 222,000'].index)
df = df.drop(df[df.Price =='€ 584,000'].index)
df = df.drop(df[df.Price =='€ 4,800'].index)
df = df.drop(df[df.Price =='€ 468,700'].index)
df = df.drop(df[df.Price =='€ 465,500'].index)
df = df.drop(df[df.Price =='€ 374,900'].index)
df = df.drop(df[df.Price =='€ 431,773'].index)
df = df.drop(df[df.Price =='€ 364,000'].index)
df = df.drop(df[df.Price =='€ 192,500'].index)
df = df.drop(df[df.Price =='€ 191,500'].index)
df = df.drop(df[df.Price =='€ 177,000'].index)
df = df.drop(df[df.Price =='€ 422,000'].index)
df = df.drop(df[df.Price =='€ 314,680'].index)
df = df.drop(df[df.Price =='€ 284,999'].index)
df = df.drop(df[df.Price =='€ 263,000'].index)
df = df.drop(df[df.Price =='€ 222,500'].index)
df = df.drop(df[df.Price =='€ 399,600'].index)
df = df.drop(df[df.Price =='€ 322,650'].index)
df = df.drop(df[df.Price =='€ 214,200'].index)
df = df.drop(df[df.Price =='€ 120,500'].index)
df = df.drop(df[df.Price =='€ 330,500'].index)
df = df.drop(df[df.Price =='€ 391,000'].index)
df = df.drop(df[df.Price =='€ 810,000'].index)
df = df.drop(df[df.Price =='€ 572,000'].index)
df = df.drop(df[df.Price =='€ 414,000'].index)
df = df.drop(df[df.Price =='€ 376,800'].index)
df = df.drop(df[df.Price =='€ 164,900'].index)
df = df.drop(df[df.Price =='€ 214,000'].index)
df = df.drop(df[df.Price =='€ 179,900'].index)
df = df.drop(df[df.Price =='€ 178,500'].index)
df = df.drop(df[df.Price =='€ 172,400'].index)
df = df.drop(df[df.Price =='€ 162,000'].index)
df = df.drop(df[df.Price =='€ 3,495'].index)
df = df.drop(df[df.Price =='€ 3,400'].index)
df = df.drop(df[df.Price =='€ 3,250'].index)
df = df.drop(df[df.Price =='€ 1,945'].index)
df = df.drop(df[df.Price =='€ 134,900'].index)
df = df.drop(df[df.Price =='€ 353,000'].index)
df = df.drop(df[df.Price =='€ 317,758'].index)
df = df.drop(df[df.Price =='€ 302,250'].index)
df = df.drop(df[df.Price =='€ 171,563'].index)
df = df.drop(df[df.Price =='€ 119,900'].index)
df = df.drop(df[df.Price =='€ 929,000'].index)
df = df.drop(df[df.Price =='€ 442,500'].index)
df = df.drop(df[df.Price =='€ 329,900'].index)
df = df.drop(df[df.Price =='€ 46,000'].index)
df = df.drop(df[df.Price =='€ 232,750'].index)
df = df.drop(df[df.Price =='€ 284,211'].index)
df = df.drop(df[df.Price =='€ 283,698'].index)
df = df.drop(df[df.Price =='€ 2,890'].index)
df = df.drop(df[df.Price =='€ 1,895'].index)
df = df.drop(df[df.Price =='€ 238,630'].index)
df = df.drop(df[df.Price =='€ 264,900'].index)
df = df.drop(df[df.Price =='€ 249,995'].index)
df = df.drop(df[df.Price =='€ 323,150'].index)
df = df.drop(df[df.Price =='€ 193,000'].index)
df = df.drop(df[df.Price =='€ 242,000'].index)
df = df.drop(df[df.Price =='€ 915,000'].index)
df = df.drop(df[df.Price =='€ 330,750'].index)
df = df.drop(df[df.Price =='€ 218,500'].index)
df = df.drop(df[df.Price =='€ 3,875'].index)
df = df.drop(df[df.Price =='€ 272,500'].index)
df = df.drop(df[df.Price =='€ 116,000'].index)
df = df.drop(df[df.Price =='€ 208,000'].index)
df = df.drop(df[df.Price =='€ 281,500'].index)
df = df.drop(df[df.Price =='€ 325,950'].index)
df = df.drop(df[df.Price =='€ 116,000'].index)
df = df.drop(df[df.Price =='€ 208,000'].index)
df = df.drop(df[df.Price =='€ 281,500'].index)
df = df.drop(df[df.Price =='€ 325,950'].index)
df = df.drop(df[df.Price =='€ 798,500'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 175500'].index)
df = df.drop(df[df.Price =='€ 117000'].index)
df = df.drop(df[df.Price =='€ 1770'].index)
df = df.drop(df[df.Price =='€ 4250'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 175500'].index)
df = df.drop(df[df.Price =='€ 117000'].index)
df = df.drop(df[df.Price =='€ 1770'].index)
df = df.drop(df[df.Price =='€ 4250'].index)
df = df.drop(df[df.Price =='€ 276600'].index)
df = df.drop(df[df.Price =='€ 276,600 '].index)
df = df.drop(df[df.Price =='€ 175,500 '].index)
df = df.drop(df[df.Price =='€ 1,098'].index)
df = df.drop(df[df.Price =='€ 233,000'].index)
df = df.drop(df[df.Price =='€ 236,987'].index)
df = df.drop(df[df.Price =='€ 241,995'].index)
df = df.drop(df[df.Price =='€ 311,621'].index)
df = df.drop(df[df.Price =='€ 2,430'].index)
df = df.drop(df[df.Price =='€ 574,000'].index)
df = df.drop(df[df.Price =='€ 276,600'].index)
df = df.drop(df[df.Price =='€ 117,000'].index)
df = df.drop(df[df.Price =='€ 4,250'].index)
df = df.drop(df[df.Price =='€ 97,200'].index)
df = df.drop(df[df.Price =='€ 97,000'].index)
df = df.drop(df[df.Price =='€ 67,500'].index)
df = df.drop(df[df.Price =='€ 329,717'].index)
df = df.drop(df[df.Price =='€ 261,877'].index)
df = df.drop(df[df.Price =='€ 175,500'].index)
df = df.drop(df[df.Price =='€ 1,770'].index)

df = df.drop(df[df.Price =='€ 388,850'].index)
df = df.drop(df[df.Price =='€ 46,650'].index)
df = df.drop(df[df.Price =='€ 2,520'].index)
df = df.drop(df[df.Price =='€ 6,250'].index)
df = df.drop(df[df.Price =='€ 67,678'].index)
df = df.drop(df[df.Price =='€ 371,000'].index)
df = df.drop(df[df.Price =='€ 214,464'].index)
df = df.drop(df[df.Price =='€ 543,500'].index)
df = df.drop(df[df.Price =='€ 582,000'].index)

df = df.drop(df[df.Price =='€ 1,585'].index)
df = df.drop(df[df.Price =='€ 818,000'].index)
df = df.drop(df[df.Price =='€ 3,050'].index)
df = df.drop(df[df.Price =='€ 279,900'].index)
df = df.drop(df[df.Price =='€ 491,000'].index)
df = df.drop(df[df.Price =='€ 519,900'].index)

df = df.drop(df[df.Price =='€ 301,412'].index)
df = df.drop(df[df.Price =='€ 144,317'].index)
df = df.drop(df[df.Price =='€ 151,177'].index)
df = df.drop(df[df.Price =='€ 233,558'].index)
df = df.drop(df[df.Price =='€ 239,284'].index)
df = df.drop(df[df.Price =='€ 295,801'].index)
df = df.drop(df[df.Price =='€ 206,954'].index)
df = df.drop(df[df.Price =='€ 213,000'].index)
df = df.drop(df[df.Price =='€ 216,800'].index)
df = df.drop(df[df.Price =='€ 230,610'].index)
df = df.drop(df[df.Price =='€ 301,604'].index)
df = df.drop(df[df.Price =='€ 4,700'].index)
df = df.drop(df[df.Price =='€ 458,000'].index)
df = df.drop(df[df.Price =='€ 81,792'].index)
df = df.drop(df[df.Price =='€ 82,880'].index)
df = df.drop(df[df.Price =='€ 68,000'].index)
df = df.drop(df[df.Price =='€ 1,115'].index)
df = df.drop(df[df.Price =='€ 428,500'].index)
df = df.drop(df[df.Price =='€ 386,000'].index)
df = df.drop(df[df.Price =='€ 216,000'].index)

df = df.drop(df[df.Price =='€ 214,990'].index)
df = df.drop(df[df.Price =='€ 1,875'].index)
df = df.drop(df[df.Price =='€ 798,000'].index)
df = df.drop(df[df.Price =='€ 1,220'].index)
df = df.drop(df[df.Price =='€ 755,000'].index)
df = df.drop(df[df.Price =='€ 89,467'].index)
df = df.drop(df[df.Price =='€ 107,060'].index)
df = df.drop(df[df.Price =='€ 128,775'].index)
df = df.drop(df[df.Price =='€ 128,900'].index)
df = df.drop(df[df.Price =='€ 476,035'].index)
df = df.drop(df[df.Price =='€ 332,914'].index)
df = df.drop(df[df.Price =='€ 351,273'].index)
df = df.drop(df[df.Price =='€ 363,000'].index)
df = df.drop(df[df.Price =='€ 368,160'].index)

df = df.drop(df[df.Price =='€ 2,495'].index)
df = df.drop(df[df.Price =='€ 265,500'].index)
df = df.drop(df[df.Price =='€ 267,750'].index)
df = df.drop(df[df.Price =='€ 273,461'].index)
df = df.drop(df[df.Price =='€ 274,363'].index)
df = df.drop(df[df.Price =='€ 243,000'].index)
df = df.drop(df[df.Price =='€ 245,400'].index)
df = df.drop(df[df.Price =='€ 245,665'].index)
df = df.drop(df[df.Price =='€ 247,964'].index)
df = df.drop(df[df.Price =='€ 252,905'].index)
df = df.drop(df[df.Price =='€ 488,000'].index)
df = df.drop(df[df.Price =='€ 881,000'].index)
df = df.drop(df[df.Price =='€ 673,000'].index)
df = df.drop(df[df.Price =='€ 84,130'].index)
df = df.drop(df[df.Price =='€ 88,740'].index)
df = df.drop(df[df.Price =='€ 261,440'].index)
df = df.drop(df[df.Price =='€ 256,500'].index)
df = df.drop(df[df.Price =='€ 255,750'].index)
df = df.drop(df[df.Price =='€ 3,699'].index)
df = df.drop(df[df.Price =='€ 2,699'].index)
df = df.drop(df[df.Price =='€ 348,528'].index)
df = df.drop(df[df.Price =='€ 285,155'].index)
df = df.drop(df[df.Price =='€ 288,300'].index)
df = df.drop(df[df.Price =='€ 289,010'].index)
df = df.drop(df[df.Price =='€ 289,522'].index)
df = df.drop(df[df.Price =='€ 252,350'].index)
df = df.drop(df[df.Price =='€ 127,000'].index)
df = df.drop(df[df.Price =='€ 274,500'].index)
df = df.drop(df[df.Price =='€ 279,650'].index)
df = df.drop(df[df.Price =='€ 284,313'].index)
df = df.drop(df[df.Price =='€ 348,528'].index)
df = df.drop(df[df.Price =='€ 285,155'].index)
df = df.drop(df[df.Price =='€ 288,300'].index)
df = df.drop(df[df.Price =='€ 289,010'].index)
df = df.drop(df[df.Price =='€ 289,522'].index)
df = df.drop(df[df.Price =='€ 252,350'].index)
df = df.drop(df[df.Price =='€ 127,000'].index)
df = df.drop(df[df.Price =='€ 274,500'].index)
df = df.drop(df[df.Price =='€ 279,650'].index)
df = df.drop(df[df.Price =='€ 284,313'].index)
df = df.drop(df[df.Price =='€ 294,915'].index)
df = df.drop(df[df.Price =='€ 293,512'].index)
df = df.drop(df[df.Price =='€ 293,248'].index)
df = df.drop(df[df.Price =='€ 290,500'].index)
df = df.drop(df[df.Price =='€ 882,000'].index)

df = df.drop(df[df.Price =='€ 669,300'].index)
df = df.drop(df[df.Price =='€ 333,760'].index)
df = df.drop(df[df.Price =='€ 333,321'].index)
df = df.drop(df[df.Price =='€ 327,700'].index)
df = df.drop(df[df.Price =='€ 320,200'].index)
df = df.drop(df[df.Price =='€ 254,500'].index)
df = df.drop(df[df.Price =='€ 303,500'].index)
df = df.drop(df[df.Price =='€ 303,445'].index)
df = df.drop(df[df.Price =='€ 302,500'].index)
df = df.drop(df[df.Price =='€ 301,100'].index)
df = df.drop(df[df.Price =='€ 315,130'].index)
df = df.drop(df[df.Price =='€ 316,937'].index)
df = df.drop(df[df.Price =='€ 318,555'].index)
df = df.drop(df[df.Price =='€ 320,200 '].index)
df = df.drop(df[df.Price =='€ 338,000'].index)
df = df.drop(df[df.Price =='€ 329,624'].index)
df = df.drop(df[df.Price =='€ 330,928'].index)
df = df.drop(df[df.Price =='€ 332,277'].index)
df = df.drop(df[df.Price =='€ 332,852'].index)
df = df.drop(df[df.Price =='€ 299,999'].index)

df = df.drop(df[df.Price =='€ 370,435'].index)
df = df.drop(df[df.Price =='€ 352,855'].index)
df = df.drop(df[df.Price =='€ 351,500'].index)
df = df.drop(df[df.Price =='€ 349,050'].index)
df = df.drop(df[df.Price =='€ 348,871'].index)
df = df.drop(df[df.Price =='€ 275,200'].index)
df = df.drop(df[df.Price =='€ 347,196'].index)
df = df.drop(df[df.Price =='€ 146,000'].index)
df = df.drop(df[df.Price =='€ 340,256'].index)
df = df.drop(df[df.Price =='€ 336,852'].index)
df = df.drop(df[df.Price =='€ 36,000'].index)
df = df.drop(df[df.Price =='€ 318,578'].index)
df = df.drop(df[df.Price =='€ 207,000'].index)
df = df.drop(df[df.Price =='€ 284,450'].index)
df = df.drop(df[df.Price =='€ 498,850'].index)

df = df.drop(df[df.Price =='€ 441,805'].index)
df = df.drop(df[df.Price =='€ 408,999'].index)
df = df.drop(df[df.Price =='€ 403,000'].index)
df = df.drop(df[df.Price =='€ 398,346'].index)
df = df.drop(df[df.Price =='€ 389,990'].index)
df = df.drop(df[df.Price =='€ 187,000'].index)
df = df.drop(df[df.Price =='€ 365,800'].index)
df = df.drop(df[df.Price =='€ 360,900'].index)
df = df.drop(df[df.Price =='€ 358,939'].index)
df = df.drop(df[df.Price =='€ 335,387'].index)
df = df.drop(df[df.Price =='€ 247,500'].index)
df = df.drop(df[df.Price =='€ 356,000'].index)
df = df.drop(df[df.Price =='€ 354,643'].index)
df = df.drop(df[df.Price =='€ 354,413'].index)
df = df.drop(df[df.Price =='€ 347,698'].index)
df = df.drop(df[df.Price =='€ 349,300'].index)
df = df.drop(df[df.Price =='€ 313,599'].index)
df = df.drop(df[df.Price =='€ 307,343'].index)
df = df.drop(df[df.Price =='€ 306,447'].index)
df = df.drop(df[df.Price =='€ 296,845'].index)
df = df.drop(df[df.Price =='€ 374,571'].index)
df = df.drop(df[df.Price =='€ 417,240'].index)
df = df.drop(df[df.Price =='€ 417,685'].index)
df = df.drop(df[df.Price =='€ 462,788'].index)
df = df.drop(df[df.Price =='€ 1,435'].index)
df = df.drop(df[df.Price =='€ 369,675'].index)
df = df.drop(df[df.Price =='€ 1,169'].index)
df = df.drop(df[df.Price =='€ 161,000'].index)
df = df.drop(df[df.Price =='€ 167,000'].index)
df = df.drop(df[df.Price =='€ 305,127'].index)

df = df.drop(df[df.Price =='€ 739,000'].index)
df = df.drop(df[df.Price =='€ 330,346'].index)
df = df.drop(df[df.Price =='€ 327,440'].index)
df = df.drop(df[df.Price =='€ 320,039'].index)
df = df.drop(df[df.Price =='€ 314,576'].index)
df = df.drop(df[df.Price =='€ 789,000'].index)
df = df.drop(df[df.Price =='€ 263,147'].index)
df = df.drop(df[df.Price =='€ 1,999'].index)
df = df.drop(df[df.Price =='€ 391,200'].index)
df = df.drop(df[df.Price =='€ 216,500'].index)
df = df.drop(df[df.Price =='€ 472,788'].index)
df = df.drop(df[df.Price =='€ 494,972'].index)
df = df.drop(df[df.Price =='€ 498,067'].index)
df = df.drop(df[df.Price =='€ 1,015'].index)
df = df.drop(df[df.Price =='€ 325,601'].index)

df = df.drop(df[df.Price =='€ 349,296'].index)
df = df.drop(df[df.Price =='€ 122,000'].index)
df = df.drop(df[df.Price =='€ 538,071'].index)
df = df.drop(df[df.Price =='€ 335,458'].index)
df = df.drop(df[df.Price =='€ 332,458'].index)
df = df.drop(df[df.Price =='€ 304,997'].index)
df = df.drop(df[df.Price =='€ 295,825'].index)
df = df.drop(df[df.Price =='€ 291,968'].index)
df = df.drop(df[df.Price =='€ 345,750'].index)
df = df.drop(df[df.Price =='€ 689,000'].index)
df = df.drop(df[df.Price =='€ 476,000'].index)
df = df.drop(df[df.Price =='€ 1,525'].index)
df = df.drop(df[df.Price =='€ 307,000'].index)
df = df.drop(df[df.Price =='€ 14,500'].index)
df = df.drop(df[df.Price =='€ 2,375'].index)
df = df.drop(df[df.Price =='€ 339,325'].index)
df = df.drop(df[df.Price =='€ 1,290'].index)
df = df.drop(df[df.Price =='€ 341,493'].index)
df = df.drop(df[df.Price =='€ 348,217'].index)
df = df.drop(df[df.Price =='€ 292,528'].index)

df = df.drop(df[df.Price =='€ 407,364'].index)
df = df.drop(df[df.Price =='€ 988,000'].index)
df = df.drop(df[df.Price =='€ 497,650'].index)
df = df.drop(df[df.Price =='€ 456,000'].index)
df = df.drop(df[df.Price =='€ 344,000'].index)
df = df.drop(df[df.Price =='€ 370,250'].index)
df = df.drop(df[df.Price =='€ 219,950'].index)
df = df.drop(df[df.Price =='€ 432,309'].index)
df = df.drop(df[df.Price =='€ 398,500'].index)
df = df.drop(df[df.Price =='€ 2,095'].index)
df = df.drop(df[df.Price =='€ 137,500'].index)
df = df.drop(df[df.Price =='€ 592,450'].index)
df = df.drop(df[df.Price =='€ 235,500'].index)
df = df.drop(df[df.Price =='€ 228,530'].index)
df = df.drop(df[df.Price =='€ 528,000'].index)

df = df.drop(df[df.Price =='€ 4,850'].index)
df = df.drop(df[df.Price =='€ 623,000'].index)
df = df.drop(df[df.Price =='€ 349,850'].index)
df = df.drop(df[df.Price =='€ 331,950'].index)
df = df.drop(df[df.Price =='€ 1,985'].index)
df = df.drop(df[df.Price =='€ 2,190'].index)
df = df.drop(df[df.Price =='€ 147,500'].index)
df = df.drop(df[df.Price =='€ 319,926'].index)
df = df.drop(df[df.Price =='€ 267,500'].index)
df = df.drop(df[df.Price =='€ 509,500'].index)
df = df.drop(df[df.Price =='€ 898,000'].index)
df = df.drop(df[df.Price =='€ 2,480'].index)
df = df.drop(df[df.Price =='€ 998,000'].index)
df = df.drop(df[df.Price =='€ 224,900'].index)
df = df.drop(df[df.Price =='€ 192,000'].index)

df = df.drop(df[df.Price =='€ 251,016'].index)
df = df.drop(df[df.Price =='€ 330,816'].index)
df = df.drop(df[df.Price =='€ 165,239'].index)
df = df.drop(df[df.Price =='€ 162,500'].index)
df = df.drop(df[df.Price =='€ 134,000'].index)
df = df.drop(df[df.Price =='€ 1,285'].index)
df = df.drop(df[df.Price =='€ 27,500'].index)
df = df.drop(df[df.Price =='€ 27,500'].index)
df = df.drop(df[df.Price =='€ 459,500'].index)
df = df.drop(df[df.Price =='€ 84,000'].index)
df = df.drop(df[df.Price =='€ 723,500'].index)

df = df.drop(df[df.Price =='€ 281,698'].index)
df = df.drop(df[df.Price =='€ 5,825'].index)
df = df.drop(df[df.Price =='€ 5,250'].index)
df = df.drop(df[df.Price =='€ 2,740'].index)
df = df.drop(df[df.Price =='€ 338,800'].index)
df = df.drop(df[df.Price =='€ 174,500'].index)
df = df.drop(df[df.Price =='€ 124,000'].index)
df = df.drop(df[df.Price =='€ 167,500'].index)
df = df.drop(df[df.Price =='€ 59,900'].index)
df = df.drop(df[df.Price =='€ 314,001'].index)


df = df.drop(df[df.Price =='€ 289,900'].index)
df = df.drop(df[df.Price =='€ 339,500'].index)
df = df.drop(df[df.Price =='€ 357,500'].index)
df = df.drop(df[df.Price =='€ 426,454'].index)
df = df.drop(df[df.Price =='€ 134,500'].index)
df = df.drop(df[df.Price =='€ 328,500'].index)
df = df.drop(df[df.Price =='€ 396,000'].index)
df = df.drop(df[df.Price =='€ 136,500'].index)
df = df.drop(df[df.Price =='€ 371,900'].index)
df = df.drop(df[df.Price =='€ 907,500'].index)
df = df.drop(df[df.Price =='€ 108,535'].index)
df = df.drop(df[df.Price =='€ 1,045'].index)
df = df.drop(df[df.Price =='€ 614,000'].index)
df = df.drop(df[df.Price =='€ 581,000'].index)
df = df.drop(df[df.Price =='€ 183,000'].index)
df = df.drop(df[df.Price =='€ 518,000'].index)
df = df.drop(df[df.Price =='€ 388,800'].index)
df = df.drop(df[df.Price =='€ 488,051'].index)
df = df.drop(df[df.Price =='€ 502,700'].index)
df = df.drop(df[df.Price =='€ 383,800'].index)

df = df.drop(df[df.Price =='€ 2,000'].index)
df = df.drop(df[df.Price =='€ 3,700'].index)
df = df.drop(df[df.Price =='€ 393,000'].index)
df = df.drop(df[df.Price =='€ 103,000'].index)
df = df.drop(df[df.Price =='€ 417,930'].index)
df = df.drop(df[df.Price =='€ 32,000'].index)
df = df.drop(df[df.Price =='€ 722,000'].index)
df = df.drop(df[df.Price =='€ 697,500'].index)
df = df.drop(df[df.Price =='€ 258,500'].index)
df = df.drop(df[df.Price =='€ 74,900'].index)
df = df.drop(df[df.Price =='€ 497,400'].index)
df = df.drop(df[df.Price =='€ 141,385'].index)
df = df.drop(df[df.Price =='€ 313,000'].index)
df = df.drop(df[df.Price =='€ 129,800'].index)
df = df.drop(df[df.Price =='€ 429,500'].index)
df = df.drop(df[df.Price =='€ 441,141'].index)
df = df.drop(df[df.Price =='€ 431,816'].index)
df = df.drop(df[df.Price =='€ 693,600'].index)
df = df.drop(df[df.Price =='€ 651,100'].index)
df = df.drop(df[df.Price =='€ 156,000'].index)

df = df.drop(df[df.Price =='€ 331,785'].index)
df = df.drop(df[df.Price =='€ 93,000'].index)
df = df.drop(df[df.Price =='€ 285,975'].index)
df = df.drop(df[df.Price =='€ 229,669'].index)
df = df.drop(df[df.Price =='€ 157,500'].index)
df = df.drop(df[df.Price =='€ 361,347'].index)
df = df.drop(df[df.Price =='€ 163,000'].index)
df = df.drop(df[df.Price =='€ 173,000'].index)
df = df.drop(df[df.Price =='€ 494,000'].index)
df = df.drop(df[df.Price =='€ 322,291'].index)
df = df.drop(df[df.Price =='€ 296,607'].index)
df = df.drop(df[df.Price =='€ 362,989'].index)
df = df.drop(df[df.Price =='€ 361,499'].index)
df = df.drop(df[df.Price =='€ 361,260'].index)
df = df.drop(df[df.Price =='€ 337,500'].index)

df = df.drop(df[df.Price =='€ 276,075'].index)
df = df.drop(df[df.Price =='€ 291,000'].index)
df = df.drop(df[df.Price =='€ 256,932'].index)
df = df.drop(df[df.Price =='€ 346,500'].index)
df = df.drop(df[df.Price =='€ 232,247'].index)
df = df.drop(df[df.Price =='€ 670,000'].index)
df = df.drop(df[df.Price =='€ 139,999'].index)
df = df.drop(df[df.Price =='€ 72,200'].index)
df = df.drop(df[df.Price =='€ 439,900'].index)
df = df.drop(df[df.Price =='€ 255,087'].index)
df = df.drop(df[df.Price =='€ 569,600'].index)
df = df.drop(df[df.Price =='€ 328,210'].index)
df = df.drop(df[df.Price =='€ 234,900'].index)
df = df.drop(df[df.Price =='€ 342,866'].index)
df = df.drop(df[df.Price =='€ 398,900'].index)
df = df.drop(df[df.Price =='€ 387,500'].index)
df = df.drop(df[df.Price =='€ 215,244'].index)
df = df.drop(df[df.Price =='€ 56,000'].index)
df = df.drop(df[df.Price =='€ 307,867'].index)
df = df.drop(df[df.Price =='€ 668,000'].index)
df = df.drop(df[df.Price =='€ 55,000'].index)
df = df.drop(df[df.Price =='€ 341,000'].index)
df = df.drop(df[df.Price =='€ 356,257'].index)
df = df.drop(df[df.Price =='€ 464,000'].index)
df = df.drop(df[df.Price =='€ 310,846'].index)
df = df.drop(df[df.Price =='€ 1,125'].index)
df = df.drop(df[df.Price =='€ 1,240'].index)
df = df.drop(df[df.Price =='€ 379,386'].index)
df = df.drop(df[df.Price =='€ 386,466'].index)
df = df.drop(df[df.Price =='€ 504,300'].index)
df = df.drop(df[df.Price =='€ 461,272'].index)
df = df.drop(df[df.Price =='€ 89,900'].index)
df = df.drop(df[df.Price =='€ 688,000'].index)
df = df.drop(df[df.Price =='€ 1,399'].index)
df = df.drop(df[df.Price =='€ 351,800'].index)

df = df.drop(df[df.Price =='€ 278,500'].index)
df = df.drop(df[df.Price =='€ 537,000'].index)
df = df.drop(df[df.Price =='€ 1,374'].index)
df = df.drop(df[df.Price =='€ 445,750'].index)
df = df.drop(df[df.Price =='€ 1,075'].index)
df = df.drop(df[df.Price =='€ 443,000'].index)
df = df.drop(df[df.Price =='€ 447,100'].index)
df = df.drop(df[df.Price =='€ 453,816'].index)
df = df.drop(df[df.Price =='€ 383,100'].index)
df = df.drop(df[df.Price =='€ 378,800'].index)
df = df.drop(df[df.Price =='€ 424,000'].index)
df = df.drop(df[df.Price =='€ 1,430'].index)
df = df.drop(df[df.Price =='€ 106,900'].index)
df = df.drop(df[df.Price =='€ 129,900'].index)
df = df.drop(df[df.Price =='€ 448,000'].index)

df = df.drop(df[df.Price =='€ 354,000'].index)
df = df.drop(df[df.Price =='€ 271,500'].index)
df = df.drop(df[df.Price =='€ 214,500'].index)
df = df.drop(df[df.Price =='€ 199,999'].index)
df = df.drop(df[df.Price =='€ 147,000'].index)
df = df.drop(df[df.Price =='€ 634,500'].index)
df = df.drop(df[df.Price =='€ 206,000'].index)
df = df.drop(df[df.Price =='€ 349,560'].index)
df = df.drop(df[df.Price =='€ 331,200'].index)
df = df.drop(df[df.Price =='€ 313,500'].index)
df = df.drop(df[df.Price =='€ 280,443'].index)
df = df.drop(df[df.Price =='€ 437,692'].index)
df = df.drop(df[df.Price =='€ 368,800'].index)
df = df.drop(df[df.Price =='€ 849,999'].index)
df = df.drop(df[df.Price =='€ 338,744'].index)
df = df.drop(df[df.Price =='€ 594,500'].index)
df = df.drop(df[df.Price =='€ 612,800'].index)
df = df.drop(df[df.Price =='€ 108,000'].index)
df = df.drop(df[df.Price =='€ 300,500'].index)
df = df.drop(df[df.Price =='€ 333,181'].index)
df = df.drop(df[df.Price =='€ 338,215'].index)

df = df.drop(df[df.Price =='€ 340,400'].index)
df = df.drop(df[df.Price =='€ 184,500'].index)
df = df.drop(df[df.Price =='€ 1,049'].index)
df = df.drop(df[df.Price =='€ 939,000'].index)
df = df.drop(df[df.Price =='€ 267,000'].index)
df = df.drop(df[df.Price =='€ 368,324'].index)
df = df.drop(df[df.Price =='€ 314,000'].index)
df = df.drop(df[df.Price =='€ 45,000'].index)
df = df.drop(df[df.Price =='€ 2,900'].index)
df = df.drop(df[df.Price =='€ 6,650'].index)
df = df.drop(df[df.Price =='€ 829,000'].index)
df = df.drop(df[df.Price =='€ 370,882'].index)
df = df.drop(df[df.Price =='€ 321,000'].index)
df = df.drop(df[df.Price =='€ 299,995'].index)
df = df.drop(df[df.Price =='€ 354,000'].index)

df = df.drop(df[df.Price =='€ 2,985'].index)
df = df.drop(df[df.Price =='€ 94,000'].index)
df = df.drop(df[df.Price =='€ 436,000'].index)
df = df.drop(df[df.Price =='€ 182,000'].index)
df = df.drop(df[df.Price =='€ 3,690'].index)
df = df.drop(df[df.Price =='€ 342,000'].index)
df = df.drop(df[df.Price =='€ 274,000'].index)
df = df.drop(df[df.Price =='€ 485,700'].index)
df = df.drop(df[df.Price =='€ 463,400'].index)
df = df.drop(df[df.Price =='€ 399,900'].index)

df = df.drop(df[df.Price =='€ 795,500'].index)
df = df.drop(df[df.Price =='€ 3,450'].index)
df = df.drop(df[df.Price =='€ 1,940'].index)
df = df.drop(df[df.Price =='€ 154,500'].index)
df = df.drop(df[df.Price =='€ 1,785'].index)
df = df.drop(df[df.Price =='€ 39,000'].index)
df = df.drop(df[df.Price =='€ 327,500'].index)
df = df.drop(df[df.Price =='€ 710,000'].index)
df = df.drop(df[df.Price =='€ 364,900'].index)
df = df.drop(df[df.Price =='€ 365,700'].index)
df = df.drop(df[df.Price =='€ 1,480'].index)
df = df.drop(df[df.Price =='€ 3,850'].index)
df = df.drop(df[df.Price =='€ 255,500'].index)
df = df.drop(df[df.Price =='€ 2,145'].index)
df = df.drop(df[df.Price =='€ 1,990'].index)

df = df.drop(df[df.Price =='€ 79,500'].index)
df = df.drop(df[df.Price =='€ 448,500'].index)
df = df.drop(df[df.Price =='€ 286,000'].index)
df = df.drop(df[df.Price =='€ 196,000'].index)
df = df.drop(df[df.Price =='€ 387,000'].index)
df = df.drop(df[df.Price =='€ 889,000'].index)
df = df.drop(df[df.Price =='€ 2,399'].index)
df = df.drop(df[df.Price =='€ 999,500'].index)
df = df.drop(df[df.Price =='€ 69,000'].index)
df = df.drop(df[df.Price =='€ 411,000'].index)
df = df.drop(df[df.Price =='€ 256,000'].index)
df = df.drop(df[df.Price =='€ 588,000'].index)
df = df.drop(df[df.Price =='€ 697,000'].index)
df = df.drop(df[df.Price =='€ 20,000'].index)
df = df.drop(df[df.Price =='€ 154,000'].index)
df = df.drop(df[df.Price =='€ 1,820'].index)
df = df.drop(df[df.Price =='€ 252,000'].index)
df = df.drop(df[df.Price =='€ 1,249'].index)
df = df.drop(df[df.Price =='€ 99,500'].index)
df = df.drop(df[df.Price =='€ 15,000'].index)


df = df.drop(df[df.Price =='€ 132,000'].index)
df = df.drop(df[df.Price =='€ 779,000'].index)
df = df.drop(df[df.Price =='€ 865,000'].index)
df = df.drop(df[df.Price =='€ 303,000'].index)
df = df.drop(df[df.Price =='€ 232,948'].index)
df = df.drop(df[df.Price =='€ 1,575'].index)
df = df.drop(df[df.Price =='€ 171,000'].index)
df = df.drop(df[df.Price =='€ 277,000'].index)
df = df.drop(df[df.Price =='€ 482,000'].index)
df = df.drop(df[df.Price =='€ 344,630'].index)
df = df.drop(df[df.Price =='€ 1,060'].index)
df = df.drop(df[df.Price =='€ 444,500'].index)
df = df.drop(df[df.Price =='€ 329,500'].index)
df = df.drop(df[df.Price =='€ 277,500'].index)
df = df.drop(df[df.Price =='€ 3,380'].index)
df = df.drop(df[df.Price =='€ 287,000'].index)
df = df.drop(df[df.Price =='€ 282,500'].index)
df = df.drop(df[df.Price =='€ 1,370'].index)
df = df.drop(df[df.Price =='€ 412,000'].index)
df = df.drop(df[df.Price =='€ 999,000'].index)

df = df.drop(df[df.Price =='€ 149,500'].index)
df = df.drop(df[df.Price =='€ 332,000'].index)
df = df.drop(df[df.Price =='€ 1,645'].index)
df = df.drop(df[df.Price =='€ 249,950'].index)
df = df.drop(df[df.Price =='€ 122,500'].index)
df = df.drop(df[df.Price =='€ 69,500'].index)
df = df.drop(df[df.Price =='€ 357,000'].index)
df = df.drop(df[df.Price =='€ 1,140'].index)
df = df.drop(df[df.Price =='€ 133,000'].index)
df = df.drop(df[df.Price =='€ 269,500'].index)
df = df.drop(df[df.Price =='€ 10,000'].index)
df = df.drop(df[df.Price =='€ 648,000'].index)
df = df.drop(df[df.Price =='€ 478,000'].index)
df = df.drop(df[df.Price =='€ 474,000'].index)
df = df.drop(df[df.Price =='€ 118,000'].index)
df = df.drop(df[df.Price =='€ 1,920'].index)
df = df.drop(df[df.Price =='€ 419,893'].index)
df = df.drop(df[df.Price =='€ 89,500'].index)
df = df.drop(df[df.Price =='€ 352,000'].index)
df = df.drop(df[df.Price =='€ 249,750'].index)
df = df.drop(df[df.Price =='€ 2,990'].index)
df = df.drop(df[df.Price =='€ 232,000'].index)
df = df.drop(df[df.Price =='€ 333,000'].index)
df = df.drop(df[df.Price =='€ 272,000'].index)
df = df.drop(df[df.Price =='€ 339,900'].index)
df = df.drop(df[df.Price =='€ 159,169'].index)
df = df.drop(df[df.Price =='€ 227,000'].index)
df = df.drop(df[df.Price =='€ 276,000'].index)
df = df.drop(df[df.Price =='€ 292,500'].index)
df = df.drop(df[df.Price =='€ 317,500'].index)
df = df.drop(df[df.Price =='€ 483,000'].index)
df = df.drop(df[df.Price =='€ 342,785'].index)
df = df.drop(df[df.Price =='€ 345,900'].index)
df = df.drop(df[df.Price =='€ 347,000'].index)
df = df.drop(df[df.Price =='€ 2,817'].index)
df = df.drop(df[df.Price =='€ 337,000'].index)

df = df.drop(df[df.Price =='€ 142,000'].index)
df = df.drop(df[df.Price =='€ 328,000'].index)
df = df.drop(df[df.Price =='€ 678,000'].index)
df = df.drop(df[df.Price =='€ 237,500'].index)
df = df.drop(df[df.Price =='€ 109,900'].index)
df = df.drop(df[df.Price =='€ 136,000'].index)
df = df.drop(df[df.Price =='€ 660,000'].index)
df = df.drop(df[df.Price =='€ 144,000'].index)
df = df.drop(df[df.Price =='€ 309,500'].index)
df = df.drop(df[df.Price =='€ 144,000'].index)
df = df.drop(df[df.Price =='€ 660,000'].index)
df = df.drop(df[df.Price =='€ 423,500'].index)
df = df.drop(df[df.Price =='€ 291,328'].index)
df = df.drop(df[df.Price =='€ 291,328'].index)
df = df.drop(df[df.Price =='€ 297,348'].index)
df = df.drop(df[df.Price =='€ 202,000'].index)
df = df.drop(df[df.Price =='€ 262,000'].index)
df = df.drop(df[df.Price =='€ 1,299'].index)
df = df.drop(df[df.Price =='€ 1,065'].index)
df = df.drop(df[df.Price =='€ 340,347'].index)
df = df.drop(df[df.Price =='€ 835,000'].index)
df = df.drop(df[df.Price =='€ 295,500'].index)
df = df.drop(df[df.Price =='€ 512,000'].index)
df = df.drop(df[df.Price =='€ 2,249'].index)
df = df.drop(df[df.Price =='€ 5,850'].index)
df = df.drop(df[df.Price =='€ 559,000'].index)
df = df.drop(df[df.Price =='€ 1,255'].index)
df = df.drop(df[df.Price =='€ 367,000'].index)
df = df.drop(df[df.Price =='€ 253,000'].index)
df = df.drop(df[df.Price =='€ 166,000'].index)
df = df.drop(df[df.Price =='€ 2,685'].index)
df = df.drop(df[df.Price =='€ 253,740'].index)
df = df.drop(df[df.Price =='€ 322,000'].index)
df = df.drop(df[df.Price =='€ 492,000'].index)
df = df.drop(df[df.Price =='€ 424,450'].index)
df = df.drop(df[df.Price =='€ 262,500'].index)
df = df.drop(df[df.Price =='€ 9,500'].index)
df = df.drop(df[df.Price =='€ 830,000'].index)
df = df.drop(df[df.Price =='€ 336,000'].index)
df = df.drop(df[df.Price =='€ 332,410'].index)
df = df.drop(df[df.Price =='€ 433,000'].index)
df = df.drop(df[df.Price =='€ 358,500'].index)
df = df.drop(df[df.Price =='€ 362,500'].index)
df = df.drop(df[df.Price =='€ 2,850'].index)
df = df.drop(df[df.Price =='€ 5,500'].index)
df = df.drop(df[df.Price =='€ 2,650'].index)
df = df.drop(df[df.Price =='€ 1,280'].index)

df = df.drop(df[df.Price =='€ 2,280'].index)
df = df.drop(df[df.Price =='€ 257,500'].index)
df = df.drop(df[df.Price =='€ 620,000'].index)
df = df.drop(df[df.Price =='€ 88,000'].index)
df = df.drop(df[df.Price =='€ 364,300'].index)
df = df.drop(df[df.Price =='€ 99,900'].index)
df = df.drop(df[df.Price =='€ 284,000'].index)
df = df.drop(df[df.Price =='€ 497,000'].index)
df = df.drop(df[df.Price =='€ 1,275'].index)
df = df.drop(df[df.Price =='€ 128,000'].index)
df = df.drop(df[df.Price =='€ 3,750'].index)
df = df.drop(df[df.Price =='€ 49,000'].index)
df = df.drop(df[df.Price =='€ 169,500'].index)
df = df.drop(df[df.Price =='€ 679,000'].index)
df = df.drop(df[df.Price =='€ 2,975'].index)
df = df.drop(df[df.Price =='€ 209,500'].index)
df = df.drop(df[df.Price =='€ 434,000'].index)
df = df.drop(df[df.Price =='€ 1,890'].index)
df = df.drop(df[df.Price =='€ 644,500'].index)
df = df.drop(df[df.Price =='€ 1,165'].index)
df = df.drop(df[df.Price =='€ 353,050'].index)
df = df.drop(df[df.Price =='€ 497,500'].index)
df = df.drop(df[df.Price =='€ 164,500'].index)
df = df.drop(df[df.Price =='€ 197,000'].index)
df = df.drop(df[df.Price =='€ 119,500'].index)
df = df.drop(df[df.Price =='€ 815,000'].index)
df = df.drop(df[df.Price =='€ 559,500'].index)
df = df.drop(df[df.Price =='€ 707,645'].index)
df = df.drop(df[df.Price =='€ 296,000'].index)
df = df.drop(df[df.Price =='€ 408,000'].index)

df = df.drop(df[df.Price =='€ 2,400'].index)
df = df.drop(df[df.Price =='€ 168,000'].index)
df = df.drop(df[df.Price =='€ 4,350'].index)
df = df.drop(df[df.Price =='€ 59,000'].index)
df = df.drop(df[df.Price =='€ 428,000'].index)
df = df.drop(df[df.Price =='€ 1,800'].index)
df = df.drop(df[df.Price =='€ 2,275'].index)
df = df.drop(df[df.Price =='€ 282,000'].index)
df = df.drop(df[df.Price =='€ 378,000'].index)
df = df.drop(df[df.Price =='€ 580,953'].index)
df = df.drop(df[df.Price =='€ 595,400'].index)
df = df.drop(df[df.Price =='€ 870,000'].index)
df = df.drop(df[df.Price =='€ 639,000'].index)
df = df.drop(df[df.Price =='€ 376,700'].index)
df = df.drop(df[df.Price =='€ 1,790'].index)



df = df.drop(df[df.Price =='€ 293,250'].index)
df = df.drop(df[df.Price =='€ 194,900'].index)
df = df.drop(df[df.Price =='€ 2,490'].index)
df = df.drop(df[df.Price =='€ 359,500'].index)
df = df.drop(df[df.Price =='€ 1,145'].index)
df = df.drop(df[df.Price =='€ 748,000'].index)
df = df.drop(df[df.Price =='€ 388,000'].index)
df = df.drop(df[df.Price =='€ 885,000'].index)
df = df.drop(df[df.Price =='€ 820,000'].index)
df = df.drop(df[df.Price =='€ 266,000'].index)
df = df.drop(df[df.Price =='€ 219,500'].index)
df = df.drop(df[df.Price =='€ 384,000'].index)
df = df.drop(df[df.Price =='€ 3,150'].index)
df = df.drop(df[df.Price =='€ 112,000'].index)
df = df.drop(df[df.Price =='€ 759,000'].index)

df = df.drop(df[df.Price =='€ 1,390'].index)
df = df.drop(df[df.Price =='€ 347,500'].index)
df = df.drop(df[df.Price =='€ 287,500'].index)
df = df.drop(df[df.Price =='€ 1,180'].index)
df = df.drop(df[df.Price =='€ 780,000'].index)
df = df.drop(df[df.Price =='€ 404,600'].index)
df = df.drop(df[df.Price =='€ 245,748'].index)
df = df.drop(df[df.Price =='€ 139,900'].index)
df = df.drop(df[df.Price =='€ 244,000'].index)
df = df.drop(df[df.Price =='€ 392,110'].index)
df = df.drop(df[df.Price =='€ 630,000'].index)
df = df.drop(df[df.Price =='€ 1,245'].index)
df = df.drop(df[df.Price =='€ 2,295'].index)
df = df.drop(df[df.Price =='€ 990,000'].index)
df = df.drop(df[df.Price =='€ 1,190'].index)
df = df.drop(df[df.Price =='€ 555,000'].index)
df = df.drop(df[df.Price =='€ 297,500'].index)
df = df.drop(df[df.Price =='€ 178,000'].index)
df = df.drop(df[df.Price =='€ 372,000'].index)
df = df.drop(df[df.Price =='€ 129,500'].index)

df = df.drop(df[df.Price =='€ 249,900'].index)
df = df.drop(df[df.Price =='€ 35,000'].index)
df = df.drop(df[df.Price =='€ 139,500'].index)
df = df.drop(df[df.Price =='€ 218,000'].index)
df = df.drop(df[df.Price =='€ 1,680'].index)
df = df.drop(df[df.Price =='€ 409,000'].index)
df = df.drop(df[df.Price =='€ 292,000'].index)
df = df.drop(df[df.Price =='€ 392,000'].index)
df = df.drop(df[df.Price =='€ 1,085'].index)
df = df.drop(df[df.Price =='€ 985,000'].index)
df = df.drop(df[df.Price =='€ 239,500'].index)
df = df.drop(df[df.Price =='€ 1,225'].index)
df = df.drop(df[df.Price =='€ 318,000'].index)
df = df.drop(df[df.Price =='€ 910,000'].index)
df = df.drop(df[df.Price =='€ 259,900'].index)


df = df.drop(df[df.Price =='€ 289,500'].index)
df = df.drop(df[df.Price =='€ 229,900'].index)
df = df.drop(df[df.Price =='€ 199,900'].index)
df = df.drop(df[df.Price =='€ 1,199'].index)
df = df.drop(df[df.Price =='€ 212,000'].index)
df = df.drop(df[df.Price =='€ 79,000'].index)
df = df.drop(df[df.Price =='€ 137,000'].index)
df = df.drop(df[df.Price =='€ 1,185'].index)
df = df.drop(df[df.Price =='€ 1,375'].index)
df = df.drop(df[df.Price =='€ 1,980'].index)

df = df.drop(df[df.Price =='€ 2,200'].index)
df = df.drop(df[df.Price =='€ 2,300'].index)
df = df.drop(df[df.Price =='€ 1,700'].index)
df = df.drop(df[df.Price =='€ 405,000'].index)
df = df.drop(df[df.Price =='€ 299,900'].index)
df = df.drop(df[df.Price =='€ 394,400'].index)
df = df.drop(df[df.Price =='€ 394,000'].index)
df = df.drop(df[df.Price =='€ 569,000'].index)
df = df.drop(df[df.Price =='€ 331,000'].index)
df = df.drop(df[df.Price =='€ 159,500'].index)
df = df.drop(df[df.Price =='€ 920,000'].index)
df = df.drop(df[df.Price =='€ 1,380'].index)
df = df.drop(df[df.Price =='€ 467,000'].index)
df = df.drop(df[df.Price =='€ 294,500'].index)
df = df.drop(df[df.Price =='€ 159,50'].index)
df = df.drop(df[df.Price =='€ 1,300'].index)
df = df.drop(df[df.Price =='€ 334,000'].index)
df = df.drop(df[df.Price =='€ 228,000'].index)
df = df.drop(df[df.Price =='€ 184,000'].index)
df = df.drop(df[df.Price =='€ 770,000'].index)

df = df.drop(df[df.Price =='€ 1,690'].index)
df = df.drop(df[df.Price =='€ 880,000'].index)
df = df.drop(df[df.Price =='€ 294,000'].index)
df = df.drop(df[df.Price =='€ 860,000'].index)
df = df.drop(df[df.Price =='€ 1,600'].index)
df = df.drop(df[df.Price =='€ 589,000'].index)
df = df.drop(df[df.Price =='€ 349,500'].index)
df = df.drop(df[df.Price =='€ 540,000'].index)
df = df.drop(df[df.Price =='€ 548,000'].index)
df = df.drop(df[df.Price =='€ 610,000'].index)
df = df.drop(df[df.Price =='€ 1,995'].index)
df = df.drop(df[df.Price =='€ 316,000'].index)
df = df.drop(df[df.Price =='€ 257,000'].index)
df = df.drop(df[df.Price =='€ 247,000'].index)
df = df.drop(df[df.Price =='€ 1,900'].index)

df = df.drop(df[df.Price =='€ 669,000'].index)
df = df.drop(df[df.Price =='€ 539,000'].index)
df = df.drop(df[df.Price =='€ 3,950'].index)
df = df.drop(df[df.Price =='€ 3,900'].index)
df = df.drop(df[df.Price =='€ 158,000'].index)
df = df.drop(df[df.Price =='€ 669,000 '].index)
df = df.drop(df[df.Price =='€ 3,300'].index)
df = df.drop(df[df.Price =='€ 406,000'].index)
df = df.drop(df[df.Price =='€ 659,000'].index)
df = df.drop(df[df.Price =='€ 1,695'].index)
df = df.drop(df[df.Price =='€ 268,000'].index)
df = df.drop(df[df.Price =='€ 680,000'].index)
df = df.drop(df[df.Price =='€ 25,000'].index)
df = df.drop(df[df.Price =='€ 259,500'].index)
df = df.drop(df[df.Price =='€ 189,900'].index)
df = df.drop(df[df.Price ==''].index)
df = df.drop(df[df.Price ==''].index)

df = df.drop(df[df.Price =='€ 530,000'].index)
df = df.drop(df[df.Price =='€ 730,000'].index)
df = df.drop(df[df.Price =='€ 1,000'].index)
df = df.drop(df[df.Price =='€ 2,800'].index)
df = df.drop(df[df.Price =='€ 629,000'].index)
df = df.drop(df[df.Price =='€ 1,975'].index)
df = df.drop(df[df.Price =='€ 149,900'].index)
df = df.drop(df[df.Price =='€ 299,500'].index)
df = df.drop(df[df.Price =='€ 1,499'].index)
df = df.drop(df[df.Price =='€ 174,000'].index)
df = df.drop(df[df.Price =='€ 224,000'].index)
df = df.drop(df[df.Price =='€ 358,000'].index)
df = df.drop(df[df.Price =='€ 945,000'].index)
df = df.drop(df[df.Price =='€ 935,000'].index)
df = df.drop(df[df.Price =='€ 1,175'].index)

df = df.drop(df[df.Price =='€ 283,000'].index)
df = df.drop(df[df.Price =='€ 819,000'].index)
df = df.drop(df[df.Price =='€ 1,200'].index)
df = df.drop(df[df.Price =='€ 1,090'].index)
df = df.drop(df[df.Price =='€ 397,500'].index)
df = df.drop(df[df.Price =='€ 698,000'].index)
df = df.drop(df[df.Price =='€ 2,600'].index)
df = df.drop(df[df.Price =='€ 1,550'].index)
df = df.drop(df[df.Price =='€ 900,000'].index)
df = df.drop(df[df.Price =='€ 234,000'].index)
df = df.drop(df[df.Price =='€ 949,000'].index)
df = df.drop(df[df.Price =='€ 30,000'].index)
df = df.drop(df[df.Price =='€ 40,000'].index)
df = df.drop(df[df.Price =='€ 1,795'].index)
df = df.drop(df[df.Price =='€ 899,000'].index)
df = df.drop(df[df.Price =='€ 248,000'].index)
df = df.drop(df[df.Price =='€ 279,500'].index)
df = df.drop(df[df.Price =='€ 972,000'].index)
df = df.drop(df[df.Price =='€ 324,000'].index)
df = df.drop(df[df.Price =='€ 640,000'].index)
df = df.drop(df[df.Price =='€ 510,000'].index)
df = df.drop(df[df.Price =='€ 500,000'].index)
df = df.drop(df[df.Price =='€ 735,000'].index)
df = df.drop(df[df.Price =='€ 498,000'].index)
df = df.drop(df[df.Price =='€ 849,000'].index)
df = df.drop(df[df.Price =='€ 560,000'].index)
df = df.drop(df[df.Price =='€ 715,000'].index)
df = df.drop(df[df.Price =='€ 765,000'].index)
df = df.drop(df[df.Price =='€ 800,000'].index)
df = df.drop(df[df.Price =='€ 189,500'].index)
df = df.drop(df[df.Price =='€ 237,000'].index)

df = df.drop(df[df.Price =='€ 2,950'].index)
df = df.drop(df[df.Price =='€ 665,000'].index)
df = df.drop(df[df.Price =='€ 519,000'].index)
df = df.drop(df[df.Price =='€ 238,000'].index)
df = df.drop(df[df.Price =='€ 2,350'].index)
df = df.drop(df[df.Price =='€ 2,450'].index)
df = df.drop(df[df.Price =='€ 297,000'].index)
df = df.drop(df[df.Price =='€ 229,500'].index)
df = df.drop(df[df.Price =='€ 3,200'].index)
df = df.drop(df[df.Price =='€ 1,750'].index)
df = df.drop(df[df.Price =='€ 199,500'].index)
df = df.drop(df[df.Price =='€ 440,000'].index)
df = df.drop(df[df.Price =='€ 438,000'].index)
df = df.drop(df[df.Price =='€ 2,500'].index)
df = df.drop(df[df.Price =='€ 455,000'].index)

df = df.drop(df[df.Price =='€ 685,000'].index)
df = df.drop(df[df.Price =='€ 179,500'].index)
df = df.drop(df[df.Price =='€ 4,950'].index)
df = df.drop(df[df.Price =='€ 580,000'].index)
df = df.drop(df[df.Price =='€ 368,000'].index)
df = df.drop(df[df.Price =='€ 50,000'].index)
df = df.drop(df[df.Price =='€ 615,000'].index)
df = df.drop(df[df.Price =='€ 298,000'].index)
df = df.drop(df[df.Price =='€ 749,000'].index)
df = df.drop(df[df.Price =='€ 278,000'].index)
df = df.drop(df[df.Price =='€ 875,000'].index)
df = df.drop(df[df.Price =='€ 198,000'].index)
df = df.drop(df[df.Price =='€ 700,000'].index)
df = df.drop(df[df.Price =='€ 825,000'].index)
df = df.drop(df[df.Price =='€ 579,000'].index)
df = df.drop(df[df.Price =='€ 975,000'].index)
df = df.drop(df[df.Price =='€ 459,000'].index)
df = df.drop(df[df.Price =='€ 249,500'].index)
df = df.drop(df[df.Price =='€ 598,000'].index)
df = df.drop(df[df.Price =='€ 890,000'].index)
df = df.drop(df[df.Price =='€ 60,000'].index)
df = df.drop(df[df.Price =='€ 89,000'].index)
df = df.drop(df[df.Price =='€ 65,000'].index)
df = df.drop(df[df.Price =='€ 1,400'].index)
df = df.drop(df[df.Price =='€ 1,095'].index)

df = df.drop(df[df.Price =='€ 398,000'].index)
df = df.drop(df[df.Price =='€ 205,000'].index)
df = df.drop(df[df.Price =='€ 2,750'].index)
df = df.drop(df[df.Price =='€ 535,000'].index)
df = df.drop(df[df.Price =='€ 799,000'].index)
df = df.drop(df[df.Price =='€ 720,000'].index)
df = df.drop(df[df.Price =='€ 925,000'].index)
df = df.drop(df[df.Price =='€ 845,000'].index)
df = df.drop(df[df.Price =='€ 1,950'].index)
df = df.drop(df[df.Price =='€ 309,000'].index)
df = df.drop(df[df.Price =='€ 1,500'].index)
df = df.drop(df[df.Price =='€ 1,395'].index)
df = df.drop(df[df.Price =='€ 348,000'].index)
df = df.drop(df[df.Price =='€ 1,775'].index)
df = df.drop(df[df.Price =='€ 529,000'].index)
df = df.drop(df[df.Price =='€ 1,850'].index)
df = df.drop(df[df.Price =='€ 70,000'].index)
df = df.drop(df[df.Price =='€ 590,000'].index)
df = df.drop(df[df.Price =='€ 745,000'].index)
df = df.drop(df[df.Price =='€ 479,000'].index)
df['Price'] = df['Price'].apply(lambda x: x.replace('€', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)
del df["Location"]
del df["Area"]
del df["Furnished"]
del df["Kitchen type"]
del df["Status"]
del df["Garden surface"]
del df["Swimming Pool"]
       

df

#df['Price'].value_counts()
#df['Price'].unique()
#df"]



#df['Price'].value_counts()
#df['Price'].unique()
#df
# Out:
#             property-type   Price Number_of_Rooms
# 1                  OTHERS    1650               4
# 2          House for sale  419000               3
# 4          House for sale  149000               2
# 5          House for sale  149000               5
# 6          House for sale  149000               2
# ...                   ...     ...             ...
# 10183              OTHERS  599900               4
# 10184              OTHERS  729000               8
# 10185  Apartment for sale  150000               1
# 10186              OTHERS    2795               3
# 10187      House for sale  980000               5
#
# [7599 rows x 3 columns]

# %%
#build a model 
import seaborn as sns
import pandas as pd
df
df.shape
import numpy as np 

X = df.drop(columns=['property-type']).to_numpy()
y =Price= df.Price.to_numpy().reshape(-1 , 1)
print("X shape : ", X.shape)
print("y shape : ", y.shape)
#ax.scatter(df['Number_of_Rooms'],df['Price'])

fig, axes = plt.subplots(nrows=1, ncols=1)
plt.tight_layout()


axes.scatter(df['Number_of_Rooms'],df['Price'])
plt.show()
df.corr()

from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_test: ", y_test.shape)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
The_accuracy_of_the_train=print('The accuracy of the train',regressor.score(X_train, y_train)*100)
TheAccuracyofthetest=print('The Accuracy of thetest',regressor.score(X_test, y_test)*100)
#print(regressor.score(X_test,X_train)*100)
#print(regressor.score(y_test,y_train)*100)
y_pred=regressor.predict(X_test)
print(y_pred)
print('coefficient',regressor.coef_)

from sklearn.metrics import mean_squared_error
print('mean_squared_error',mean_squared_error(y_test, y_pred, squared=False))
sns.displot(df['Price'],kde=False)
sns.displot(df['Number_of_Rooms'],kde=False)
sns.displot(df['property-type'],kde=False)
import seaborn as sb
sns.boxplot(df['Price'],df['Number_of_Rooms'])
#for feat in df.dtypes[df.dtypes=='object'].index:
 #   sb.countplot(y='Price', data=df)
#import seaborn as sb
#mask = np.zeros_like(df.corr(), dtype=np.bool)
#mask[np.triu_indices_from(mask)] = True
#sb.heatmap(df.corr()*100, 
 #          cmap='RdBu_r', 
  #         annot = True, 
   #        mask = mask)
# Out:
# X shape :  (7599, 2)
# y shape :  (7599, 1)
# Shape of X_train:  (6079, 2)
# Shape of X_test:  (1520, 2)
# Shape of y_train:  (6079, 1)
# Shape of y_test:  (1520, 1)
# The accuracy of the train 100.0
# The Accuracy of thetest 100.0
# [[150000.]
#  [280000.]
#  [389000.]
#  ...
#  [695000.]
#  [375000.]
#  [695000.]]
# coefficient [[ 1.0000000e+00 -5.4091095e-13]]
# mean_squared_error 1.2601422088402792e-10
# C:\Users\masrra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Number_of_Rooms'>

# %%
#ON DOCKER
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.externals import joblib
from sklearn.metrics import mean_squared_error
df = pd.read_csv("/home/jinesh/Desktop/cardata/train.csv")
# Check data columns and Drop unncessesary columns.
df.columns
df.drop('Unnamed: 0',inplace=True,axis=1)
df.head(5)

LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
         normalize=False)
### Now check the RMSE of model
price_pred = lin_reg.predict(X_test)
lin_rmse = np.sqrt(mean_squared_error(price_pred,y_test))
lin_rmse
## We see here some column (Fuel_type) is Non Numeric, Convert into numeric value
df['Fuel_Type'] = df['Fuel_Type'].apply(lambda x: 1 if x == "Petrol" else 0)

## Drop selling price for train our model
selling_prices = df['SellingPrice']
df.drop('SellingPrice',axis=1,inplace=True)

## Split the data into train and test sets for train our model
X_train, X_test, y_train, y_test = train_test_split(df,selling_prices,random_state=42)

## At this point we have clean data set that has data for model to train, Train linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)

### Check prediction on one data point
X_new = np.array([26000,0,3,1,86,0,1300,1015,5]).reshape(1,-1)
lin_reg.predict(X_new)

### Save our model, This will generate .pkl file in your currentl dircetroy, your model is ready to use.
joblib.dump(lin_reg,"car_price_prediction.pkl")

# %%
#FOR the picture of the application 
#CarPricePrediction/web/src/static/style.css
h1 {
  text-align: center;
  background-color:  rgba(71, 99, 255, 0.2);
  border-style: outset;
}

h2 {
  text-align: left;
  background-color:  rgba(71, 99, 255, 0.2);
  border-style: outset;
}

body {
   background-image: url("car1.jpg");
   background-repeat: 2;
}

p {
  text-align: left;
  font-family:Courier New;
  font-size: 20px;
  font-weight: bold;
  font-style: oblique;
  padding-bottom: 10px;

}

# %%
#CarPricePrediction/web/src/templates/car.html
<html>
 <head>
        {% if title %}
        <title>{{ title }}'s Car Price Prediction</title>
        {% else %}
        <title>Welcome to Car Price Prediction</title>
        {% endif %}
        <link rel="stylesheet" type="text/css" href="/static/style.css">
    </head>
 <body>
    <h1> Car Price Prediction based on Linear Regression</h1>
    <p style="text-align:left;font-size:12; font-style:italic;font-family:Times">Get Original Dataset From <a href="https://www.kaggle.com/gunishj/carpricepred/downloads/carpricepred.zip/1">Here</a></p>
    <h2>Enter your car details</h2>
    <form action="" method="post">
        {{ form.hidden_tag() }}
        <p>
            {{ form.car_age.label }}</br>
            {{ form.car_age(size=32) }}</br>
            {% for error in form.car_age.errors %}
            <span style="color:red;">{{ error }}</span>
            {% endfor %}
        </p>
        <p>
            {{ form.car_doors.label }}</br>
            {{ form.car_doors(size=32) }}</br>
            {% for error in form.car_doors.errors %}
            <span style="color:red;">{{ error }}</span>
            {% endfor %}
        </p>
         <p>
            {{ form.car_cc.label }}</br>
            {{ form.car_cc(size=32) }}</br>
            {% for error in form.car_cc.errors %}
            <span style="color:red;">{{ error }}</span>
            {% endfor %}
        </p>
        <p>
            {{ form.car_horsepower.label }}</br>
            {{ form.car_horsepower(size=32) }}</br>
            {% for error in form.car_horsepower.errors %}
            <span style="color:red;">{{ error }}</span>
            {% endfor %}
        </p>
         <p>
            {{ form.car_odometer.label }}</br>
            {{ form.car_odometer(size=32) }}</br>
            {% for error in form.car_odometer.errors %}
            <span style="color:red;">{{ error }}</span>
            {% endfor %}
        </p>
        <p>
            {{ form.car_weight.label }}</br>
            {{ form.car_weight(size=32) }}</br>
            {% for error in form.car_weight.errors %}
            <span style="color:red;">{{ error }}</span>
            {% endfor %}
        </p>
         <p>
            {{form.car_fuel.label}}  {{form.car_fuel}}
            <!--{% for error in form.car_fuel.errors %}-->
            <!--<span style="color:red;">{{ error }}</span>-->
            <!--{% endfor %}-->
        </p>
         <p>
            {{form.car_transmission.label}}  {{form.car_transmission}}
            <!--{% for error in form.car_transmission.errors %}-->
            <!--<span style="color:red;">{{ error }}</span>-->
            <!--{% endfor %}-->
        </p>
        <p>
            {{form.car_color.label}}  {{form.car_color}}
            <!--{% for error in form.car_color.errors %}-->
            <!--<span style="color:red;">{{ error }}</span>-->
            <!--{% endfor %}-->
        </p>
        <p>
            {{ form.predict() }}
        </p>
    </form>
</body>
</html>

# %%
#CarPricePrediction/web/src/templates/error.html
<html>
    <head>
       <title>Error Page</title>
        <link rel="stylesheet" type="text/css" href="/static/style.css">
    </head>
    <body>
    <h1 style="color:red"> Must be missing some mandatory values, Please try Again </h1>
    </body>
</html>

# %%
#CarPricePrediction/web/src/templates/result.html
<html>
    <head>
        {% if title %}
        <title>{{ title }}'s Car Price Prediction</title>
        {% else %}
        <title>Welcome to Car Price Prediction</title>
        {% endif %}
          <link rel="stylesheet" type="text/css" href="/static/style.css">
   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
   <script type="text/javascript">
      google.charts.load('current', {'packages':['gauge']});
      google.charts.setOnLoadCallback(drawChart);

      function drawChart() {

        var data = google.visualization.arrayToDataTable([
          ['Label', 'Value'],
          ['Car Price', {{ price }}]
        ]);

        var options = {
          width: 1000, height: 500,
          redFrom: {{ price }} - 1120, redTo: {{ price }} + 1120,

          minorTicks: 10,
          max: 2 * {{price}} ,
          min:0
        };
        var chart = new google.visualization.Gauge(document.getElementById('car_price'));
        chart.draw(data, options);

      }
    </script>
    </head>
    <body>
    <h1> Based on Our model your car price is US$ {{ price }}</h1>
    <div id="car_price" style="width: 400px; height: 120px;"></div>
    </body>
</html>
